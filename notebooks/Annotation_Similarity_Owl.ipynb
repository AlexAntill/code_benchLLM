# %% [markdown]
# # Cell Ontology Similarity from CSV
# A notebook that assesses cell similarities from a csv conatining two cell types. Using Owlready

# %%
import pandas as pd
import numpy as np
import os
import glob
import re
from rapidfuzz import process
from owlready2 import get_ontology

# %%
## Load Datasets and Mapping Reference (Text to Cell Ontology ID)
# Base Directory of Dataset
base_dir = os.path.expanduser("~/Göran_Karlsson_Lab/benchLLM/Granja_et_al")
input_pattern = os.path.join(base_dir, "author_vs_*.csv")

# Mapping Reference 
# General 
mapping_df = pd.read_csv(os.path.expanduser("~/Göran_Karlsson_Lab/benchLLM/cell_to_cell_ontology.csv"))
label_to_id = dict(zip(mapping_df['label'], mapping_df['ontology_id']))
label_to_id_ci = {k.lower(): v for k, v in label_to_id.items()} # Remove Case Sentivity

# %%
# Load Cell Ontology Map (OWL)
print("Loading Cell Ontology (OWL)...")
G = get_ontology("http://purl.obolibrary.org/obo/cl.owl").load()
print("Ontology loaded.")
# Out:
# Loading Cell Ontology (OWL)...
# Ontology loaded.

# %%
def get_ancestors(cls):
    return set(cls.ancestors()) if cls else set()

def compute_similarity(id1, id2, onto):
    if id1 is None or id2 is None:
        return 0

    class1 = onto.search_one(iri="*" + id1.replace(":", "_"))
    class2 = onto.search_one(iri="*" + id2.replace(":", "_"))

    if not class1 or not class2:
        return 0

    ancestors1 = get_ancestors(class1)
    ancestors2 = get_ancestors(class2)

    intersection = ancestors1 & ancestors2
    union = ancestors1 | ancestors2

    if not union:
        return 0

    return len(intersection) / len(union)  # Jaccard similarity

def normalize_label(label):
    label = str(label).lower().strip()
    label = re.sub(r'\s*\(.*?\)', '', label)
    if label.endswith('s') and len(label) > 1:
        label = label[:-1]
    return label

def fuzzy_match_label(label, choices, threshold=80):
    if label is None:
        return None
    result = process.extractOne(label, choices)
    if result is None:
        return None
    if len(result) == 2:
        match, score = result
    elif len(result) == 3:
        # Sometimes it returns (match, score, index)
        match, score, _ = result
    else:
        return None
    if score >= threshold:
        return match
    return None


for file_path in glob.glob(input_pattern):
    if '_similarity' in os.path.basename(file_path):
        continue

    print(f"\nProcessing: {os.path.basename(file_path)}")
    df = pd.read_csv(file_path)

    colnames = df.columns.tolist()
    if len(colnames) < 2:
        print(f"  Skipping {file_path} — not enough columns.")
        continue

    author_col = colnames[0]
    llm_col = colnames[1]

    similarity_scores = []
    for _, row in df.iterrows():
        author_label = normalize_label(row[author_col])
        llm_label = normalize_label(row[llm_col])

        if author_label in ["nan", "none"] or pd.isna(author_label):
            author_label = None
        if llm_label in ["nan", "none"] or pd.isna(llm_label):
            llm_label = None

        fuzzy_used = False

        id1 = label_to_id_ci.get(author_label) if author_label else None
        id2 = label_to_id_ci.get(llm_label) if llm_label else None

        if id1 is None and author_label is not None:
            matched_label = fuzzy_match_label(author_label, label_to_id_ci.keys())
            if matched_label:
                fuzzy_used = True
            id1 = label_to_id_ci.get(matched_label)

        if id2 is None and llm_label is not None:
            matched_label = fuzzy_match_label(llm_label, label_to_id_ci.keys())
            if matched_label:
                fuzzy_used = True
            id2 = label_to_id_ci.get(matched_label)

        sim = compute_similarity(id1, id2, G)
        print(f"Comparing {author_label} ({id1}) vs {llm_label} ({id2}) (fuzzy={fuzzy_used}): sim={sim}")
        similarity_scores.append(sim)


    df['similarity_score'] = similarity_scores

    #out_path = file_path.replace(".csv", "_similarity.csv")
    #df.to_csv(out_path, index=False)
    #print(f"  Saved: {os.path.basename(out_path)}")
# Out:
# Processing: author_vs_celltypist_Roy_Immune_All_High_new.csv
# Comparing 01_hsc (CL:0000037) vs hsc/mpp (CL:0000037) (fuzzy=True): sim=1.0
# Comparing 02_early.eryth (None) vs memp (CL:0000050) (fuzzy=True): sim=0
# Comparing 03_late.eryth (None) vs mid erythroid (CL:0000038) (fuzzy=True): sim=0
# Comparing 04_early.baso (None) vs mast cell (CL:0000097) (fuzzy=False): sim=0
# Comparing 05_cmp.lmpp (CL:0001059) vs hsc/mpp (CL:0000037) (fuzzy=True): sim=0.6842105263157895
# Comparing 06_clp.1 (CL:0000051) vs pro-b cell (CL:0000826) (fuzzy=True): sim=0.7222222222222222
# Comparing 07_gmp (CL:0000557) vs classical monocyte (CL:0000860) (fuzzy=True): sim=0.3939393939393939
# Comparing 08_gmp.neut (CL:0000557) vs neutrophil-myeloid progenitor (CL:0000775) (fuzzy=True): sim=0.39285714285714285
# Comparing 09_pdc (CL:0000784) vs pdc (CL:0000784) (fuzzy=True): sim=1.0
# Comparing 10_cdc (CL:0000990) vs dc2 (CL:0000784) (fuzzy=True): sim=0.9130434782608695
# Comparing 11_cd14.mono.1 (None) vs classical monocyte (CL:0000860) (fuzzy=False): sim=0
# Comparing 12_cd14.mono.2 (None) vs classical monocyte (CL:0000860) (fuzzy=False): sim=0
# Comparing 13_cd16.mono (None) vs non-classical monocyte (CL:0000875) (fuzzy=False): sim=0
# Comparing 14_unk (None) vs classical monocyte (CL:0000860) (fuzzy=False): sim=0
# Comparing 15_clp.2 (CL:0000051) vs pro-b cell (CL:0000826) (fuzzy=True): sim=0.7222222222222222
# Comparing 16_pre.b (None) vs small pre-b cell (CL:0002053) (fuzzy=False): sim=0
# Comparing 17_b (None) vs naive b cell (CL:0000788) (fuzzy=False): sim=0
# Comparing 18_plasma (None) vs plasma cell (CL:0000786) (fuzzy=False): sim=0
# Comparing 19_cd8.n (None) vs tcm/naive cytotoxic t cell (CL:0000000) (fuzzy=True): sim=0
# Comparing 20_cd4.n1 (None) vs tcm/naive helper t cell (CL:0000000) (fuzzy=True): sim=0
# Comparing 21_cd4.n2 (None) vs tcm/naive helper t cell (CL:0000000) (fuzzy=True): sim=0
# Comparing 22_cd4.m (None) vs tcm/naive helper t cell (CL:0000000) (fuzzy=True): sim=0
# Comparing 23_cd8.em (None) vs mait cell (CL:0000000) (fuzzy=True): sim=0
# Comparing 24_cd8.cm (None) vs tem/trm cytotoxic t cell (CL:0000000) (fuzzy=True): sim=0
# Comparing 25_nk (None) vs cd16+ nk cell (CL:0000000) (fuzzy=True): sim=0
# Comparing 26_unk (None) vs naive b cell (CL:0000788) (fuzzy=False): sim=0
#
# Processing: author_vs_Gemini2_5.csv
# Comparing 01_hsc (CL:0000037) vs leukemic blast (CL:4070012) (fuzzy=True): sim=0.3333333333333333
# Comparing 02_early.eryth (None) vs erythroid progenitor cell (CL:0000038) (fuzzy=False): sim=0
# Comparing 03_late.eryth (None) vs erythroid lineage cell (CL:0000764) (fuzzy=False): sim=0
# Comparing 04_early.baso (None) vs None (None) (fuzzy=False): sim=0
# Comparing 05_cmp.lmpp (CL:0001059) vs mixed-phenotype acute leukemia blast (CL:0000055) (fuzzy=True): sim=0.47058823529411764
# Comparing 06_clp.1 (CL:0000051) vs b-lymphoid progenitor (CL:0000050) (fuzzy=True): sim=0.8235294117647058
# Comparing 07_gmp (CL:0000557) vs myeloid blast (CL:0000835) (fuzzy=True): sim=0.56
# Comparing 08_gmp.neut,"mixed-phenotype acute leukemia blasts, b/myeloid" (None) vs None (None) (fuzzy=False): sim=0
# Comparing 09_pdc (CL:0000784) vs plasmacytoid dendritic cell (CL:0001058) (fuzzy=True): sim=0.9166666666666666
# Comparing 10_cdc (CL:0000990) vs None (None) (fuzzy=True): sim=0
# Comparing 11_cd14.mono.1 (None) vs None (None) (fuzzy=False): sim=0
# Comparing 12_cd14.mono.2 (None) vs monocyte (CL:0001054) (fuzzy=False): sim=0
# Comparing 13_cd16.mono (None) vs non-classical monocyte (CL:0000875) (fuzzy=False): sim=0
# Comparing 14_unk (None) vs monocyte (CL:0001054) (fuzzy=False): sim=0
# Comparing 15_clp.2 (CL:0000051) vs pre-b cell (CL:0000817) (fuzzy=True): sim=0.38461538461538464
# Comparing 16_pre.b (None) vs pre-b cell (CL:0000817) (fuzzy=False): sim=0
# Comparing 17_b (None) vs b cell (CL:0000236) (fuzzy=False): sim=0
# Comparing 18_plasma (None) vs None (None) (fuzzy=False): sim=0
# Comparing 19_cd8.n (None) vs cd8+ t cell (CL:0000917) (fuzzy=True): sim=0
# Comparing 20_cd4.n1 (None) vs t cell (CL:0000084) (fuzzy=False): sim=0
# Comparing 21_cd4.n2 (None) vs t cell (CL:0000084) (fuzzy=False): sim=0
# Comparing 22_cd4.m (None) vs t cell (CL:0000084) (fuzzy=False): sim=0
# Comparing 23_cd8.em (None) vs cytotoxic t lymphocyte (CL:0000910) (fuzzy=False): sim=0
# Comparing 24_cd8.cm (None) vs cd8+ t cell (CL:0000917) (fuzzy=True): sim=0
# Comparing 25_nk (None) vs natural killer cell (CL:0000623) (fuzzy=False): sim=0
# Comparing 26_unk (None) vs b-cell (CL:0000236) (fuzzy=False): sim=0
#
# Processing: author_vs_celltypist_Roy_Immune_All_Low_new.csv
# Comparing 01_hsc (CL:0000037) vs hsc/mpp (CL:0000037) (fuzzy=True): sim=1.0
# Comparing 02_early.eryth (None) vs memp (CL:0000050) (fuzzy=True): sim=0
# Comparing 03_late.eryth (None) vs mid erythroid (CL:0000038) (fuzzy=True): sim=0
# Comparing 04_early.baso (None) vs mast cell (CL:0000097) (fuzzy=False): sim=0
# Comparing 05_cmp.lmpp (CL:0001059) vs hsc/mpp (CL:0000037) (fuzzy=True): sim=0.6842105263157895
# Comparing 06_clp.1 (CL:0000051) vs pro-b cell (CL:0000826) (fuzzy=True): sim=0.7222222222222222
# Comparing 07_gmp (CL:0000557) vs classical monocyte (CL:0000860) (fuzzy=True): sim=0.3939393939393939
# Comparing 08_gmp.neut (CL:0000557) vs neutrophil-myeloid progenitor (CL:0000775) (fuzzy=True): sim=0.39285714285714285
# Comparing 09_pdc (CL:0000784) vs pdc (CL:0000784) (fuzzy=True): sim=1.0
# Comparing 10_cdc (CL:0000990) vs dc2 (CL:0000784) (fuzzy=True): sim=0.9130434782608695
# Comparing 11_cd14.mono.1 (None) vs classical monocyte (CL:0000860) (fuzzy=False): sim=0
# Comparing 12_cd14.mono.2 (None) vs classical monocyte (CL:0000860) (fuzzy=False): sim=0
# Comparing 13_cd16.mono (None) vs non-classical monocyte (CL:0000875) (fuzzy=False): sim=0
# Comparing 14_unk (None) vs classical monocyte (CL:0000860) (fuzzy=False): sim=0
# Comparing 15_clp.2 (CL:0000051) vs pro-b cell (CL:0000826) (fuzzy=True): sim=0.7222222222222222
# Comparing 16_pre.b (None) vs small pre-b cell (CL:0002053) (fuzzy=False): sim=0
# Comparing 17_b (None) vs naive b cell (CL:0000788) (fuzzy=False): sim=0
# Comparing 18_plasma (None) vs plasma cell (CL:0000786) (fuzzy=False): sim=0
# Comparing 19_cd8.n (None) vs tcm/naive cytotoxic t cell (CL:0000000) (fuzzy=True): sim=0
# Comparing 20_cd4.n1 (None) vs tcm/naive helper t cell (CL:0000000) (fuzzy=True): sim=0
# Comparing 21_cd4.n2 (None) vs tcm/naive helper t cell (CL:0000000) (fuzzy=True): sim=0
# Comparing 22_cd4.m (None) vs tcm/naive helper t cell (CL:0000000) (fuzzy=True): sim=0
# Comparing 23_cd8.em (None) vs mait cell (CL:0000000) (fuzzy=True): sim=0
# Comparing 24_cd8.cm (None) vs tem/trm cytotoxic t cell (CL:0000000) (fuzzy=True): sim=0
# Comparing 25_nk (None) vs cd16+ nk cell (CL:0000000) (fuzzy=True): sim=0
# Comparing 26_unk (None) vs naive b cell (CL:0000788) (fuzzy=False): sim=0
#
# Processing: author_vs_Grok3Beta.csv
# Comparing 01_hsc (CL:0000037) vs leukemic blast (CL:4070012) (fuzzy=True): sim=0.3333333333333333
# Comparing 02_early.eryth (None) vs hematopoietic progenitor-like leukemic blast (CL:0000037) (fuzzy=True): sim=0
# Comparing 03_late.eryth (None) vs erythroid progenitor (CL:0000038) (fuzzy=True): sim=0
# Comparing 04_early.baso (None) vs basophil (CL:0000767) (fuzzy=False): sim=0
# Comparing 05_cmp.lmpp (CL:0001059) vs myeloid leukemic blast (CL:0000055) (fuzzy=True): sim=0.47058823529411764
# Comparing 06_clp.1 (CL:0000051) vs b-cell precursor (CL:0000000) (fuzzy=True): sim=0.4666666666666667
# Comparing 07_gmp (CL:0000557) vs myeloid monocytic blast (CL:0000055) (fuzzy=True): sim=0.36363636363636365
# Comparing 08_gmp.neut (CL:0000557) vs myeloblast (CL:0000835) (fuzzy=True): sim=0.56
# Comparing 09_pdc (CL:0000784) vs plasmacytoid dendritic cell (CL:0001058) (fuzzy=True): sim=0.9166666666666666
# Comparing 10_cdc (CL:0000990) vs monocyte (CL:0001054) (fuzzy=True): sim=0.6785714285714286
# Comparing 11_cd14.mono.1 (None) vs monocyte (CL:0001054) (fuzzy=False): sim=0
# Comparing 12_cd14.mono.2 (None) vs monocyte (CL:0001054) (fuzzy=False): sim=0
# Comparing 13_cd16.mono (None) vs monocyte (CL:0001054) (fuzzy=False): sim=0
# Comparing 14_unk (None) vs monocyte (CL:0001054) (fuzzy=False): sim=0
# Comparing 15_clp.2 (CL:0000051) vs b-cell precursor (CL:0000000) (fuzzy=True): sim=0.4666666666666667
# Comparing 16_pre.b (None) vs b-cell lineage leukemic blast (CL:0000000) (fuzzy=True): sim=0
# Comparing 17_b (None) vs b cell (CL:0000236) (fuzzy=False): sim=0
# Comparing 18_plasma (None) vs plasma cell (CL:0000786) (fuzzy=False): sim=0
# Comparing 19_cd8.n (None) vs cd8-positive t cell (CL:0000917) (fuzzy=True): sim=0
# Comparing 20_cd4.n1 (None) vs t cell (CL:0000084) (fuzzy=False): sim=0
# Comparing 21_cd4.n2 (None) vs t cell (CL:0000084) (fuzzy=False): sim=0
# Comparing 22_cd4.m (None) vs t cell (CL:0000084) (fuzzy=False): sim=0
# Comparing 23_cd8.em (None) vs cytotoxic t cell (CL:0000910) (fuzzy=False): sim=0
# Comparing 24_cd8.cm (None) vs cytotoxic t cell (CL:0000910) (fuzzy=False): sim=0
# Comparing 25_nk (None) vs natural killer cell (CL:0000623) (fuzzy=False): sim=0
# Comparing 26_unk (None) vs b cell (CL:0000236) (fuzzy=False): sim=0
#
# Processing: author_vs_celltypist_Granja_Immune_All_High.csv
# Comparing 01_hsc (CL:0000037) vs hsc/mpp (CL:0000037) (fuzzy=True): sim=1.0
# Comparing 02_early.eryth (None) vs hsc/mpp (CL:0000037) (fuzzy=True): sim=0
# Comparing 03_late.eryth (None) vs erythroid (CL:0000038) (fuzzy=True): sim=0
# Comparing 04_early.baso (None) vs mast cell (CL:0000097) (fuzzy=False): sim=0
# Comparing 05_cmp.lmpp (CL:0001059) vs hsc/mpp (CL:0000037) (fuzzy=True): sim=0.6842105263157895
# Comparing 06_clp.1 (CL:0000051) vs b-cell lineage (CL:0000000) (fuzzy=True): sim=0.4666666666666667
# Comparing 07_gmp (CL:0000557) vs promyelocyte (CL:0000836) (fuzzy=True): sim=0.56
# Comparing 08_gmp.neut (CL:0000557) vs hsc/mpp (CL:0000037) (fuzzy=True): sim=0.5416666666666666
# Comparing 09_pdc (CL:0000784) vs pdc (CL:0000784) (fuzzy=True): sim=1.0
# Comparing 10_cdc (CL:0000990) vs dc (CL:0000782) (fuzzy=True): sim=0.88
# Comparing 11_cd14.mono.1 (None) vs monocyte (CL:0001054) (fuzzy=False): sim=0
# Comparing 12_cd14.mono.2 (None) vs monocyte (CL:0001054) (fuzzy=False): sim=0
# Comparing 13_cd16.mono (None) vs monocyte (CL:0001054) (fuzzy=False): sim=0
# Comparing 14_unk (None) vs monocyte (CL:0001054) (fuzzy=False): sim=0
# Comparing 15_clp.2 (CL:0000051) vs b-cell lineage (CL:0000000) (fuzzy=True): sim=0.4666666666666667
# Comparing 16_pre.b (None) vs b-cell lineage (CL:0000000) (fuzzy=True): sim=0
# Comparing 17_b (None) vs b cell (CL:0000236) (fuzzy=False): sim=0
# Comparing 18_plasma (None) vs plasma cell (CL:0000786) (fuzzy=False): sim=0
# Comparing 19_cd8.n (None) vs t cell (CL:0000084) (fuzzy=False): sim=0
# Comparing 20_cd4.n1 (None) vs t cell (CL:0000084) (fuzzy=False): sim=0
# Comparing 21_cd4.n2 (None) vs t cell (CL:0000084) (fuzzy=False): sim=0
# Comparing 22_cd4.m (None) vs t cell (CL:0000084) (fuzzy=False): sim=0
# Comparing 23_cd8.em (None) vs t cell (CL:0000084) (fuzzy=False): sim=0
# Comparing 24_cd8.cm (None) vs t cell (CL:0000084) (fuzzy=False): sim=0
# Comparing 25_nk (None) vs ilc (CL:0000453) (fuzzy=True): sim=0
# Comparing 26_unk (None) vs b cell (CL:0000236) (fuzzy=False): sim=0
#
# Processing: author_vs_celltypist_Granja_Immune_All_Low.csv
# Comparing 01_hsc (CL:0000037) vs hsc/mpp (CL:0000037) (fuzzy=True): sim=1.0
# Comparing 02_early.eryth (None) vs megakaryocyte precursor (CL:0000556) (fuzzy=True): sim=0
# Comparing 03_late.eryth (None) vs mid erythroid (CL:0000038) (fuzzy=True): sim=0
# Comparing 04_early.baso (None) vs mast cell (CL:0000097) (fuzzy=False): sim=0
# Comparing 05_cmp.lmpp (CL:0001059) vs hsc/mpp (CL:0000037) (fuzzy=True): sim=0.6842105263157895
# Comparing 06_clp.1 (CL:0000051) vs pro-b cell (CL:0000826) (fuzzy=True): sim=0.7222222222222222
# Comparing 07_gmp (CL:0000557) vs promyelocyte (CL:0000836) (fuzzy=True): sim=0.56
# Comparing 08_gmp.neut (CL:0000557) vs cmp (CL:0001059) (fuzzy=True): sim=0.6086956521739131
# Comparing 09_pdc (CL:0000784) vs pdc (CL:0000784) (fuzzy=True): sim=1.0
# Comparing 10_cdc (CL:0000990) vs dc2 (CL:0000784) (fuzzy=True): sim=0.9130434782608695
# Comparing 11_cd14.mono.1 (None) vs classical monocyte (CL:0000860) (fuzzy=False): sim=0
# Comparing 12_cd14.mono.2 (None) vs classical monocyte (CL:0000860) (fuzzy=False): sim=0
# Comparing 13_cd16.mono (None) vs non-classical monocyte (CL:0000875) (fuzzy=False): sim=0
# Comparing 14_unk (None) vs classical monocyte (CL:0000860) (fuzzy=False): sim=0
# Comparing 15_clp.2 (CL:0000051) vs pro-b cell (CL:0000826) (fuzzy=True): sim=0.7222222222222222
# Comparing 16_pre.b (None) vs small pre-b cell (CL:0002053) (fuzzy=False): sim=0
# Comparing 17_b (None) vs naive b cell (CL:0000788) (fuzzy=False): sim=0
# Comparing 18_plasma (None) vs plasma cell (CL:0000786) (fuzzy=False): sim=0
# Comparing 19_cd8.n (None) vs tcm/naive cytotoxic t cell (CL:0000000) (fuzzy=True): sim=0
# Comparing 20_cd4.n1 (None) vs tcm/naive helper t cell (CL:0000000) (fuzzy=True): sim=0
# Comparing 21_cd4.n2 (None) vs tcm/naive helper t cell (CL:0000000) (fuzzy=True): sim=0
# Comparing 22_cd4.m (None) vs tcm/naive helper t cell (CL:0000000) (fuzzy=True): sim=0
# Comparing 23_cd8.em (None) vs mait cell (CL:0000000) (fuzzy=True): sim=0
# Comparing 24_cd8.cm (None) vs tem/trm cytotoxic t cell (CL:0000000) (fuzzy=True): sim=0
# Comparing 25_nk (None) vs cd16+ nk cell (CL:0000000) (fuzzy=True): sim=0
# Comparing 26_unk (None) vs naive b cell (CL:0000788) (fuzzy=False): sim=0
#
# Processing: author_vs_gpt4_1.csv
# Comparing 01_hsc (CL:0000037) vs None (None) (fuzzy=True): sim=0
# Comparing 02_early.eryth (None) vs None (None) (fuzzy=False): sim=0
# Comparing 03_late.eryth (None) vs None (None) (fuzzy=False): sim=0
# Comparing 04_early.baso (None) vs None (None) (fuzzy=False): sim=0
# Comparing 05_cmp.lmpp (CL:0001059) vs None (None) (fuzzy=True): sim=0
# Comparing 06_clp.1 (CL:0000051) vs None (None) (fuzzy=True): sim=0
# Comparing 07_gmp (CL:0000557) vs None (None) (fuzzy=True): sim=0
# Comparing 08_gmp.neut (CL:0000557) vs None (None) (fuzzy=True): sim=0
# Comparing 09_pdc (CL:0000784) vs None (None) (fuzzy=True): sim=0
# Comparing 10_cdc (CL:0000990) vs None (None) (fuzzy=True): sim=0
# Comparing 11_cd14.mono.1 (None) vs None (None) (fuzzy=False): sim=0
# Comparing 12_cd14.mono.2 (None) vs classical monocyte (CL:0000860) (fuzzy=False): sim=0
# Comparing 13_cd16.mono (None) vs None (None) (fuzzy=False): sim=0
# Comparing 14_unk (None) vs classical monocyte (CL:0000860) (fuzzy=False): sim=0
# Comparing 15_clp.2 (CL:0000051) vs None (None) (fuzzy=True): sim=0
# Comparing 16_pre.b (None) vs None (None) (fuzzy=False): sim=0
# Comparing 17_b (None) vs None (None) (fuzzy=False): sim=0
# Comparing 18_plasma (None) vs None (None) (fuzzy=False): sim=0
# Comparing 19_cd8.n (None) vs None (None) (fuzzy=False): sim=0
# Comparing 20_cd4.n1 (None) vs None (None) (fuzzy=False): sim=0
# Comparing 21_cd4.n2 (None) vs None (None) (fuzzy=False): sim=0
# Comparing 22_cd4.m (None) vs None (None) (fuzzy=False): sim=0
# Comparing 23_cd8.em (None) vs None (None) (fuzzy=False): sim=0
# Comparing 24_cd8.cm (None) vs None (None) (fuzzy=False): sim=0
# Comparing 25_nk (None) vs None (None) (fuzzy=False): sim=0
# Comparing 26_unk (None) vs None (None) (fuzzy=False): sim=0
#
# Processing: author_vs_Llama4.csv
# Comparing 01_hsc (CL:0000037) vs immature hematopoietic cell (CL:0000000) (fuzzy=True): sim=0.4375
# Comparing 02_early.eryth (None) vs hematopoietic stem cell (CL:0000037) (fuzzy=False): sim=0
# Comparing 03_late.eryth (None) vs erythrocyte (CL:0000232) (fuzzy=False): sim=0
# Comparing 04_early.baso (None) vs myeloid cell (CL:0000763) (fuzzy=False): sim=0
# Comparing 05_cmp.lmpp (CL:0001059) vs b cell progenitor (CL:0000826) (fuzzy=True): sim=0.6842105263157895
# Comparing 06_clp.1 (CL:0000051) vs b cell (CL:0000236) (fuzzy=True): sim=0.43478260869565216
# Comparing 07_gmp (CL:0000557) vs dendritic cell (CL:0001056) (fuzzy=True): sim=0.30303030303030304
# Comparing 08_gmp.neut (CL:0000557) vs neutrophil (CL:0000775) (fuzzy=True): sim=0.39285714285714285
# Comparing 09_pdc (CL:0000784) vs b cell (CL:0000236) (fuzzy=True): sim=0.6
# Comparing 10_cdc (CL:0000990) vs None (None) (fuzzy=True): sim=0
# Comparing 11_cd14.mono.1 (None) vs monocyte (CL:0001054) (fuzzy=False): sim=0
# Comparing 12_cd14.mono.2 (None) vs myeloid cell (CL:0000763) (fuzzy=False): sim=0
# Comparing 13_cd16.mono (None) vs monocyte (CL:0001054) (fuzzy=False): sim=0
# Comparing 14_unk (None) vs t cell (CL:0000084) (fuzzy=False): sim=0
# Comparing 15_clp.2 (CL:0000051) vs b cell progenitor (CL:0000826) (fuzzy=True): sim=0.7222222222222222
# Comparing 16_pre.b (None) vs b cell (CL:0000236) (fuzzy=False): sim=0
# Comparing 17_b (None) vs b cell (CL:0000236) (fuzzy=False): sim=0
# Comparing 18_plasma (None) vs plasma b cell (CL:0000786) (fuzzy=False): sim=0
# Comparing 19_cd8.n (None) vs t cell (CL:0000084) (fuzzy=False): sim=0
# Comparing 20_cd4.n1 (None) vs t cell (CL:0000084) (fuzzy=False): sim=0
# Comparing 21_cd4.n2 (None) vs cd4-positive t cell (CL:0000492) (fuzzy=True): sim=0
# Comparing 22_cd4.m (None) vs t cell (CL:0000084) (fuzzy=False): sim=0
# Comparing 23_cd8.em (None) vs t cell (CL:0000084) (fuzzy=False): sim=0
# Comparing 24_cd8.cm (None) vs cytotoxic t cell (CL:0000910) (fuzzy=False): sim=0
# Comparing 25_nk (None) vs cd8-positive t cell (CL:0000917) (fuzzy=True): sim=0
# Comparing 26_unk (None) vs b cell (CL:0000236) (fuzzy=False): sim=0
#
# Processing: author_vs_Claude3_7Sonnet.csv
# Comparing 01_hsc (CL:0000037) vs hematopoietic stem and progenitor cell (CL:0011026) (fuzzy=True): sim=0.6875
# Comparing 02_early.eryth (None) vs hematopoietic stem and progenitor cell (CL:0011026) (fuzzy=True): sim=0
# Comparing 03_late.eryth (None) vs erythroid precursor (CL:0001066) (fuzzy=True): sim=0
# Comparing 04_early.baso (None) vs mast cell precursor (CL:0011115) (fuzzy=True): sim=0
# Comparing 05_cmp.lmpp (CL:0001059) vs hematopoietic stem and progenitor cell (CL:0011026) (fuzzy=True): sim=0.6875
# Comparing 06_clp.1 (CL:0000051) vs b-cell precursor (CL:0000000) (fuzzy=True): sim=0.4666666666666667
# Comparing 07_gmp (CL:0000557) vs myeloid progenitor cell (CL:0000839) (fuzzy=True): sim=0.5652173913043478
# Comparing 08_gmp.neut (CL:0000557) vs promyelocyte (CL:0000836) (fuzzy=True): sim=0.56
# Comparing 09_pdc (CL:0000784) vs plasmacytoid dendritic cell (CL:0001058) (fuzzy=True): sim=0.9166666666666666
# Comparing 10_cdc (CL:0000990) vs monocyte (CL:0001054) (fuzzy=True): sim=0.6785714285714286
# Comparing 11_cd14.mono.1 (None) vs neutrophil (CL:0000775) (fuzzy=False): sim=0
# Comparing 12_cd14.mono.2 (None) vs classical monocyte (CL:0000860) (fuzzy=False): sim=0
# Comparing 13_cd16.mono (None) vs non-classical monocyte (CL:0000875) (fuzzy=False): sim=0
# Comparing 14_unk (None) vs monocyte (CL:0001054) (fuzzy=False): sim=0
# Comparing 15_clp.2 (CL:0000051) vs b cell precursor (CL:0000817) (fuzzy=True): sim=0.38461538461538464
# Comparing 16_pre.b (None) vs pre-b cell (CL:0000817) (fuzzy=False): sim=0
# Comparing 17_b (None) vs b cell (CL:0000236) (fuzzy=False): sim=0
# Comparing 18_plasma (None) vs plasma cell (CL:0000786) (fuzzy=False): sim=0
# Comparing 19_cd8.n (None) vs cd8+ t cell (CL:0000917) (fuzzy=True): sim=0
# Comparing 20_cd4.n1 (None) vs cd4+ t cell (CL:0000545) (fuzzy=True): sim=0
# Comparing 21_cd4.n2 (None) vs cd4+ t cell (CL:0000545) (fuzzy=True): sim=0
# Comparing 22_cd4.m (None) vs t cell (CL:0000084) (fuzzy=False): sim=0
# Comparing 23_cd8.em (None) vs cd8+ t cell (CL:0000917) (fuzzy=True): sim=0
# Comparing 24_cd8.cm (None) vs cd8+ t cell (CL:0000917) (fuzzy=True): sim=0
# Comparing 25_nk (None) vs natural killer cell (CL:0000623) (fuzzy=False): sim=0
# Comparing 26_unk (None) vs b cell (CL:0000236) (fuzzy=False): sim=0
#
# Processing: author_vs_gpt4_1mini.csv
# Comparing 01_hsc (CL:0000037) vs hematopoietic stem and progenitor cell (CL:0011026) (fuzzy=True): sim=0.6875
# Comparing 02_early.eryth (None) vs mpal blast with early hematopoietic progenitor phenotype (CL:0000007) (fuzzy=True): sim=0
# Comparing 03_late.eryth (None) vs erythroid progenitor cell (CL:0000038) (fuzzy=False): sim=0
# Comparing 04_early.baso (None) vs None (None) (fuzzy=False): sim=0
# Comparing 05_cmp.lmpp (CL:0001059) vs None (None) (fuzzy=True): sim=0
# Comparing 06_clp.1 (CL:0000051) vs None (None) (fuzzy=True): sim=0
# Comparing 07_gmp (CL:0000557) vs None (None) (fuzzy=True): sim=0
# Comparing 08_gmp.neut (CL:0000557) vs None (None) (fuzzy=True): sim=0
# Comparing 09_pdc (CL:0000784) vs None (None) (fuzzy=True): sim=0
# Comparing 10_cdc (CL:0000990) vs monocyte / macrophage (CL:0000394) (fuzzy=True): sim=0.38461538461538464
# Comparing 11_cd14.mono.1 (None) vs monocyte (CL:0001054) (fuzzy=False): sim=0
# Comparing 12_cd14.mono.2 (None) vs monocyte (CL:0001054) (fuzzy=False): sim=0
# Comparing 13_cd16.mono (None) vs monocyte (CL:0001054) (fuzzy=False): sim=0
# Comparing 14_unk (None) vs monocyte/macrophage (CL:0000394) (fuzzy=True): sim=0
# Comparing 15_clp.2 (CL:0000051) vs b cell progenitor (CL:0000826) (fuzzy=True): sim=0.7222222222222222
# Comparing 16_pre.b (None) vs b cell (CL:0000236) (fuzzy=False): sim=0
# Comparing 17_b (None) vs b cell (CL:0000236) (fuzzy=False): sim=0
# Comparing 18_plasma (None) vs plasma cell (CL:0000786) (fuzzy=False): sim=0
# Comparing 19_cd8.n (None) vs cd8-positive t cell (CL:0000917) (fuzzy=True): sim=0
# Comparing 20_cd4.n1 (None) vs t lymphocyte (CL:0000084) (fuzzy=False): sim=0
# Comparing 21_cd4.n2 (None) vs t cell (CL:0000084) (fuzzy=False): sim=0
# Comparing 22_cd4.m (None) vs t cell (CL:0000084) (fuzzy=False): sim=0
# Comparing 23_cd8.em (None) vs cytotoxic t cell (CL:0000910) (fuzzy=False): sim=0
# Comparing 24_cd8.cm (None) vs cytotoxic cd8-positive t cell (CL:0000000) (fuzzy=True): sim=0
# Comparing 25_nk (None) vs None (None) (fuzzy=False): sim=0
# Comparing 26_unk (None) vs b cell (CL:0000236) (fuzzy=False): sim=0
