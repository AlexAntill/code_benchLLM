# %% [markdown]
# # Cell Ontology Similarity from CSV
# A notebook that assesses cell similarities from a .csv containing two congruent columns of cell types. Jaccard similarity is calculated using Owlready.
# <br> <b/> N.B. </b> For cell ontology labelling from general sources utilise the upper cell and for cell ontology labelling from CellTypist labelled data use the lower cell. Automatic choice based on file name are the bottom cells.
# <br> <b/> N.B. </b> CellTypist granularity (low and high immune reference) can be changed affceting similarity.

# %%
import pandas as pd
import numpy as np
import os
import glob
import re
from rapidfuzz import process
from owlready2 import get_ontology

# %% [markdown]
# In mapping refernece choose which 'label_to_id_2' depending on cell typist granularity

# %%
## Load Datasets and Mapping Reference (Text to Cell Ontology ID)
# Base Directory of Dataset
base_dir = os.path.expanduser("~/Göran_Karlsson_Lab/benchLLM/Granja_et_al")
input_pattern = os.path.join(base_dir, "author_vs_*.csv")
input_pattern_cellTypist = os.path.join(base_dir, "author_vs_celltypist_*.csv")

## Mapping Reference 
# General 
mapping_df = pd.read_csv(os.path.expanduser("~/Göran_Karlsson_Lab/benchLLM/cell_to_cell_ontology.csv"))
label_to_id = dict(zip(mapping_df['label'], mapping_df['ontology_id']))
label_to_id_ci = {k.lower(): v for k, v in label_to_id.items()} # Remove Case Sentivity

# CellTypist (Switch 'label_to_id_2' Depending on Granularity of CellTypist Annotation)
mapping_df_2 = pd.read_csv(os.path.expanduser("~/Göran_Karlsson_Lab/benchLLM/CellTypist_to_Cell_Ontology.csv"))
#label_to_id_2 = dict(zip(mapping_df_2['Low-hierarchy cell types'], mapping_df_2['Cell Ontology ID'])) # High Granularity
label_to_id_2 = (mapping_df_2
    .groupby('High-hierarchy cell types')['Cell Ontology ID']
    .apply(set)
    .to_dict()
) # Low Granularity
label_to_id_ci_2 = {k.lower(): v for k, v in label_to_id_2.items()}

# %%
# Load Cell Ontology Map (OWL)
print("Loading Cell Ontology (OWL)...")
G = get_ontology("http://purl.obolibrary.org/obo/cl.owl").load()
print("Ontology loaded.")
# Out:
# Loading Cell Ontology (OWL)...
# Ontology loaded.

# %% [markdown]
# General Purpose Cell Ontology Based Similarity

# %%
def get_ancestors(cls):
    return set(cls.ancestors()) if cls else set()

def compute_similarity(id1, id2, onto):
    if id1 is None or id2 is None:
        return 0

    class1 = onto.search_one(iri="*" + id1.replace(":", "_")) # Convert ID1 to be Compatible with OWL
    class2 = onto.search_one(iri="*" + id2.replace(":", "_")) # Convert ID2 to be Compatible with OWL

    if not class1 or not class2:
        return 0

    ancestors1 = get_ancestors(class1)
    ancestors2 = get_ancestors(class2)

    intersection = ancestors1 & ancestors2
    union = ancestors1 | ancestors2

    if not union:
        return 0

    return len(intersection) / len(union)  # Jaccard Similarity

def normalize_label(label):
    label = str(label).lower().strip() # Remove Case Sensitivity
    label = re.sub(r'\s*\(.*?\)', '', label)  # Remove Special Characters
    if label.endswith('s') and len(label) > 1:
        label = label[:-1]
    return label # Remove Plural

def fuzzy_match_label(label, choices, threshold=80):
    if label is None:
        return None
    result = process.extractOne(label, choices)
    if result is None:
        return None
    if len(result) == 2:
        match, score = result
    elif len(result) == 3:
        # Sometimes it returns (match, score, index)
        match, score, _ = result
    else:
        return None
    if score >= threshold:
        return match
    return None # Use Fuzzy Match if Exact Match is Null


for file_path in glob.glob(input_pattern):
    if '_similarity' in os.path.basename(file_path) or '_celltypist_' in os.path.basename(file_path):
        continue

    print(f"\nProcessing: {os.path.basename(file_path)}")
    df = pd.read_csv(file_path)

    colnames = df.columns.tolist()
    if len(colnames) < 2:
        print(f"  Skipping {file_path} — not enough columns.")
        continue

    author_col = colnames[0]
    llm_col = colnames[1]

    similarity_scores = []
    for _, row in df.iterrows():
        author_label = normalize_label(row[author_col])
        llm_label = normalize_label(row[llm_col])

        if author_label in ["nan", "none"] or pd.isna(author_label):
            author_label = None
        if llm_label in ["nan", "none"] or pd.isna(llm_label):
            llm_label = None

        fuzzy_used_author = False
        fuzzy_used_llm = False

        id1 = label_to_id_ci.get(author_label) if author_label else None
        id2 = label_to_id_ci.get(llm_label) if llm_label else None

        if id1 is None and author_label is not None:
            matched_label = fuzzy_match_label(author_label, label_to_id_ci.keys())
            if matched_label:
                fuzzy_used_author = True
            id1 = label_to_id_ci.get(matched_label)

        if id2 is None and llm_label is not None:
            matched_label = fuzzy_match_label(llm_label, label_to_id_ci.keys())
            if matched_label:
                fuzzy_used_llm = True
            id2 = label_to_id_ci.get(matched_label)

        sim = compute_similarity(id1, id2, G)
        print(f"Comparing {author_label} ({id1}) vs {llm_label} ({id2}) (fuzzy author ={fuzzy_used_author} and fuzzy llm ={fuzzy_used_llm}): sim={sim}")
        similarity_scores.append(sim)


    df['similarity_score'] = similarity_scores

    #out_path = file_path.replace(".csv", "_similarity.csv")
    #df.to_csv(out_path, index=False)
    #print(f"  Saved: {os.path.basename(out_path)}")
# Out:
# Processing: author_vs_Gemini2_5.csv
# Comparing 01_hsc (CL:0000037) vs leukemic blast (CL:4070012) (fuzzy author =True and fuzzy llm =True): sim=0.3333333333333333
# Comparing 02_early.eryth (None) vs erythroid progenitor cell (CL:0000038) (fuzzy author =False and fuzzy llm =False): sim=0
# Comparing 03_late.eryth (None) vs erythroid lineage cell (CL:0000764) (fuzzy author =False and fuzzy llm =False): sim=0
# Comparing 04_early.baso (None) vs None (None) (fuzzy author =False and fuzzy llm =False): sim=0
# Comparing 05_cmp.lmpp (CL:0001059) vs mixed-phenotype acute leukemia blast (CL:0000055) (fuzzy author =True and fuzzy llm =True): sim=0.47058823529411764
# Comparing 06_clp.1 (CL:0000051) vs b-lymphoid progenitor (CL:0000050) (fuzzy author =True and fuzzy llm =True): sim=0.8235294117647058
# Comparing 07_gmp (CL:0000557) vs myeloid blast (CL:0000835) (fuzzy author =True and fuzzy llm =True): sim=0.56
# Comparing 08_gmp.neut,"mixed-phenotype acute leukemia blasts, b/myeloid" (None) vs None (None) (fuzzy author =False and fuzzy llm =False): sim=0
# Comparing 09_pdc (CL:0000784) vs plasmacytoid dendritic cell (CL:0001058) (fuzzy author =True and fuzzy llm =False): sim=0.9166666666666666
# Comparing 10_cdc (CL:0000990) vs None (None) (fuzzy author =True and fuzzy llm =False): sim=0
# Comparing 11_cd14.mono.1 (None) vs None (None) (fuzzy author =False and fuzzy llm =False): sim=0
# Comparing 12_cd14.mono.2 (None) vs monocyte (CL:0001054) (fuzzy author =False and fuzzy llm =False): sim=0
# Comparing 13_cd16.mono (None) vs non-classical monocyte (CL:0000875) (fuzzy author =False and fuzzy llm =False): sim=0
# Comparing 14_unk (None) vs monocyte (CL:0001054) (fuzzy author =False and fuzzy llm =False): sim=0
# Comparing 15_clp.2 (CL:0000051) vs pre-b cell (CL:0000817) (fuzzy author =True and fuzzy llm =False): sim=0.38461538461538464
# Comparing 16_pre.b (None) vs pre-b cell (CL:0000817) (fuzzy author =False and fuzzy llm =False): sim=0
# Comparing 17_b (None) vs b cell (CL:0000236) (fuzzy author =False and fuzzy llm =False): sim=0
# Comparing 18_plasma (None) vs None (None) (fuzzy author =False and fuzzy llm =False): sim=0
# Comparing 19_cd8.n (None) vs cd8+ t cell (CL:0000917) (fuzzy author =False and fuzzy llm =True): sim=0
# Comparing 20_cd4.n1 (None) vs t cell (CL:0000084) (fuzzy author =False and fuzzy llm =False): sim=0
# Comparing 21_cd4.n2 (None) vs t cell (CL:0000084) (fuzzy author =False and fuzzy llm =False): sim=0
# Comparing 22_cd4.m (None) vs t cell (CL:0000084) (fuzzy author =False and fuzzy llm =False): sim=0
# Comparing 23_cd8.em (None) vs cytotoxic t lymphocyte (CL:0000910) (fuzzy author =False and fuzzy llm =False): sim=0
# Comparing 24_cd8.cm (None) vs cd8+ t cell (CL:0000917) (fuzzy author =False and fuzzy llm =True): sim=0
# Comparing 25_nk (None) vs natural killer cell (CL:0000623) (fuzzy author =False and fuzzy llm =False): sim=0
# Comparing 26_unk (None) vs b-cell (CL:0000236) (fuzzy author =False and fuzzy llm =False): sim=0
#
# Processing: author_vs_Grok3Beta.csv
# Comparing 01_hsc (CL:0000037) vs leukemic blast (CL:4070012) (fuzzy author =True and fuzzy llm =True): sim=0.3333333333333333
# Comparing 02_early.eryth (None) vs hematopoietic progenitor-like leukemic blast (CL:0000037) (fuzzy author =False and fuzzy llm =True): sim=0
# Comparing 03_late.eryth (None) vs erythroid progenitor (CL:0000038) (fuzzy author =False and fuzzy llm =True): sim=0
# Comparing 04_early.baso (None) vs basophil (CL:0000767) (fuzzy author =False and fuzzy llm =False): sim=0
# Comparing 05_cmp.lmpp (CL:0001059) vs myeloid leukemic blast (CL:0000055) (fuzzy author =True and fuzzy llm =True): sim=0.47058823529411764
# Comparing 06_clp.1 (CL:0000051) vs b-cell precursor (CL:0000000) (fuzzy author =True and fuzzy llm =True): sim=0.4666666666666667
# Comparing 07_gmp (CL:0000557) vs myeloid monocytic blast (CL:0000055) (fuzzy author =True and fuzzy llm =True): sim=0.36363636363636365
# Comparing 08_gmp.neut (CL:0000557) vs myeloblast (CL:0000835) (fuzzy author =True and fuzzy llm =False): sim=0.56
# Comparing 09_pdc (CL:0000784) vs plasmacytoid dendritic cell (CL:0001058) (fuzzy author =True and fuzzy llm =False): sim=0.9166666666666666
# Comparing 10_cdc (CL:0000990) vs monocyte (CL:0001054) (fuzzy author =True and fuzzy llm =False): sim=0.6785714285714286
# Comparing 11_cd14.mono.1 (None) vs monocyte (CL:0001054) (fuzzy author =False and fuzzy llm =False): sim=0
# Comparing 12_cd14.mono.2 (None) vs monocyte (CL:0001054) (fuzzy author =False and fuzzy llm =False): sim=0
# Comparing 13_cd16.mono (None) vs monocyte (CL:0001054) (fuzzy author =False and fuzzy llm =False): sim=0
# Comparing 14_unk (None) vs monocyte (CL:0001054) (fuzzy author =False and fuzzy llm =False): sim=0
# Comparing 15_clp.2 (CL:0000051) vs b-cell precursor (CL:0000000) (fuzzy author =True and fuzzy llm =True): sim=0.4666666666666667
# Comparing 16_pre.b (None) vs b-cell lineage leukemic blast (CL:0000000) (fuzzy author =False and fuzzy llm =True): sim=0
# Comparing 17_b (None) vs b cell (CL:0000236) (fuzzy author =False and fuzzy llm =False): sim=0
# Comparing 18_plasma (None) vs plasma cell (CL:0000786) (fuzzy author =False and fuzzy llm =False): sim=0
# Comparing 19_cd8.n (None) vs cd8-positive t cell (CL:0000917) (fuzzy author =False and fuzzy llm =True): sim=0
# Comparing 20_cd4.n1 (None) vs t cell (CL:0000084) (fuzzy author =False and fuzzy llm =False): sim=0
# Comparing 21_cd4.n2 (None) vs t cell (CL:0000084) (fuzzy author =False and fuzzy llm =False): sim=0
# Comparing 22_cd4.m (None) vs t cell (CL:0000084) (fuzzy author =False and fuzzy llm =False): sim=0
# Comparing 23_cd8.em (None) vs cytotoxic t cell (CL:0000910) (fuzzy author =False and fuzzy llm =False): sim=0
# Comparing 24_cd8.cm (None) vs cytotoxic t cell (CL:0000910) (fuzzy author =False and fuzzy llm =False): sim=0
# Comparing 25_nk (None) vs natural killer cell (CL:0000623) (fuzzy author =False and fuzzy llm =False): sim=0
# Comparing 26_unk (None) vs b cell (CL:0000236) (fuzzy author =False and fuzzy llm =False): sim=0
#
# Processing: author_vs_gpt4_1.csv
# Comparing 01_hsc (CL:0000037) vs None (None) (fuzzy author =True and fuzzy llm =False): sim=0
# Comparing 02_early.eryth (None) vs None (None) (fuzzy author =False and fuzzy llm =False): sim=0
# Comparing 03_late.eryth (None) vs None (None) (fuzzy author =False and fuzzy llm =False): sim=0
# Comparing 04_early.baso (None) vs None (None) (fuzzy author =False and fuzzy llm =False): sim=0
# Comparing 05_cmp.lmpp (CL:0001059) vs None (None) (fuzzy author =True and fuzzy llm =False): sim=0
# Comparing 06_clp.1 (CL:0000051) vs None (None) (fuzzy author =True and fuzzy llm =False): sim=0
# Comparing 07_gmp (CL:0000557) vs None (None) (fuzzy author =True and fuzzy llm =False): sim=0
# Comparing 08_gmp.neut (CL:0000557) vs None (None) (fuzzy author =True and fuzzy llm =False): sim=0
# Comparing 09_pdc (CL:0000784) vs None (None) (fuzzy author =True and fuzzy llm =False): sim=0
# Comparing 10_cdc (CL:0000990) vs None (None) (fuzzy author =True and fuzzy llm =False): sim=0
# Comparing 11_cd14.mono.1 (None) vs None (None) (fuzzy author =False and fuzzy llm =False): sim=0
# Comparing 12_cd14.mono.2 (None) vs classical monocyte (CL:0000860) (fuzzy author =False and fuzzy llm =False): sim=0
# Comparing 13_cd16.mono (None) vs None (None) (fuzzy author =False and fuzzy llm =False): sim=0
# Comparing 14_unk (None) vs classical monocyte (CL:0000860) (fuzzy author =False and fuzzy llm =False): sim=0
# Comparing 15_clp.2 (CL:0000051) vs None (None) (fuzzy author =True and fuzzy llm =False): sim=0
# Comparing 16_pre.b (None) vs None (None) (fuzzy author =False and fuzzy llm =False): sim=0
# Comparing 17_b (None) vs None (None) (fuzzy author =False and fuzzy llm =False): sim=0
# Comparing 18_plasma (None) vs None (None) (fuzzy author =False and fuzzy llm =False): sim=0
# Comparing 19_cd8.n (None) vs None (None) (fuzzy author =False and fuzzy llm =False): sim=0
# Comparing 20_cd4.n1 (None) vs None (None) (fuzzy author =False and fuzzy llm =False): sim=0
# Comparing 21_cd4.n2 (None) vs None (None) (fuzzy author =False and fuzzy llm =False): sim=0
# Comparing 22_cd4.m (None) vs None (None) (fuzzy author =False and fuzzy llm =False): sim=0
# Comparing 23_cd8.em (None) vs None (None) (fuzzy author =False and fuzzy llm =False): sim=0
# Comparing 24_cd8.cm (None) vs None (None) (fuzzy author =False and fuzzy llm =False): sim=0
# Comparing 25_nk (None) vs None (None) (fuzzy author =False and fuzzy llm =False): sim=0
# Comparing 26_unk (None) vs None (None) (fuzzy author =False and fuzzy llm =False): sim=0
#
# Processing: author_vs_Llama4.csv
# Comparing 01_hsc (CL:0000037) vs immature hematopoietic cell (CL:0000000) (fuzzy author =True and fuzzy llm =True): sim=0.4375
# Comparing 02_early.eryth (None) vs hematopoietic stem cell (CL:0000037) (fuzzy author =False and fuzzy llm =False): sim=0
# Comparing 03_late.eryth (None) vs erythrocyte (CL:0000232) (fuzzy author =False and fuzzy llm =False): sim=0
# Comparing 04_early.baso (None) vs myeloid cell (CL:0000763) (fuzzy author =False and fuzzy llm =False): sim=0
# Comparing 05_cmp.lmpp (CL:0001059) vs b cell progenitor (CL:0000826) (fuzzy author =True and fuzzy llm =True): sim=0.6842105263157895
# Comparing 06_clp.1 (CL:0000051) vs b cell (CL:0000236) (fuzzy author =True and fuzzy llm =False): sim=0.43478260869565216
# Comparing 07_gmp (CL:0000557) vs dendritic cell (CL:0001056) (fuzzy author =True and fuzzy llm =False): sim=0.30303030303030304
# Comparing 08_gmp.neut (CL:0000557) vs neutrophil (CL:0000775) (fuzzy author =True and fuzzy llm =False): sim=0.39285714285714285
# Comparing 09_pdc (CL:0000784) vs b cell (CL:0000236) (fuzzy author =True and fuzzy llm =False): sim=0.6
# Comparing 10_cdc (CL:0000990) vs None (None) (fuzzy author =True and fuzzy llm =False): sim=0
# Comparing 11_cd14.mono.1 (None) vs monocyte (CL:0001054) (fuzzy author =False and fuzzy llm =False): sim=0
# Comparing 12_cd14.mono.2 (None) vs myeloid cell (CL:0000763) (fuzzy author =False and fuzzy llm =False): sim=0
# Comparing 13_cd16.mono (None) vs monocyte (CL:0001054) (fuzzy author =False and fuzzy llm =False): sim=0
# Comparing 14_unk (None) vs t cell (CL:0000084) (fuzzy author =False and fuzzy llm =False): sim=0
# Comparing 15_clp.2 (CL:0000051) vs b cell progenitor (CL:0000826) (fuzzy author =True and fuzzy llm =True): sim=0.7222222222222222
# Comparing 16_pre.b (None) vs b cell (CL:0000236) (fuzzy author =False and fuzzy llm =False): sim=0
# Comparing 17_b (None) vs b cell (CL:0000236) (fuzzy author =False and fuzzy llm =False): sim=0
# Comparing 18_plasma (None) vs plasma b cell (CL:0000786) (fuzzy author =False and fuzzy llm =False): sim=0
# Comparing 19_cd8.n (None) vs t cell (CL:0000084) (fuzzy author =False and fuzzy llm =False): sim=0
# Comparing 20_cd4.n1 (None) vs t cell (CL:0000084) (fuzzy author =False and fuzzy llm =False): sim=0
# Comparing 21_cd4.n2 (None) vs cd4-positive t cell (CL:0000492) (fuzzy author =False and fuzzy llm =True): sim=0
# Comparing 22_cd4.m (None) vs t cell (CL:0000084) (fuzzy author =False and fuzzy llm =False): sim=0
# Comparing 23_cd8.em (None) vs t cell (CL:0000084) (fuzzy author =False and fuzzy llm =False): sim=0
# Comparing 24_cd8.cm (None) vs cytotoxic t cell (CL:0000910) (fuzzy author =False and fuzzy llm =False): sim=0
# Comparing 25_nk (None) vs cd8-positive t cell (CL:0000917) (fuzzy author =False and fuzzy llm =True): sim=0
# Comparing 26_unk (None) vs b cell (CL:0000236) (fuzzy author =False and fuzzy llm =False): sim=0
#
# Processing: author_vs_Claude3_7Sonnet.csv
# Comparing 01_hsc (CL:0000037) vs hematopoietic stem and progenitor cell (CL:0011026) (fuzzy author =True and fuzzy llm =True): sim=0.6875
# Comparing 02_early.eryth (None) vs hematopoietic stem and progenitor cell (CL:0011026) (fuzzy author =False and fuzzy llm =True): sim=0
# Comparing 03_late.eryth (None) vs erythroid precursor (CL:0001066) (fuzzy author =False and fuzzy llm =True): sim=0
# Comparing 04_early.baso (None) vs mast cell precursor (CL:0011115) (fuzzy author =False and fuzzy llm =True): sim=0
# Comparing 05_cmp.lmpp (CL:0001059) vs hematopoietic stem and progenitor cell (CL:0011026) (fuzzy author =True and fuzzy llm =True): sim=0.6875
# Comparing 06_clp.1 (CL:0000051) vs b-cell precursor (CL:0000000) (fuzzy author =True and fuzzy llm =True): sim=0.4666666666666667
# Comparing 07_gmp (CL:0000557) vs myeloid progenitor cell (CL:0000839) (fuzzy author =True and fuzzy llm =False): sim=0.5652173913043478
# Comparing 08_gmp.neut (CL:0000557) vs promyelocyte (CL:0000836) (fuzzy author =True and fuzzy llm =False): sim=0.56
# Comparing 09_pdc (CL:0000784) vs plasmacytoid dendritic cell (CL:0001058) (fuzzy author =True and fuzzy llm =False): sim=0.9166666666666666
# Comparing 10_cdc (CL:0000990) vs monocyte (CL:0001054) (fuzzy author =True and fuzzy llm =False): sim=0.6785714285714286
# Comparing 11_cd14.mono.1 (None) vs neutrophil (CL:0000775) (fuzzy author =False and fuzzy llm =False): sim=0
# Comparing 12_cd14.mono.2 (None) vs classical monocyte (CL:0000860) (fuzzy author =False and fuzzy llm =False): sim=0
# Comparing 13_cd16.mono (None) vs non-classical monocyte (CL:0000875) (fuzzy author =False and fuzzy llm =False): sim=0
# Comparing 14_unk (None) vs monocyte (CL:0001054) (fuzzy author =False and fuzzy llm =False): sim=0
# Comparing 15_clp.2 (CL:0000051) vs b cell precursor (CL:0000817) (fuzzy author =True and fuzzy llm =True): sim=0.38461538461538464
# Comparing 16_pre.b (None) vs pre-b cell (CL:0000817) (fuzzy author =False and fuzzy llm =False): sim=0
# Comparing 17_b (None) vs b cell (CL:0000236) (fuzzy author =False and fuzzy llm =False): sim=0
# Comparing 18_plasma (None) vs plasma cell (CL:0000786) (fuzzy author =False and fuzzy llm =False): sim=0
# Comparing 19_cd8.n (None) vs cd8+ t cell (CL:0000917) (fuzzy author =False and fuzzy llm =True): sim=0
# Comparing 20_cd4.n1 (None) vs cd4+ t cell (CL:0000545) (fuzzy author =False and fuzzy llm =True): sim=0
# Comparing 21_cd4.n2 (None) vs cd4+ t cell (CL:0000545) (fuzzy author =False and fuzzy llm =True): sim=0
# Comparing 22_cd4.m (None) vs t cell (CL:0000084) (fuzzy author =False and fuzzy llm =False): sim=0
# Comparing 23_cd8.em (None) vs cd8+ t cell (CL:0000917) (fuzzy author =False and fuzzy llm =True): sim=0
# Comparing 24_cd8.cm (None) vs cd8+ t cell (CL:0000917) (fuzzy author =False and fuzzy llm =True): sim=0
# Comparing 25_nk (None) vs natural killer cell (CL:0000623) (fuzzy author =False and fuzzy llm =False): sim=0
# Comparing 26_unk (None) vs b cell (CL:0000236) (fuzzy author =False and fuzzy llm =False): sim=0
#
# Processing: author_vs_gpt4_1mini.csv
# Comparing 01_hsc (CL:0000037) vs hematopoietic stem and progenitor cell (CL:0011026) (fuzzy author =True and fuzzy llm =True): sim=0.6875
# Comparing 02_early.eryth (None) vs mpal blast with early hematopoietic progenitor phenotype (CL:0000007) (fuzzy author =False and fuzzy llm =True): sim=0
# Comparing 03_late.eryth (None) vs erythroid progenitor cell (CL:0000038) (fuzzy author =False and fuzzy llm =False): sim=0
# Comparing 04_early.baso (None) vs None (None) (fuzzy author =False and fuzzy llm =False): sim=0
# Comparing 05_cmp.lmpp (CL:0001059) vs None (None) (fuzzy author =True and fuzzy llm =False): sim=0
# Comparing 06_clp.1 (CL:0000051) vs None (None) (fuzzy author =True and fuzzy llm =False): sim=0
# Comparing 07_gmp (CL:0000557) vs None (None) (fuzzy author =True and fuzzy llm =False): sim=0
# Comparing 08_gmp.neut (CL:0000557) vs None (None) (fuzzy author =True and fuzzy llm =False): sim=0
# Comparing 09_pdc (CL:0000784) vs None (None) (fuzzy author =True and fuzzy llm =False): sim=0
# Comparing 10_cdc (CL:0000990) vs monocyte / macrophage (CL:0000394) (fuzzy author =True and fuzzy llm =True): sim=0.38461538461538464
# Comparing 11_cd14.mono.1 (None) vs monocyte (CL:0001054) (fuzzy author =False and fuzzy llm =False): sim=0
# Comparing 12_cd14.mono.2 (None) vs monocyte (CL:0001054) (fuzzy author =False and fuzzy llm =False): sim=0
# Comparing 13_cd16.mono (None) vs monocyte (CL:0001054) (fuzzy author =False and fuzzy llm =False): sim=0
# Comparing 14_unk (None) vs monocyte/macrophage (CL:0000394) (fuzzy author =False and fuzzy llm =True): sim=0
# Comparing 15_clp.2 (CL:0000051) vs b cell progenitor (CL:0000826) (fuzzy author =True and fuzzy llm =True): sim=0.7222222222222222
# Comparing 16_pre.b (None) vs b cell (CL:0000236) (fuzzy author =False and fuzzy llm =False): sim=0
# Comparing 17_b (None) vs b cell (CL:0000236) (fuzzy author =False and fuzzy llm =False): sim=0
# Comparing 18_plasma (None) vs plasma cell (CL:0000786) (fuzzy author =False and fuzzy llm =False): sim=0
# Comparing 19_cd8.n (None) vs cd8-positive t cell (CL:0000917) (fuzzy author =False and fuzzy llm =True): sim=0
# Comparing 20_cd4.n1 (None) vs t lymphocyte (CL:0000084) (fuzzy author =False and fuzzy llm =False): sim=0
# Comparing 21_cd4.n2 (None) vs t cell (CL:0000084) (fuzzy author =False and fuzzy llm =False): sim=0
# Comparing 22_cd4.m (None) vs t cell (CL:0000084) (fuzzy author =False and fuzzy llm =False): sim=0
# Comparing 23_cd8.em (None) vs cytotoxic t cell (CL:0000910) (fuzzy author =False and fuzzy llm =False): sim=0
# Comparing 24_cd8.cm (None) vs cytotoxic cd8-positive t cell (CL:0000000) (fuzzy author =False and fuzzy llm =True): sim=0
# Comparing 25_nk (None) vs None (None) (fuzzy author =False and fuzzy llm =False): sim=0
# Comparing 26_unk (None) vs b cell (CL:0000236) (fuzzy author =False and fuzzy llm =False): sim=0
#
# Processing: author_vs_Gemini2_5_Acc_Exp.csv
# Comparing hematopoietic stem cell (CL:0000037) vs leukemic blast (CL:4070012) (fuzzy author =False and fuzzy llm =True): sim=0.3333333333333333
# Comparing early erythroid cell (CL:0000000) vs erythroid progenitor cell (CL:0000038) (fuzzy author =True and fuzzy llm =False): sim=0.3888888888888889
# Comparing late erythroid cell (CL:0000000) vs erythroid lineage cell (CL:0000764) (fuzzy author =True and fuzzy llm =False): sim=0.5833333333333334
# Comparing early basophil cell (CL:0000000) vs None (None) (fuzzy author =True and fuzzy llm =False): sim=0
# Comparing common myeloid progenitor / lymphoid-primed multipotent progenitor (CL:0000049) vs mixed-phenotype acute leukemia blast (CL:0000055) (fuzzy author =True and fuzzy llm =True): sim=0.4666666666666667
# Comparing common lymphoid progenitor (CL:0000051) vs b-lymphoid progenitor (CL:0000050) (fuzzy author =False and fuzzy llm =True): sim=0.8235294117647058
# Comparing granulocyte-monocyte progenitor (CL:0000557) vs myeloid blast (CL:0000835) (fuzzy author =True and fuzzy llm =True): sim=0.56
# Comparing granulocyte-monocyte progenitors / neutrophil,"mixed-phenotype acute leukemia blasts, b/myeloid" (CL:0000557) vs None (None) (fuzzy author =True and fuzzy llm =False): sim=0
# Comparing plasmacytoid dendritic cell (CL:0001058) vs plasmacytoid dendritic cell (CL:0001058) (fuzzy author =False and fuzzy llm =False): sim=1.0
# Comparing classical dendritic cell (CL:0000000) vs None (None) (fuzzy author =True and fuzzy llm =False): sim=0
# Comparing cd14+ monocyte cell (CL:0000000) vs None (None) (fuzzy author =True and fuzzy llm =False): sim=0
# Comparing cd14+ monocyte cell (CL:0000000) vs monocyte (CL:0001054) (fuzzy author =True and fuzzy llm =False): sim=0.28
# Comparing cd16+ monocyte cell (CL:0002397) vs non-classical monocyte (CL:0000875) (fuzzy author =True and fuzzy llm =False): sim=0.8888888888888888
# Comparing unknown (None) vs monocyte (CL:0001054) (fuzzy author =False and fuzzy llm =False): sim=0
# Comparing common lymphoid progenitor (CL:0000051) vs pre-b cell (CL:0000817) (fuzzy author =False and fuzzy llm =False): sim=0.38461538461538464
# Comparing pre b-cell progenitor (CL:0000826) vs pre-b cell (CL:0000817) (fuzzy author =True and fuzzy llm =False): sim=0.37037037037037035
# Comparing b cell (CL:0000236) vs b cell (CL:0000236) (fuzzy author =False and fuzzy llm =False): sim=1.0
# Comparing plasma cell (CL:0000786) vs None (None) (fuzzy author =False and fuzzy llm =False): sim=0
# Comparing cd8+ naive cell (CL:0000900) vs cd8+ t cell (CL:0000917) (fuzzy author =True and fuzzy llm =True): sim=0.84
# Comparing cd4+ naive cell (CL:0000895) vs t cell (CL:0000084) (fuzzy author =True and fuzzy llm =False): sim=0.7391304347826086
# Comparing cd4+ naive cell (CL:0000895) vs t cell (CL:0000084) (fuzzy author =True and fuzzy llm =False): sim=0.7391304347826086
# Comparing cd4+ memory cell (CL:0000000) vs t cell (CL:0000084) (fuzzy author =True and fuzzy llm =False): sim=0.4117647058823529
# Comparing cd8+ effector memory cell (CL:0000913) vs cytotoxic t lymphocyte (CL:0000910) (fuzzy author =True and fuzzy llm =False): sim=0.6666666666666666
# Comparing cd8+ central memory cell (CL:0000907) vs cd8+ t cell (CL:0000917) (fuzzy author =True and fuzzy llm =True): sim=0.7777777777777778
# Comparing natural killer cell (CL:0000623) vs natural killer cell (CL:0000623) (fuzzy author =False and fuzzy llm =False): sim=1.0
# Comparing unknown (None) vs b-cell (CL:0000236) (fuzzy author =False and fuzzy llm =False): sim=0

# %% [markdown]
# CellTypist Annotated Cell Ontology Based Similarity

# %%
for file_path in glob.glob(input_pattern_cellTypist):
    if '_similarity' in os.path.basename(file_path):
        continue

    print(f"\nProcessing: {os.path.basename(file_path)}")
    df = pd.read_csv(file_path)

    colnames = df.columns.tolist()
    if len(colnames) < 2:
        print(f"  Skipping {file_path} — not enough columns.")
        continue

    author_col = colnames[0]
    cellTypist_col = colnames[1]

    similarity_scores = []

    for _, row in df.iterrows():
        author_label = normalize_label(row[author_col])
        cellTypist_label = normalize_label(row[cellTypist_col])

        fuzzy_used = False

        ids1 = label_to_id_ci.get(author_label)
        ids2 = label_to_id_ci_2.get(cellTypist_label)

        # Fuzzy match fallback if not found
        if not ids1 and author_label:
            match = fuzzy_match_label(author_label, label_to_id_ci.keys())
            if match:
                ids1 = label_to_id_ci[match]
                fuzzy_used_author = True

        if not ids2 and llm_label:
            match = fuzzy_match_label(cellTypist_label, label_to_id_ci_2.keys())
            if match:
                ids2 = label_to_id_ci_2[match]
                fuzzy_used_cellTypist = True

        # Normalize to sets
        if isinstance(ids1, str):
            ids1 = {ids1}
        if isinstance(ids2, str):
            ids2 = {ids2}

        max_sim = 0
        if ids1 and ids2:
            for id1 in ids1:
                for id2 in ids2:
                    sim = compute_similarity(id1, id2, G)
                    print(f"Comparing {author_label} ({id1}) vs {cellTypist_label} ({id2}) (Author Fuzzy={fuzzy_used_author} and Cell Typist Fuzzy={fuzzy_used_cellTypist}): sim={sim}")
                    if sim > max_sim:
                        max_sim = sim
                       
        else:
            print(f"Skipping row: {author_label} or {cellTypist_label} not found.")
        
        print(f"Max Sim {max_sim}") 
        similarity_scores.append(max_sim)

    df['similarity_score'] = similarity_scores
    #out_path = file_path.replace(".csv", "_similarity.csv")
    #df.to_csv(out_path, index=False)
    #print(f"  Saved: {os.path.basename(out_path)}")
# Out:
# Processing: author_vs_celltypist_Roy_Immune_All_High_new.csv
# Comparing 01_hsc (CL:0000037) vs hsc/mpp (CL:0000049) (Author Fuzzy=True and Cell Typist Fuzzy=True): sim=0.6111111111111112
# Comparing 01_hsc (CL:0000037) vs hsc/mpp (CL:0000557) (Author Fuzzy=True and Cell Typist Fuzzy=True): sim=0.5416666666666666
# Comparing 01_hsc (CL:0000037) vs hsc/mpp (CL:0000837) (Author Fuzzy=True and Cell Typist Fuzzy=True): sim=0.6470588235294118
# Comparing 01_hsc (CL:0000037) vs hsc/mpp (CL:0000936) (Author Fuzzy=True and Cell Typist Fuzzy=True): sim=0.7222222222222222
# Comparing 01_hsc (CL:0000037) vs hsc/mpp (CL:0000834) (Author Fuzzy=True and Cell Typist Fuzzy=True): sim=0.6190476190476191
# Comparing 01_hsc (CL:0000037) vs hsc/mpp (CL:0000050) (Author Fuzzy=True and Cell Typist Fuzzy=True): sim=0.6842105263157895
# Max Sim 0.7222222222222222
# Skipping row: 02_early.eryth or memp not found.
# Max Sim 0
# Skipping row: 03_late.eryth or mid erythroid not found.
# Max Sim 0
# Skipping row: 04_early.baso or mast cell not found.
# Max Sim 0
# Comparing 05_cmp.lmpp (CL:0001059) vs hsc/mpp (CL:0000049) (Author Fuzzy=True and Cell Typist Fuzzy=True): sim=0.8125
# Comparing 05_cmp.lmpp (CL:0001059) vs hsc/mpp (CL:0000557) (Author Fuzzy=True and Cell Typist Fuzzy=True): sim=0.6086956521739131
# Comparing 05_cmp.lmpp (CL:0001059) vs hsc/mpp (CL:0000837) (Author Fuzzy=True and Cell Typist Fuzzy=True): sim=0.6470588235294118
# Comparing 05_cmp.lmpp (CL:0001059) vs hsc/mpp (CL:0000936) (Author Fuzzy=True and Cell Typist Fuzzy=True): sim=0.7222222222222222
# Comparing 05_cmp.lmpp (CL:0001059) vs hsc/mpp (CL:0000834) (Author Fuzzy=True and Cell Typist Fuzzy=True): sim=0.6190476190476191
# Comparing 05_cmp.lmpp (CL:0001059) vs hsc/mpp (CL:0000050) (Author Fuzzy=True and Cell Typist Fuzzy=True): sim=0.7777777777777778
# Max Sim 0.8125
# Skipping row: 06_clp.1 or pro-b cell not found.
# Max Sim 0
# Comparing 07_gmp (CL:0000557) vs classical monocyte (CL:0000875) (Author Fuzzy=True and Cell Typist Fuzzy=True): sim=0.3939393939393939
# Comparing 07_gmp (CL:0000557) vs classical monocyte (CL:0000576) (Author Fuzzy=True and Cell Typist Fuzzy=True): sim=0.40625
# Comparing 07_gmp (CL:0000557) vs classical monocyte (CL:0000860) (Author Fuzzy=True and Cell Typist Fuzzy=True): sim=0.3939393939393939
# Max Sim 0.40625
# Skipping row: 08_gmp.neut or neutrophil-myeloid progenitor not found.
# Max Sim 0
# Comparing 09_pdc (CL:0000784) vs pdc (CL:0001058) (Author Fuzzy=True and Cell Typist Fuzzy=True): sim=0.9166666666666666
# Max Sim 0.9166666666666666
# Comparing 10_cdc (CL:0000990) vs dc2 (CL:0000990) (Author Fuzzy=True and Cell Typist Fuzzy=True): sim=1.0
# Comparing 10_cdc (CL:0000990) vs dc2 (CL:0001056) (Author Fuzzy=True and Cell Typist Fuzzy=True): sim=0.9130434782608695
# Comparing 10_cdc (CL:0000990) vs dc2 (CL:0000840) (Author Fuzzy=True and Cell Typist Fuzzy=True): sim=0.88
# Max Sim 1.0
# Skipping row: 11_cd14.mono.1 or classical monocyte not found.
# Max Sim 0
# Skipping row: 12_cd14.mono.2 or classical monocyte not found.
# Max Sim 0
# Skipping row: 13_cd16.mono or non-classical monocyte not found.
# Max Sim 0
# Skipping row: 14_unk or classical monocyte not found.
# Max Sim 0
# Skipping row: 15_clp.2 or pro-b cell not found.
# Max Sim 0
# Skipping row: 16_pre.b or small pre-b cell not found.
# Max Sim 0
# Skipping row: 17_b or naive b cell not found.
# Max Sim 0
# Skipping row: 18_plasma or plasma cell not found.
# Max Sim 0
# Skipping row: 19_cd8.n or tcm/naive cytotoxic t cell not found.
# Max Sim 0
# Skipping row: 20_cd4.n1 or tcm/naive helper t cell not found.
# Max Sim 0
# Skipping row: 21_cd4.n2 or tcm/naive helper t cell not found.
# Max Sim 0
# Skipping row: 22_cd4.m or tcm/naive helper t cell not found.
# Max Sim 0
# Skipping row: 23_cd8.em or mait cell not found.
# Max Sim 0
# Skipping row: 24_cd8.cm or tem/trm cytotoxic t cell not found.
# Max Sim 0
# Skipping row: 25_nk or cd16+ nk cell not found.
# Max Sim 0
# Skipping row: 26_unk or naive b cell not found.
# Max Sim 0
#
# Processing: author_vs_celltypist_Roy_Immune_All_Low_new.csv
# Comparing 01_hsc (CL:0000037) vs hsc/mpp (CL:0000049) (Author Fuzzy=True and Cell Typist Fuzzy=True): sim=0.6111111111111112
# Comparing 01_hsc (CL:0000037) vs hsc/mpp (CL:0000557) (Author Fuzzy=True and Cell Typist Fuzzy=True): sim=0.5416666666666666
# Comparing 01_hsc (CL:0000037) vs hsc/mpp (CL:0000837) (Author Fuzzy=True and Cell Typist Fuzzy=True): sim=0.6470588235294118
# Comparing 01_hsc (CL:0000037) vs hsc/mpp (CL:0000936) (Author Fuzzy=True and Cell Typist Fuzzy=True): sim=0.7222222222222222
# Comparing 01_hsc (CL:0000037) vs hsc/mpp (CL:0000834) (Author Fuzzy=True and Cell Typist Fuzzy=True): sim=0.6190476190476191
# Comparing 01_hsc (CL:0000037) vs hsc/mpp (CL:0000050) (Author Fuzzy=True and Cell Typist Fuzzy=True): sim=0.6842105263157895
# Max Sim 0.7222222222222222
# Skipping row: 02_early.eryth or memp not found.
# Max Sim 0
# Skipping row: 03_late.eryth or mid erythroid not found.
# Max Sim 0
# Skipping row: 04_early.baso or mast cell not found.
# Max Sim 0
# Comparing 05_cmp.lmpp (CL:0001059) vs hsc/mpp (CL:0000049) (Author Fuzzy=True and Cell Typist Fuzzy=True): sim=0.8125
# Comparing 05_cmp.lmpp (CL:0001059) vs hsc/mpp (CL:0000557) (Author Fuzzy=True and Cell Typist Fuzzy=True): sim=0.6086956521739131
# Comparing 05_cmp.lmpp (CL:0001059) vs hsc/mpp (CL:0000837) (Author Fuzzy=True and Cell Typist Fuzzy=True): sim=0.6470588235294118
# Comparing 05_cmp.lmpp (CL:0001059) vs hsc/mpp (CL:0000936) (Author Fuzzy=True and Cell Typist Fuzzy=True): sim=0.7222222222222222
# Comparing 05_cmp.lmpp (CL:0001059) vs hsc/mpp (CL:0000834) (Author Fuzzy=True and Cell Typist Fuzzy=True): sim=0.6190476190476191
# Comparing 05_cmp.lmpp (CL:0001059) vs hsc/mpp (CL:0000050) (Author Fuzzy=True and Cell Typist Fuzzy=True): sim=0.7777777777777778
# Max Sim 0.8125
# Skipping row: 06_clp.1 or pro-b cell not found.
# Max Sim 0
# Comparing 07_gmp (CL:0000557) vs classical monocyte (CL:0000875) (Author Fuzzy=True and Cell Typist Fuzzy=True): sim=0.3939393939393939
# Comparing 07_gmp (CL:0000557) vs classical monocyte (CL:0000576) (Author Fuzzy=True and Cell Typist Fuzzy=True): sim=0.40625
# Comparing 07_gmp (CL:0000557) vs classical monocyte (CL:0000860) (Author Fuzzy=True and Cell Typist Fuzzy=True): sim=0.3939393939393939
# Max Sim 0.40625
# Skipping row: 08_gmp.neut or neutrophil-myeloid progenitor not found.
# Max Sim 0
# Comparing 09_pdc (CL:0000784) vs pdc (CL:0001058) (Author Fuzzy=True and Cell Typist Fuzzy=True): sim=0.9166666666666666
# Max Sim 0.9166666666666666
# Comparing 10_cdc (CL:0000990) vs dc2 (CL:0000990) (Author Fuzzy=True and Cell Typist Fuzzy=True): sim=1.0
# Comparing 10_cdc (CL:0000990) vs dc2 (CL:0001056) (Author Fuzzy=True and Cell Typist Fuzzy=True): sim=0.9130434782608695
# Comparing 10_cdc (CL:0000990) vs dc2 (CL:0000840) (Author Fuzzy=True and Cell Typist Fuzzy=True): sim=0.88
# Max Sim 1.0
# Skipping row: 11_cd14.mono.1 or classical monocyte not found.
# Max Sim 0
# Skipping row: 12_cd14.mono.2 or classical monocyte not found.
# Max Sim 0
# Skipping row: 13_cd16.mono or non-classical monocyte not found.
# Max Sim 0
# Skipping row: 14_unk or classical monocyte not found.
# Max Sim 0
# Skipping row: 15_clp.2 or pro-b cell not found.
# Max Sim 0
# Skipping row: 16_pre.b or small pre-b cell not found.
# Max Sim 0
# Skipping row: 17_b or naive b cell not found.
# Max Sim 0
# Skipping row: 18_plasma or plasma cell not found.
# Max Sim 0
# Skipping row: 19_cd8.n or tcm/naive cytotoxic t cell not found.
# Max Sim 0
# Skipping row: 20_cd4.n1 or tcm/naive helper t cell not found.
# Max Sim 0
# Skipping row: 21_cd4.n2 or tcm/naive helper t cell not found.
# Max Sim 0
# Skipping row: 22_cd4.m or tcm/naive helper t cell not found.
# Max Sim 0
# Skipping row: 23_cd8.em or mait cell not found.
# Max Sim 0
# Skipping row: 24_cd8.cm or tem/trm cytotoxic t cell not found.
# Max Sim 0
# Skipping row: 25_nk or cd16+ nk cell not found.
# Max Sim 0
# Skipping row: 26_unk or naive b cell not found.
# Max Sim 0
#
# Processing: author_vs_celltypist_Granja_Immune_All_High.csv
# Comparing 01_hsc (CL:0000037) vs hsc/mpp (CL:0000049) (Author Fuzzy=True and Cell Typist Fuzzy=True): sim=0.6111111111111112
# Comparing 01_hsc (CL:0000037) vs hsc/mpp (CL:0000557) (Author Fuzzy=True and Cell Typist Fuzzy=True): sim=0.5416666666666666
# Comparing 01_hsc (CL:0000037) vs hsc/mpp (CL:0000837) (Author Fuzzy=True and Cell Typist Fuzzy=True): sim=0.6470588235294118
# Comparing 01_hsc (CL:0000037) vs hsc/mpp (CL:0000936) (Author Fuzzy=True and Cell Typist Fuzzy=True): sim=0.7222222222222222
# Comparing 01_hsc (CL:0000037) vs hsc/mpp (CL:0000834) (Author Fuzzy=True and Cell Typist Fuzzy=True): sim=0.6190476190476191
# Comparing 01_hsc (CL:0000037) vs hsc/mpp (CL:0000050) (Author Fuzzy=True and Cell Typist Fuzzy=True): sim=0.6842105263157895
# Max Sim 0.7222222222222222
# Skipping row: 02_early.eryth or hsc/mpp not found.
# Max Sim 0
# Skipping row: 03_late.eryth or erythroid not found.
# Max Sim 0
# Skipping row: 04_early.baso or mast cell not found.
# Max Sim 0
# Comparing 05_cmp.lmpp (CL:0001059) vs hsc/mpp (CL:0000049) (Author Fuzzy=True and Cell Typist Fuzzy=True): sim=0.8125
# Comparing 05_cmp.lmpp (CL:0001059) vs hsc/mpp (CL:0000557) (Author Fuzzy=True and Cell Typist Fuzzy=True): sim=0.6086956521739131
# Comparing 05_cmp.lmpp (CL:0001059) vs hsc/mpp (CL:0000837) (Author Fuzzy=True and Cell Typist Fuzzy=True): sim=0.6470588235294118
# Comparing 05_cmp.lmpp (CL:0001059) vs hsc/mpp (CL:0000936) (Author Fuzzy=True and Cell Typist Fuzzy=True): sim=0.7222222222222222
# Comparing 05_cmp.lmpp (CL:0001059) vs hsc/mpp (CL:0000834) (Author Fuzzy=True and Cell Typist Fuzzy=True): sim=0.6190476190476191
# Comparing 05_cmp.lmpp (CL:0001059) vs hsc/mpp (CL:0000050) (Author Fuzzy=True and Cell Typist Fuzzy=True): sim=0.7777777777777778
# Max Sim 0.8125
# Comparing 06_clp.1 (CL:0000051) vs b-cell lineage (CL:0000826) (Author Fuzzy=True and Cell Typist Fuzzy=True): sim=0.7222222222222222
# Comparing 06_clp.1 (CL:0000051) vs b-cell lineage (CL:0002046) (Author Fuzzy=True and Cell Typist Fuzzy=True): sim=0.6842105263157895
# Comparing 06_clp.1 (CL:0000051) vs b-cell lineage (CL:0000817) (Author Fuzzy=True and Cell Typist Fuzzy=True): sim=0.38461538461538464
# Max Sim 0.7222222222222222
# Comparing 07_gmp (CL:0000557) vs promyelocyte (CL:0000836) (Author Fuzzy=True and Cell Typist Fuzzy=True): sim=0.56
# Max Sim 0.56
# Comparing 08_gmp.neut (CL:0000557) vs hsc/mpp (CL:0000049) (Author Fuzzy=True and Cell Typist Fuzzy=True): sim=0.5454545454545454
# Comparing 08_gmp.neut (CL:0000557) vs hsc/mpp (CL:0000557) (Author Fuzzy=True and Cell Typist Fuzzy=True): sim=1.0
# Comparing 08_gmp.neut (CL:0000557) vs hsc/mpp (CL:0000837) (Author Fuzzy=True and Cell Typist Fuzzy=True): sim=0.5
# Comparing 08_gmp.neut (CL:0000557) vs hsc/mpp (CL:0000936) (Author Fuzzy=True and Cell Typist Fuzzy=True): sim=0.5652173913043478
# Comparing 08_gmp.neut (CL:0000557) vs hsc/mpp (CL:0000834) (Author Fuzzy=True and Cell Typist Fuzzy=True): sim=0.56
# Comparing 08_gmp.neut (CL:0000557) vs hsc/mpp (CL:0000050) (Author Fuzzy=True and Cell Typist Fuzzy=True): sim=0.6818181818181818
# Max Sim 1.0
# Comparing 09_pdc (CL:0000784) vs pdc (CL:0001058) (Author Fuzzy=True and Cell Typist Fuzzy=True): sim=0.9166666666666666
# Max Sim 0.9166666666666666
# Comparing 10_cdc (CL:0000990) vs dc (CL:0000990) (Author Fuzzy=True and Cell Typist Fuzzy=True): sim=1.0
# Comparing 10_cdc (CL:0000990) vs dc (CL:0001056) (Author Fuzzy=True and Cell Typist Fuzzy=True): sim=0.9130434782608695
# Comparing 10_cdc (CL:0000990) vs dc (CL:0000840) (Author Fuzzy=True and Cell Typist Fuzzy=True): sim=0.88
# Max Sim 1.0
# Skipping row: 11_cd14.mono.1 or monocyte not found.
# Max Sim 0
# Skipping row: 12_cd14.mono.2 or monocyte not found.
# Max Sim 0
# Skipping row: 13_cd16.mono or monocyte not found.
# Max Sim 0
# Skipping row: 14_unk or monocyte not found.
# Max Sim 0
# Comparing 15_clp.2 (CL:0000051) vs b-cell lineage (CL:0000826) (Author Fuzzy=True and Cell Typist Fuzzy=True): sim=0.7222222222222222
# Comparing 15_clp.2 (CL:0000051) vs b-cell lineage (CL:0002046) (Author Fuzzy=True and Cell Typist Fuzzy=True): sim=0.6842105263157895
# Comparing 15_clp.2 (CL:0000051) vs b-cell lineage (CL:0000817) (Author Fuzzy=True and Cell Typist Fuzzy=True): sim=0.38461538461538464
# Max Sim 0.7222222222222222
# Skipping row: 16_pre.b or b-cell lineage not found.
# Max Sim 0
# Skipping row: 17_b or b cell not found.
# Max Sim 0
# Skipping row: 18_plasma or plasma cell not found.
# Max Sim 0
# Skipping row: 19_cd8.n or t cell not found.
# Max Sim 0
# Skipping row: 20_cd4.n1 or t cell not found.
# Max Sim 0
# Skipping row: 21_cd4.n2 or t cell not found.
# Max Sim 0
# Skipping row: 22_cd4.m or t cell not found.
# Max Sim 0
# Skipping row: 23_cd8.em or t cell not found.
# Max Sim 0
# Skipping row: 24_cd8.cm or t cell not found.
# Max Sim 0
# Skipping row: 25_nk or ilc not found.
# Max Sim 0
# Skipping row: 26_unk or b cell not found.
# Max Sim 0
#
# Processing: author_vs_celltypist_Granja_Immune_All_Low.csv
# Comparing 01_hsc (CL:0000037) vs hsc/mpp (CL:0000049) (Author Fuzzy=True and Cell Typist Fuzzy=True): sim=0.6111111111111112
# Comparing 01_hsc (CL:0000037) vs hsc/mpp (CL:0000557) (Author Fuzzy=True and Cell Typist Fuzzy=True): sim=0.5416666666666666
# Comparing 01_hsc (CL:0000037) vs hsc/mpp (CL:0000837) (Author Fuzzy=True and Cell Typist Fuzzy=True): sim=0.6470588235294118
# Comparing 01_hsc (CL:0000037) vs hsc/mpp (CL:0000936) (Author Fuzzy=True and Cell Typist Fuzzy=True): sim=0.7222222222222222
# Comparing 01_hsc (CL:0000037) vs hsc/mpp (CL:0000834) (Author Fuzzy=True and Cell Typist Fuzzy=True): sim=0.6190476190476191
# Comparing 01_hsc (CL:0000037) vs hsc/mpp (CL:0000050) (Author Fuzzy=True and Cell Typist Fuzzy=True): sim=0.6842105263157895
# Max Sim 0.7222222222222222
# Skipping row: 02_early.eryth or megakaryocyte precursor not found.
# Max Sim 0
# Skipping row: 03_late.eryth or mid erythroid not found.
# Max Sim 0
# Skipping row: 04_early.baso or mast cell not found.
# Max Sim 0
# Comparing 05_cmp.lmpp (CL:0001059) vs hsc/mpp (CL:0000049) (Author Fuzzy=True and Cell Typist Fuzzy=True): sim=0.8125
# Comparing 05_cmp.lmpp (CL:0001059) vs hsc/mpp (CL:0000557) (Author Fuzzy=True and Cell Typist Fuzzy=True): sim=0.6086956521739131
# Comparing 05_cmp.lmpp (CL:0001059) vs hsc/mpp (CL:0000837) (Author Fuzzy=True and Cell Typist Fuzzy=True): sim=0.6470588235294118
# Comparing 05_cmp.lmpp (CL:0001059) vs hsc/mpp (CL:0000936) (Author Fuzzy=True and Cell Typist Fuzzy=True): sim=0.7222222222222222
# Comparing 05_cmp.lmpp (CL:0001059) vs hsc/mpp (CL:0000834) (Author Fuzzy=True and Cell Typist Fuzzy=True): sim=0.6190476190476191
# Comparing 05_cmp.lmpp (CL:0001059) vs hsc/mpp (CL:0000050) (Author Fuzzy=True and Cell Typist Fuzzy=True): sim=0.7777777777777778
# Max Sim 0.8125
# Skipping row: 06_clp.1 or pro-b cell not found.
# Max Sim 0
# Comparing 07_gmp (CL:0000557) vs promyelocyte (CL:0000836) (Author Fuzzy=True and Cell Typist Fuzzy=True): sim=0.56
# Max Sim 0.56
# Skipping row: 08_gmp.neut or cmp not found.
# Max Sim 0
# Comparing 09_pdc (CL:0000784) vs pdc (CL:0001058) (Author Fuzzy=True and Cell Typist Fuzzy=True): sim=0.9166666666666666
# Max Sim 0.9166666666666666
# Comparing 10_cdc (CL:0000990) vs dc2 (CL:0000990) (Author Fuzzy=True and Cell Typist Fuzzy=True): sim=1.0
# Comparing 10_cdc (CL:0000990) vs dc2 (CL:0001056) (Author Fuzzy=True and Cell Typist Fuzzy=True): sim=0.9130434782608695
# Comparing 10_cdc (CL:0000990) vs dc2 (CL:0000840) (Author Fuzzy=True and Cell Typist Fuzzy=True): sim=0.88
# Max Sim 1.0
# Skipping row: 11_cd14.mono.1 or classical monocyte not found.
# Max Sim 0
# Skipping row: 12_cd14.mono.2 or classical monocyte not found.
# Max Sim 0
# Skipping row: 13_cd16.mono or non-classical monocyte not found.
# Max Sim 0
# Skipping row: 14_unk or classical monocyte not found.
# Max Sim 0
# Skipping row: 15_clp.2 or pro-b cell not found.
# Max Sim 0
# Skipping row: 16_pre.b or small pre-b cell not found.
# Max Sim 0
# Skipping row: 17_b or naive b cell not found.
# Max Sim 0
# Skipping row: 18_plasma or plasma cell not found.
# Max Sim 0
# Skipping row: 19_cd8.n or tcm/naive cytotoxic t cell not found.
# Max Sim 0
# Skipping row: 20_cd4.n1 or tcm/naive helper t cell not found.
# Max Sim 0
# Skipping row: 21_cd4.n2 or tcm/naive helper t cell not found.
# Max Sim 0
# Skipping row: 22_cd4.m or tcm/naive helper t cell not found.
# Max Sim 0
# Skipping row: 23_cd8.em or mait cell not found.
# Max Sim 0
# Skipping row: 24_cd8.cm or tem/trm cytotoxic t cell not found.
# Max Sim 0
# Skipping row: 25_nk or cd16+ nk cell not found.
# Max Sim 0
# Skipping row: 26_unk or naive b cell not found.
# Max Sim 0

# %%
## Load Datasets and Mapping Reference (Text to Cell Ontology ID)
# Base Directory of Dataset
base_dir = os.path.expanduser("~/Göran_Karlsson_Lab/benchLLM/Granja_et_al")
input_pattern = os.path.join(base_dir, "author_vs_*.csv")

## Mapping Reference 
# General 
mapping_df = pd.read_csv(os.path.expanduser("~/Göran_Karlsson_Lab/benchLLM/cell_to_cell_ontology.csv"))
# CellTypist
mapping_df_cellTypist = pd.read_csv(os.path.expanduser("~/Göran_Karlsson_Lab/benchLLM/CellTypist_to_Cell_Ontology.csv"))

# %%
# Load Cell Ontology Map (OWL)
print("Loading Cell Ontology (OWL)...")
G = get_ontology("http://purl.obolibrary.org/obo/cl.owl").load()
print("Ontology loaded.")

# %%
def get_ancestors(cls):
    return set(cls.ancestors()) if cls else set()

def compute_similarity(id1, id2, onto):
    if id1 is None or id2 is None:
        return 0

    class1 = onto.search_one(iri="*" + id1.replace(":", "_")) # Convert ID1 to be Compatible with OWL
    class2 = onto.search_one(iri="*" + id2.replace(":", "_")) # Convert ID2 to be Compatible with OWL

    if not class1 or not class2:
        return 0

    ancestors1 = get_ancestors(class1)
    ancestors2 = get_ancestors(class2)

    intersection = ancestors1 & ancestors2
    union = ancestors1 | ancestors2

    if not union:
        return 0

    return len(intersection) / len(union)  # Jaccard Similarity

def normalize_label(label):
    label = str(label).lower().strip()                      # Remove Case Sensitivity and Trim
    label = re.sub(r'^\d+_?', '', label)                    # Remove Leading Numbers and Underscore
    label = re.sub(r'\s*\(.*?\)', '', label)                # Remove text in parentheses
    if label.endswith('s') and len(label) > 1:
        label = label[:-1]                                  # Remove Plural
    return label.strip()

#def normalize_label(label):
#    label = str(label).lower().strip() # Remove Case Sensitivity
#    label = re.sub(r'\s*\(.*?\)', '', label)  # Remove Special Characters
#    if label.endswith('s') and len(label) > 1:
#        label = label[:-1]
#    return label # Remove Plural

def fuzzy_match_label(label, choices, threshold=80):
    if label is None:
        return None
    result = process.extractOne(label, choices)
    if result is None:
        return None
    if len(result) == 2:
        match, score = result
    elif len(result) == 3:
        # Sometimes it returns (match, score, index)
        match, score, _ = result
    else:
        return None
    if score >= threshold:
        return match
    return None # Use Fuzzy Match if Exact Match is Null

# %%
# Read in all .CSVs that are relavent
for file_path in glob.glob(input_pattern):
    basename = os.path.basename(file_path)
    
    if '_similarity' in basename:
        continue # Exclude already completed file (Already made similarity files)
    
    if '_celltypist_' in basename:
        if 'Low' in basename:
            # Isolate CellTypist Files with High Granularity
            print(f'\nProcessing: {basename} as High Granularity CellTypist Annotation')
            label_to_id_high = dict(zip(mapping_df_cellTypist['Low-hierarchy cell types'], mapping_df_cellTypist['Cell Ontology ID']))
            label_to_id_ci_high = {k.lower(): v for k, v in label_to_id_high.items()}
            
            df = pd.read_csv(file_path)

            colnames = df.columns.tolist()
            if len(colnames) < 2:
                print(f"  Skipping {file_path} — not enough columns.")
                continue

            author_col = colnames[0]
            cellTypist_high_col = colnames[1]

            similarity_scores = []
            for _, row in df.iterrows():
                author_label = normalize_label(row[author_col])
                cellTypist_high_label = normalize_label(row[cellTypist_high_col])

                if author_label in ["nan", "none"] or pd.isna(author_label):
                    author_label = None
                if cellTypist_high_label in ["nan", "none"] or pd.isna(cellTypist_high_label):
                    cellTypist_high_label = None

                fuzzy_used_author = False
                fuzzy_used_cellTypist_high = False

                id1 = label_to_id_ci.get(author_label) if author_label else None
                id2 = label_to_id_ci_high.get(cellTypist_high_label) if cellTypist_high_label else None

                if id1 is None and author_label is not None:
                    matched_label = fuzzy_match_label(author_label, label_to_id_ci.keys())
                    if matched_label:
                        fuzzy_used_author = True
                    id1 = label_to_id_ci.get(matched_label)

                if id2 is None and cellTypist_high_label is not None:
                    matched_label = fuzzy_match_label(cellTypist_high_label, label_to_id_ci_low.keys())
                    if matched_label:
                        fuzzy_used_cellTypist_high = True
                    id2 = label_to_id_ci_high.get(matched_label)

                sim = compute_similarity(id1, id2, G)
                print(f"Comparing {author_label} ({id1}) vs {cellTypist_high_label} ({id2}) (fuzzy author ={fuzzy_used_author} and fuzzy llm ={fuzzy_used_cellTypist_high}): sim={sim}")
                similarity_scores.append(sim)


            df['similarity_score'] = similarity_scores
            print(df)
            
        elif 'High' in basename:
            # Isolate CellTypist Files with Low Granularity
            print(f'\nProcessing: {basename} as Low Granularity CellTypist Annotation')
            label_to_id_low = (mapping_df_cellTypist
                .groupby('High-hierarchy cell types')['Cell Ontology ID']
                .apply(set)
                .to_dict()
            )
            label_to_id_ci_low = {k.lower(): v for k, v in label_to_id_low.items()}
            df = pd.read_csv(file_path)

            colnames = df.columns.tolist()
            if len(colnames) < 2:
                print(f"  Skipping {file_path} — not enough columns.")
                continue

            author_col = colnames[0]
            cellTypist_col = colnames[1]

            similarity_scores = []

            for _, row in df.iterrows():
                author_label = normalize_label(row[author_col])
                cellTypist_low_label = normalize_label(row[cellTypist_col])

                fuzzy_used_author = False
                fuzzy_used_cellTypist = False

                ids1 = label_to_id_ci.get(author_label)
                ids2 = label_to_id_ci_low.get(cellTypist_low_label)

                # Fuzzy match fallback if not found
                if not ids1 and author_label:
                    match = fuzzy_match_label(author_label, label_to_id_ci.keys())
                if match:
                    ids1 = normalized_match = normalize_label(match)
                    ids1 = label_to_id_ci.get(normalized_match)
                    if ids1:
                        fuzzy_used_author = True

                if not ids2 and cellTypist_label:
                    match = fuzzy_match_label(cellTypist_low_label, label_to_id_ci_low.keys())
                if match:
                    ids2 = label_to_id_ci_low.get(match.lower())
                    if ids2:
                        fuzzy_used_cellTypist_low = True

                # Normalize to sets
                if isinstance(ids1, str):
                    ids1 = {ids1}
                if isinstance(ids2, str):
                    ids2 = {ids2}

                max_sim = 0
                if ids1 and ids2:
                    for id1 in ids1:
                        for id2 in ids2:
                            sim = compute_similarity(id1, id2, G)
                            print(f"Comparing {author_label} ({id1}) vs {cellTypist_low_label} ({id2}) (Author Fuzzy={fuzzy_used_author} and Cell Typist Fuzzy={fuzzy_used_cellTypist_low}): sim={sim}")
                            if sim > max_sim:
                                max_sim = sim
                       
                else:
                    id1_vals = ids1 if ids1 else [None]
                    id2_vals = ids2 if ids2 else [None]
                    for id1 in id1_vals:
                        for id2 in id2_vals:
                            print(f"Comparing {author_label} ({id1}) vs {cellTypist_low_label} ({id2}) (Author Fuzzy={fuzzy_used_author} and Cell Typist Fuzzy={fuzzy_used_cellTypist_low}): sim=Skipped (missing IDs)")
        
                print(f"Max Sim {max_sim}") 
                similarity_scores.append(max_sim)

            df['similarity_score'] = similarity_scores
            print(df)
            #out_path = file_path.replace(".csv", "_similarity.csv")
            #df.to_csv(out_path, index=False)
            #print(f"  Saved: {os.path.basename(out_path)}")
            
    else:
        # Isolate General Files
        print(f'\nProcessing: {basename} as General Annotation')
        label_to_id = dict(zip(mapping_df['label'], mapping_df['ontology_id']))
        label_to_id_ci = {k.lower(): v for k, v in label_to_id.items()}
    
        colnames = df.columns.tolist()
        if len(colnames) < 2:
            print(f"  Skipping {file_path} — not enough columns.")
            continue

        author_col = colnames[0]
        llm_col = colnames[1]

        similarity_scores = []
        for _, row in df.iterrows():
            author_label = normalize_label(row[author_col])
            llm_label = normalize_label(row[llm_col])

            if author_label in ["nan", "none"] or pd.isna(author_label):
                author_label = None
            if llm_label in ["nan", "none"] or pd.isna(llm_label):
                llm_label = None

            fuzzy_used_author = False
            fuzzy_used_llm = False

            id1 = label_to_id_ci.get(author_label) if author_label else None
            id2 = label_to_id_ci.get(llm_label) if llm_label else None

            if id1 is None and author_label is not None:
                matched_label = fuzzy_match_label(author_label, label_to_id_ci.keys())
                if matched_label:
                    fuzzy_used_author = True
                id1 = label_to_id_ci.get(matched_label)

            if id2 is None and llm_label is not None:
                matched_label = fuzzy_match_label(llm_label, label_to_id_ci.keys())
                if matched_label:
                    fuzzy_used_llm = True
                id2 = label_to_id_ci.get(matched_label)

            sim = compute_similarity(id1, id2, G)
            print(f"Comparing {author_label} ({id1}) vs {llm_label} ({id2}) (fuzzy author ={fuzzy_used_author} and fuzzy llm ={fuzzy_used_llm}): sim={sim}")
            similarity_scores.append(sim)


        df['similarity_score'] = similarity_scores
        print(df)

        #out_path = file_path.replace(".csv", "_similarity.csv")
        #df.to_csv(out_path, index=False)
        #print(f"  Saved: {os.path.basename(out_path)}")
# Out:
# Processing: author_vs_celltypist_Roy_Immune_All_High_new.csv as High Granularity CellTypist Annotation
# Comparing hsc (CL:0000037) vs hsc/mpp (CL:0000837) (fuzzy author =False and fuzzy llm =False): sim=0.6470588235294118
# Comparing early.eryth (CL:0000549) vs memp (CL:0000050) (fuzzy author =True and fuzzy llm =False): sim=0.6842105263157895
# Comparing late.eryth (CL:0000552) vs mid erythroid (CL:0000764) (fuzzy author =True and fuzzy llm =False): sim=0.75
# Comparing early.baso (None) vs mast cell (CL:0000097) (fuzzy author =False and fuzzy llm =True): sim=0
# Comparing cmp.lmpp (CL:0001059) vs hsc/mpp (CL:0000837) (fuzzy author =True and fuzzy llm =False): sim=0.6470588235294118
# Comparing clp.1 (CL:0000051) vs pro-b cell (None) (fuzzy author =True and fuzzy llm =False): sim=0
# Comparing gmp (CL:0000557) vs classical monocyte (CL:0000576) (fuzzy author =False and fuzzy llm =True): sim=0.40625
# Comparing gmp.neut (CL:0000557) vs neutrophil-myeloid progenitor (CL:0000834) (fuzzy author =True and fuzzy llm =False): sim=0.56
# Comparing pdc (CL:0000784) vs pdc (CL:0001058) (fuzzy author =False and fuzzy llm =False): sim=0.9166666666666666
# Comparing cdc (CL:0000990) vs dc2 (CL:0000990) (fuzzy author =False and fuzzy llm =False): sim=1.0
# Comparing cd14.mono.1 (None) vs classical monocyte (CL:0000576) (fuzzy author =False and fuzzy llm =True): sim=0
# Comparing cd14.mono.2 (None) vs classical monocyte (CL:0000576) (fuzzy author =False and fuzzy llm =True): sim=0
# Comparing cd16.mono (None) vs non-classical monocyte (CL:0000576) (fuzzy author =False and fuzzy llm =True): sim=0
# Comparing unk (CL:4052028) vs classical monocyte (CL:0000576) (fuzzy author =True and fuzzy llm =True): sim=0.5172413793103449
# Comparing clp.2 (CL:0000051) vs pro-b cell (None) (fuzzy author =True and fuzzy llm =False): sim=0
# Comparing pre.b (CL:0000952) vs small pre-b cell (CL:0000236) (fuzzy author =True and fuzzy llm =True): sim=0.75
# Comparing b (CL:0001066) vs naive b cell (CL:0000236) (fuzzy author =True and fuzzy llm =True): sim=0.37037037037037035
# Comparing plasma (CL:0000394) vs plasma cell (CL:0000786) (fuzzy author =True and fuzzy llm =True): sim=0.43478260869565216
# Comparing cd8.n (None) vs tcm/naive cytotoxic t cell (None) (fuzzy author =False and fuzzy llm =True): sim=0
# Comparing cd4.n1 (None) vs tcm/naive helper t cell (None) (fuzzy author =False and fuzzy llm =True): sim=0
# Comparing cd4.n2 (None) vs tcm/naive helper t cell (None) (fuzzy author =False and fuzzy llm =True): sim=0
# Comparing cd4.m (None) vs tcm/naive helper t cell (None) (fuzzy author =False and fuzzy llm =True): sim=0
# Comparing cd8.em (None) vs mait cell (CL:0000097) (fuzzy author =False and fuzzy llm =True): sim=0
# Comparing cd8.cm (None) vs tem/trm cytotoxic t cell (None) (fuzzy author =False and fuzzy llm =True): sim=0
# Comparing nk (CL:0000623) vs cd16+ nk cell (None) (fuzzy author =True and fuzzy llm =False): sim=0
# Comparing unk (CL:4052028) vs naive b cell (CL:0000236) (fuzzy author =True and fuzzy llm =True): sim=0.7272727272727273
#    BioClassification              cluster_cell_type  similarity_score
# 0             01_HSC                        HSC/MPP          0.647059
# 1     02_Early.Eryth                           MEMP          0.684211
# 2      03_Late.Eryth                  Mid erythroid          0.750000
# 3      04_Early.Baso                     Mast cells          0.000000
# 4        05_CMP.LMPP                        HSC/MPP          0.647059
# 5           06_CLP.1                    Pro-B cells          0.000000
# 6             07_GMP            Classical monocytes          0.406250
# 7        08_GMP.Neut  Neutrophil-myeloid progenitor          0.560000
# 8             09_pDC                            pDC          0.916667
# 9             10_cDC                            DC2          1.000000
# 10    11_CD14.Mono.1            Classical monocytes          0.000000
# 11    12_CD14.Mono.2            Classical monocytes          0.000000
# 12      13_CD16.Mono        Non-classical monocytes          0.000000
# 13            14_Unk            Classical monocytes          0.517241
# 14          15_CLP.2                    Pro-B cells          0.000000
# 15          16_Pre.B              Small pre-B cells          0.750000
# 16              17_B                  Naive B cells          0.370370
# 17         18_Plasma                   Plasma cells          0.434783
# 18          19_CD8.N    Tcm/Naive cytotoxic T cells          0.000000
# 19         20_CD4.N1       Tcm/Naive helper T cells          0.000000
# 20         21_CD4.N2       Tcm/Naive helper T cells          0.000000
# 21          22_CD4.M       Tcm/Naive helper T cells          0.000000
# 22         23_CD8.EM                     MAIT cells          0.000000
# 23         24_CD8.CM      Tem/Trm cytotoxic T cells          0.000000
# 24             25_NK                 CD16+ NK cells          0.000000
# 25            26_Unk                  Naive B cells          0.727273
#
# Processing: author_vs_Gemini2_5.csv as General Annotation
# Comparing hsc (CL:0000037) vs hsc/mpp (CL:0000037) (fuzzy author =False and fuzzy llm =True): sim=1.0
# Comparing early.eryth (CL:0000549) vs memp (CL:0000050) (fuzzy author =True and fuzzy llm =True): sim=0.6842105263157895
# Comparing late.eryth (CL:0000552) vs mid erythroid (CL:0000038) (fuzzy author =True and fuzzy llm =True): sim=0.7
# Comparing early.baso (None) vs mast cell (CL:0000097) (fuzzy author =False and fuzzy llm =False): sim=0
# Comparing cmp.lmpp (CL:0001059) vs hsc/mpp (CL:0000037) (fuzzy author =True and fuzzy llm =True): sim=0.6842105263157895
# Comparing clp.1 (CL:0000051) vs pro-b cell (CL:0000826) (fuzzy author =True and fuzzy llm =False): sim=0.7222222222222222
# Comparing gmp (CL:0000557) vs classical monocyte (CL:0000860) (fuzzy author =False and fuzzy llm =False): sim=0.3939393939393939
# Comparing gmp.neut (CL:0000557) vs neutrophil-myeloid progenitor (CL:0000775) (fuzzy author =True and fuzzy llm =True): sim=0.39285714285714285
# Comparing pdc (CL:0000784) vs pdc (CL:0000784) (fuzzy author =False and fuzzy llm =False): sim=1.0
# Comparing cdc (CL:0000990) vs dc2 (CL:0000784) (fuzzy author =False and fuzzy llm =False): sim=0.9130434782608695
# Comparing cd14.mono.1 (None) vs classical monocyte (CL:0000860) (fuzzy author =False and fuzzy llm =False): sim=0
# Comparing cd14.mono.2 (None) vs classical monocyte (CL:0000860) (fuzzy author =False and fuzzy llm =False): sim=0
# Comparing cd16.mono (None) vs non-classical monocyte (CL:0000875) (fuzzy author =False and fuzzy llm =False): sim=0
# Comparing unk (CL:4052028) vs classical monocyte (CL:0000860) (fuzzy author =True and fuzzy llm =False): sim=0.5
# Comparing clp.2 (CL:0000051) vs pro-b cell (CL:0000826) (fuzzy author =True and fuzzy llm =False): sim=0.7222222222222222
# Comparing pre.b (CL:0000952) vs small pre-b cell (CL:0002053) (fuzzy author =True and fuzzy llm =False): sim=0.8461538461538461
# Comparing b (CL:0001066) vs naive b cell (CL:0000788) (fuzzy author =True and fuzzy llm =False): sim=0.3125
# Comparing plasma (CL:0000394) vs plasma cell (CL:0000786) (fuzzy author =True and fuzzy llm =False): sim=0.43478260869565216
# Comparing cd8.n (None) vs tcm/naive cytotoxic t cell (CL:0000000) (fuzzy author =False and fuzzy llm =True): sim=0
# Comparing cd4.n1 (None) vs tcm/naive helper t cell (CL:0000000) (fuzzy author =False and fuzzy llm =True): sim=0
# Comparing cd4.n2 (None) vs tcm/naive helper t cell (CL:0000000) (fuzzy author =False and fuzzy llm =True): sim=0
# Comparing cd4.m (None) vs tcm/naive helper t cell (CL:0000000) (fuzzy author =False and fuzzy llm =True): sim=0
# Comparing cd8.em (None) vs mait cell (CL:0000000) (fuzzy author =False and fuzzy llm =True): sim=0
# Comparing cd8.cm (None) vs tem/trm cytotoxic t cell (CL:0000000) (fuzzy author =False and fuzzy llm =True): sim=0
# Comparing nk (CL:0000623) vs cd16+ nk cell (CL:0000000) (fuzzy author =True and fuzzy llm =True): sim=0.3684210526315789
# Comparing unk (CL:4052028) vs naive b cell (CL:0000788) (fuzzy author =True and fuzzy llm =False): sim=0.5925925925925926
#    BioClassification              cluster_cell_type  similarity_score
# 0             01_HSC                        HSC/MPP          1.000000
# 1     02_Early.Eryth                           MEMP          0.684211
# 2      03_Late.Eryth                  Mid erythroid          0.700000
# 3      04_Early.Baso                     Mast cells          0.000000
# 4        05_CMP.LMPP                        HSC/MPP          0.684211
# 5           06_CLP.1                    Pro-B cells          0.722222
# 6             07_GMP            Classical monocytes          0.393939
# 7        08_GMP.Neut  Neutrophil-myeloid progenitor          0.392857
# 8             09_pDC                            pDC          1.000000
# 9             10_cDC                            DC2          0.913043
# 10    11_CD14.Mono.1            Classical monocytes          0.000000
# 11    12_CD14.Mono.2            Classical monocytes          0.000000
# 12      13_CD16.Mono        Non-classical monocytes          0.000000
# 13            14_Unk            Classical monocytes          0.500000
# 14          15_CLP.2                    Pro-B cells          0.722222
# 15          16_Pre.B              Small pre-B cells          0.846154
# 16              17_B                  Naive B cells          0.312500
# 17         18_Plasma                   Plasma cells          0.434783
# 18          19_CD8.N    Tcm/Naive cytotoxic T cells          0.000000
# 19         20_CD4.N1       Tcm/Naive helper T cells          0.000000
# 20         21_CD4.N2       Tcm/Naive helper T cells          0.000000
# 21          22_CD4.M       Tcm/Naive helper T cells          0.000000
# 22         23_CD8.EM                     MAIT cells          0.000000
# 23         24_CD8.CM      Tem/Trm cytotoxic T cells          0.000000
# 24             25_NK                 CD16+ NK cells          0.368421
# 25            26_Unk                  Naive B cells          0.592593
#
# Processing: author_vs_celltypist_Roy_Immune_All_Low_new.csv as Low Granularity CellTypist Annotation
# Comparing hsc (CL:0000236) vs hsc/mpp (CL:0000844) (Author Fuzzy=True and Cell Typist Fuzzy=True): sim=0.782608695652174
# Comparing hsc (CL:0000236) vs hsc/mpp (CL:0000787) (Author Fuzzy=True and Cell Typist Fuzzy=True): sim=0.782608695652174
# Comparing hsc (CL:0000236) vs hsc/mpp (CL:0000818) (Author Fuzzy=True and Cell Typist Fuzzy=True): sim=0.8571428571428571
# Comparing hsc (CL:0000236) vs hsc/mpp (CL:0000843) (Author Fuzzy=True and Cell Typist Fuzzy=True): sim=0.75
# Comparing hsc (CL:0000236) vs hsc/mpp (CL:0000236) (Author Fuzzy=True and Cell Typist Fuzzy=True): sim=1.0
# Comparing hsc (CL:0000236) vs hsc/mpp (CL:0000788) (Author Fuzzy=True and Cell Typist Fuzzy=True): sim=0.782608695652174
# Max Sim 1.0
# Comparing early.eryth (CL:0000549) vs memp (None) (Author Fuzzy=True and Cell Typist Fuzzy=True): sim=Skipped (missing IDs)
# Max Sim 0
# Comparing late.eryth (CL:0000552) vs mid erythroid (CL:0000764) (Author Fuzzy=True and Cell Typist Fuzzy=True): sim=0.75
# Max Sim 0.75
# Comparing early.baso (None) vs mast cell (CL:0000097) (Author Fuzzy=False and Cell Typist Fuzzy=True): sim=Skipped (missing IDs)
# Max Sim 0
# Comparing cmp.lmpp (CL:0001059) vs hsc/mpp (None) (Author Fuzzy=True and Cell Typist Fuzzy=True): sim=Skipped (missing IDs)
# Max Sim 0
# Comparing clp.1 (CL:0000051) vs pro-b cell (None) (Author Fuzzy=True and Cell Typist Fuzzy=True): sim=Skipped (missing IDs)
# Max Sim 0
# Comparing gmp (CL:0000557) vs classical monocyte (CL:0000875) (Author Fuzzy=False and Cell Typist Fuzzy=True): sim=0.3939393939393939
# Comparing gmp (CL:0000557) vs classical monocyte (CL:0000576) (Author Fuzzy=False and Cell Typist Fuzzy=True): sim=0.40625
# Comparing gmp (CL:0000557) vs classical monocyte (CL:0000860) (Author Fuzzy=False and Cell Typist Fuzzy=True): sim=0.3939393939393939
# Max Sim 0.40625
# Comparing gmp.neut (CL:0000557) vs neutrophil-myeloid progenitor (None) (Author Fuzzy=True and Cell Typist Fuzzy=True): sim=Skipped (missing IDs)
# Max Sim 0
# Comparing pdc (CL:0000784) vs pdc (CL:0001058) (Author Fuzzy=False and Cell Typist Fuzzy=True): sim=0.9166666666666666
# Max Sim 0.9166666666666666
# Comparing cdc (CL:0000990) vs dc2 (CL:0000990) (Author Fuzzy=False and Cell Typist Fuzzy=True): sim=1.0
# Comparing cdc (CL:0000990) vs dc2 (CL:0001056) (Author Fuzzy=False and Cell Typist Fuzzy=True): sim=0.9130434782608695
# Comparing cdc (CL:0000990) vs dc2 (CL:0000840) (Author Fuzzy=False and Cell Typist Fuzzy=True): sim=0.88
# Max Sim 1.0
# Comparing cd14.mono.1 (None) vs classical monocyte (CL:0000875) (Author Fuzzy=False and Cell Typist Fuzzy=True): sim=Skipped (missing IDs)
# Comparing cd14.mono.1 (None) vs classical monocyte (CL:0000576) (Author Fuzzy=False and Cell Typist Fuzzy=True): sim=Skipped (missing IDs)
# Comparing cd14.mono.1 (None) vs classical monocyte (CL:0000860) (Author Fuzzy=False and Cell Typist Fuzzy=True): sim=Skipped (missing IDs)
# Max Sim 0
# Comparing cd14.mono.2 (None) vs classical monocyte (CL:0000875) (Author Fuzzy=False and Cell Typist Fuzzy=True): sim=Skipped (missing IDs)
# Comparing cd14.mono.2 (None) vs classical monocyte (CL:0000576) (Author Fuzzy=False and Cell Typist Fuzzy=True): sim=Skipped (missing IDs)
# Comparing cd14.mono.2 (None) vs classical monocyte (CL:0000860) (Author Fuzzy=False and Cell Typist Fuzzy=True): sim=Skipped (missing IDs)
# Max Sim 0
# Comparing cd16.mono (None) vs non-classical monocyte (CL:0000875) (Author Fuzzy=False and Cell Typist Fuzzy=True): sim=Skipped (missing IDs)
# Comparing cd16.mono (None) vs non-classical monocyte (CL:0000576) (Author Fuzzy=False and Cell Typist Fuzzy=True): sim=Skipped (missing IDs)
# Comparing cd16.mono (None) vs non-classical monocyte (CL:0000860) (Author Fuzzy=False and Cell Typist Fuzzy=True): sim=Skipped (missing IDs)
# Max Sim 0
# Comparing unk (CL:4052028) vs classical monocyte (CL:0000875) (Author Fuzzy=True and Cell Typist Fuzzy=True): sim=0.5
# Comparing unk (CL:4052028) vs classical monocyte (CL:0000576) (Author Fuzzy=True and Cell Typist Fuzzy=True): sim=0.5172413793103449
# Comparing unk (CL:4052028) vs classical monocyte (CL:0000860) (Author Fuzzy=True and Cell Typist Fuzzy=True): sim=0.5
# Max Sim 0.5172413793103449
# Comparing clp.2 (CL:0000051) vs pro-b cell (None) (Author Fuzzy=True and Cell Typist Fuzzy=True): sim=Skipped (missing IDs)
# Max Sim 0
# Comparing pre.b (CL:0000952) vs small pre-b cell (CL:0000844) (Author Fuzzy=True and Cell Typist Fuzzy=True): sim=0.7407407407407407
# Comparing pre.b (CL:0000952) vs small pre-b cell (CL:0000787) (Author Fuzzy=True and Cell Typist Fuzzy=True): sim=0.7407407407407407
# Comparing pre.b (CL:0000952) vs small pre-b cell (CL:0000818) (Author Fuzzy=True and Cell Typist Fuzzy=True): sim=0.8
# Comparing pre.b (CL:0000952) vs small pre-b cell (CL:0000843) (Author Fuzzy=True and Cell Typist Fuzzy=True): sim=0.7142857142857143
# Comparing pre.b (CL:0000952) vs small pre-b cell (CL:0000236) (Author Fuzzy=True and Cell Typist Fuzzy=True): sim=0.75
# Comparing pre.b (CL:0000952) vs small pre-b cell (CL:0000788) (Author Fuzzy=True and Cell Typist Fuzzy=True): sim=0.7407407407407407
# Max Sim 0.8
# Comparing b (CL:0001066) vs naive b cell (CL:0000844) (Author Fuzzy=True and Cell Typist Fuzzy=True): sim=0.3125
# Comparing b (CL:0001066) vs naive b cell (CL:0000787) (Author Fuzzy=True and Cell Typist Fuzzy=True): sim=0.3125
# Comparing b (CL:0001066) vs naive b cell (CL:0000818) (Author Fuzzy=True and Cell Typist Fuzzy=True): sim=0.3333333333333333
# Comparing b (CL:0001066) vs naive b cell (CL:0000843) (Author Fuzzy=True and Cell Typist Fuzzy=True): sim=0.30303030303030304
# Comparing b (CL:0001066) vs naive b cell (CL:0000236) (Author Fuzzy=True and Cell Typist Fuzzy=True): sim=0.37037037037037035
# Comparing b (CL:0001066) vs naive b cell (CL:0000788) (Author Fuzzy=True and Cell Typist Fuzzy=True): sim=0.3125
# Max Sim 0.37037037037037035
# Comparing plasma (CL:0000394) vs plasma cell (CL:0000980) (Author Fuzzy=True and Cell Typist Fuzzy=True): sim=0.35714285714285715
# Comparing plasma (CL:0000394) vs plasma cell (CL:0000786) (Author Fuzzy=True and Cell Typist Fuzzy=True): sim=0.43478260869565216
# Max Sim 0.43478260869565216
# Comparing cd8.n (None) vs tcm/naive cytotoxic t cell (CL:0000798) (Author Fuzzy=False and Cell Typist Fuzzy=True): sim=Skipped (missing IDs)
# Comparing cd8.n (None) vs tcm/naive cytotoxic t cell (CL:0000084) (Author Fuzzy=False and Cell Typist Fuzzy=True): sim=Skipped (missing IDs)
# Comparing cd8.n (None) vs tcm/naive cytotoxic t cell (CL:0000934) (Author Fuzzy=False and Cell Typist Fuzzy=True): sim=Skipped (missing IDs)
# Comparing cd8.n (None) vs tcm/naive cytotoxic t cell (CL:0000940) (Author Fuzzy=False and Cell Typist Fuzzy=True): sim=Skipped (missing IDs)
# Comparing cd8.n (None) vs tcm/naive cytotoxic t cell (CL:0000913) (Author Fuzzy=False and Cell Typist Fuzzy=True): sim=Skipped (missing IDs)
# Comparing cd8.n (None) vs tcm/naive cytotoxic t cell (CL:0001062) (Author Fuzzy=False and Cell Typist Fuzzy=True): sim=Skipped (missing IDs)
# Comparing cd8.n (None) vs tcm/naive cytotoxic t cell (CL:0000905) (Author Fuzzy=False and Cell Typist Fuzzy=True): sim=Skipped (missing IDs)
# Comparing cd8.n (None) vs tcm/naive cytotoxic t cell (CL:0000545) (Author Fuzzy=False and Cell Typist Fuzzy=True): sim=Skipped (missing IDs)
# Comparing cd8.n (None) vs tcm/naive cytotoxic t cell (CL:0000814) (Author Fuzzy=False and Cell Typist Fuzzy=True): sim=Skipped (missing IDs)
# Comparing cd8.n (None) vs tcm/naive cytotoxic t cell (CL:0000907) (Author Fuzzy=False and Cell Typist Fuzzy=True): sim=Skipped (missing IDs)
# Comparing cd8.n (None) vs tcm/naive cytotoxic t cell (CL:0000904) (Author Fuzzy=False and Cell Typist Fuzzy=True): sim=Skipped (missing IDs)
# Comparing cd8.n (None) vs tcm/naive cytotoxic t cell (CL:0000815) (Author Fuzzy=False and Cell Typist Fuzzy=True): sim=Skipped (missing IDs)
# Comparing cd8.n (None) vs tcm/naive cytotoxic t cell (CL:0002038) (Author Fuzzy=False and Cell Typist Fuzzy=True): sim=Skipped (missing IDs)
# Comparing cd8.n (None) vs tcm/naive cytotoxic t cell (CL:0000899) (Author Fuzzy=False and Cell Typist Fuzzy=True): sim=Skipped (missing IDs)
# Comparing cd8.n (None) vs tcm/naive cytotoxic t cell (CL:0002430) (Author Fuzzy=False and Cell Typist Fuzzy=True): sim=Skipped (missing IDs)
# Max Sim 0
# Comparing cd4.n1 (None) vs tcm/naive helper t cell (CL:0000798) (Author Fuzzy=False and Cell Typist Fuzzy=True): sim=Skipped (missing IDs)
# Comparing cd4.n1 (None) vs tcm/naive helper t cell (CL:0000084) (Author Fuzzy=False and Cell Typist Fuzzy=True): sim=Skipped (missing IDs)
# Comparing cd4.n1 (None) vs tcm/naive helper t cell (CL:0000934) (Author Fuzzy=False and Cell Typist Fuzzy=True): sim=Skipped (missing IDs)
# Comparing cd4.n1 (None) vs tcm/naive helper t cell (CL:0000940) (Author Fuzzy=False and Cell Typist Fuzzy=True): sim=Skipped (missing IDs)
# Comparing cd4.n1 (None) vs tcm/naive helper t cell (CL:0000913) (Author Fuzzy=False and Cell Typist Fuzzy=True): sim=Skipped (missing IDs)
# Comparing cd4.n1 (None) vs tcm/naive helper t cell (CL:0001062) (Author Fuzzy=False and Cell Typist Fuzzy=True): sim=Skipped (missing IDs)
# Comparing cd4.n1 (None) vs tcm/naive helper t cell (CL:0000905) (Author Fuzzy=False and Cell Typist Fuzzy=True): sim=Skipped (missing IDs)
# Comparing cd4.n1 (None) vs tcm/naive helper t cell (CL:0000545) (Author Fuzzy=False and Cell Typist Fuzzy=True): sim=Skipped (missing IDs)
# Comparing cd4.n1 (None) vs tcm/naive helper t cell (CL:0000814) (Author Fuzzy=False and Cell Typist Fuzzy=True): sim=Skipped (missing IDs)
# Comparing cd4.n1 (None) vs tcm/naive helper t cell (CL:0000907) (Author Fuzzy=False and Cell Typist Fuzzy=True): sim=Skipped (missing IDs)
# Comparing cd4.n1 (None) vs tcm/naive helper t cell (CL:0000904) (Author Fuzzy=False and Cell Typist Fuzzy=True): sim=Skipped (missing IDs)
# Comparing cd4.n1 (None) vs tcm/naive helper t cell (CL:0000815) (Author Fuzzy=False and Cell Typist Fuzzy=True): sim=Skipped (missing IDs)
# Comparing cd4.n1 (None) vs tcm/naive helper t cell (CL:0002038) (Author Fuzzy=False and Cell Typist Fuzzy=True): sim=Skipped (missing IDs)
# Comparing cd4.n1 (None) vs tcm/naive helper t cell (CL:0000899) (Author Fuzzy=False and Cell Typist Fuzzy=True): sim=Skipped (missing IDs)
# Comparing cd4.n1 (None) vs tcm/naive helper t cell (CL:0002430) (Author Fuzzy=False and Cell Typist Fuzzy=True): sim=Skipped (missing IDs)
# Max Sim 0
# Comparing cd4.n2 (None) vs tcm/naive helper t cell (CL:0000798) (Author Fuzzy=False and Cell Typist Fuzzy=True): sim=Skipped (missing IDs)
# Comparing cd4.n2 (None) vs tcm/naive helper t cell (CL:0000084) (Author Fuzzy=False and Cell Typist Fuzzy=True): sim=Skipped (missing IDs)
# Comparing cd4.n2 (None) vs tcm/naive helper t cell (CL:0000934) (Author Fuzzy=False and Cell Typist Fuzzy=True): sim=Skipped (missing IDs)
# Comparing cd4.n2 (None) vs tcm/naive helper t cell (CL:0000940) (Author Fuzzy=False and Cell Typist Fuzzy=True): sim=Skipped (missing IDs)
# Comparing cd4.n2 (None) vs tcm/naive helper t cell (CL:0000913) (Author Fuzzy=False and Cell Typist Fuzzy=True): sim=Skipped (missing IDs)
# Comparing cd4.n2 (None) vs tcm/naive helper t cell (CL:0001062) (Author Fuzzy=False and Cell Typist Fuzzy=True): sim=Skipped (missing IDs)
# Comparing cd4.n2 (None) vs tcm/naive helper t cell (CL:0000905) (Author Fuzzy=False and Cell Typist Fuzzy=True): sim=Skipped (missing IDs)
# Comparing cd4.n2 (None) vs tcm/naive helper t cell (CL:0000545) (Author Fuzzy=False and Cell Typist Fuzzy=True): sim=Skipped (missing IDs)
# Comparing cd4.n2 (None) vs tcm/naive helper t cell (CL:0000814) (Author Fuzzy=False and Cell Typist Fuzzy=True): sim=Skipped (missing IDs)
# Comparing cd4.n2 (None) vs tcm/naive helper t cell (CL:0000907) (Author Fuzzy=False and Cell Typist Fuzzy=True): sim=Skipped (missing IDs)
# Comparing cd4.n2 (None) vs tcm/naive helper t cell (CL:0000904) (Author Fuzzy=False and Cell Typist Fuzzy=True): sim=Skipped (missing IDs)
# Comparing cd4.n2 (None) vs tcm/naive helper t cell (CL:0000815) (Author Fuzzy=False and Cell Typist Fuzzy=True): sim=Skipped (missing IDs)
# Comparing cd4.n2 (None) vs tcm/naive helper t cell (CL:0002038) (Author Fuzzy=False and Cell Typist Fuzzy=True): sim=Skipped (missing IDs)
# Comparing cd4.n2 (None) vs tcm/naive helper t cell (CL:0000899) (Author Fuzzy=False and Cell Typist Fuzzy=True): sim=Skipped (missing IDs)
# Comparing cd4.n2 (None) vs tcm/naive helper t cell (CL:0002430) (Author Fuzzy=False and Cell Typist Fuzzy=True): sim=Skipped (missing IDs)
# Max Sim 0
# Comparing cd4.m (None) vs tcm/naive helper t cell (CL:0000798) (Author Fuzzy=False and Cell Typist Fuzzy=True): sim=Skipped (missing IDs)
# Comparing cd4.m (None) vs tcm/naive helper t cell (CL:0000084) (Author Fuzzy=False and Cell Typist Fuzzy=True): sim=Skipped (missing IDs)
# Comparing cd4.m (None) vs tcm/naive helper t cell (CL:0000934) (Author Fuzzy=False and Cell Typist Fuzzy=True): sim=Skipped (missing IDs)
# Comparing cd4.m (None) vs tcm/naive helper t cell (CL:0000940) (Author Fuzzy=False and Cell Typist Fuzzy=True): sim=Skipped (missing IDs)
# Comparing cd4.m (None) vs tcm/naive helper t cell (CL:0000913) (Author Fuzzy=False and Cell Typist Fuzzy=True): sim=Skipped (missing IDs)
# Comparing cd4.m (None) vs tcm/naive helper t cell (CL:0001062) (Author Fuzzy=False and Cell Typist Fuzzy=True): sim=Skipped (missing IDs)
# Comparing cd4.m (None) vs tcm/naive helper t cell (CL:0000905) (Author Fuzzy=False and Cell Typist Fuzzy=True): sim=Skipped (missing IDs)
# Comparing cd4.m (None) vs tcm/naive helper t cell (CL:0000545) (Author Fuzzy=False and Cell Typist Fuzzy=True): sim=Skipped (missing IDs)
# Comparing cd4.m (None) vs tcm/naive helper t cell (CL:0000814) (Author Fuzzy=False and Cell Typist Fuzzy=True): sim=Skipped (missing IDs)
# Comparing cd4.m (None) vs tcm/naive helper t cell (CL:0000907) (Author Fuzzy=False and Cell Typist Fuzzy=True): sim=Skipped (missing IDs)
# Comparing cd4.m (None) vs tcm/naive helper t cell (CL:0000904) (Author Fuzzy=False and Cell Typist Fuzzy=True): sim=Skipped (missing IDs)
# Comparing cd4.m (None) vs tcm/naive helper t cell (CL:0000815) (Author Fuzzy=False and Cell Typist Fuzzy=True): sim=Skipped (missing IDs)
# Comparing cd4.m (None) vs tcm/naive helper t cell (CL:0002038) (Author Fuzzy=False and Cell Typist Fuzzy=True): sim=Skipped (missing IDs)
# Comparing cd4.m (None) vs tcm/naive helper t cell (CL:0000899) (Author Fuzzy=False and Cell Typist Fuzzy=True): sim=Skipped (missing IDs)
# Comparing cd4.m (None) vs tcm/naive helper t cell (CL:0002430) (Author Fuzzy=False and Cell Typist Fuzzy=True): sim=Skipped (missing IDs)
# Max Sim 0
# Comparing cd8.em (None) vs mait cell (CL:0000097) (Author Fuzzy=False and Cell Typist Fuzzy=True): sim=Skipped (missing IDs)
# Max Sim 0
# Comparing cd8.cm (None) vs tem/trm cytotoxic t cell (CL:0000798) (Author Fuzzy=False and Cell Typist Fuzzy=True): sim=Skipped (missing IDs)
# Comparing cd8.cm (None) vs tem/trm cytotoxic t cell (CL:0000084) (Author Fuzzy=False and Cell Typist Fuzzy=True): sim=Skipped (missing IDs)
# Comparing cd8.cm (None) vs tem/trm cytotoxic t cell (CL:0000934) (Author Fuzzy=False and Cell Typist Fuzzy=True): sim=Skipped (missing IDs)
# Comparing cd8.cm (None) vs tem/trm cytotoxic t cell (CL:0000940) (Author Fuzzy=False and Cell Typist Fuzzy=True): sim=Skipped (missing IDs)
# Comparing cd8.cm (None) vs tem/trm cytotoxic t cell (CL:0000913) (Author Fuzzy=False and Cell Typist Fuzzy=True): sim=Skipped (missing IDs)
# Comparing cd8.cm (None) vs tem/trm cytotoxic t cell (CL:0001062) (Author Fuzzy=False and Cell Typist Fuzzy=True): sim=Skipped (missing IDs)
# Comparing cd8.cm (None) vs tem/trm cytotoxic t cell (CL:0000905) (Author Fuzzy=False and Cell Typist Fuzzy=True): sim=Skipped (missing IDs)
# Comparing cd8.cm (None) vs tem/trm cytotoxic t cell (CL:0000545) (Author Fuzzy=False and Cell Typist Fuzzy=True): sim=Skipped (missing IDs)
# Comparing cd8.cm (None) vs tem/trm cytotoxic t cell (CL:0000814) (Author Fuzzy=False and Cell Typist Fuzzy=True): sim=Skipped (missing IDs)
# Comparing cd8.cm (None) vs tem/trm cytotoxic t cell (CL:0000907) (Author Fuzzy=False and Cell Typist Fuzzy=True): sim=Skipped (missing IDs)
# Comparing cd8.cm (None) vs tem/trm cytotoxic t cell (CL:0000904) (Author Fuzzy=False and Cell Typist Fuzzy=True): sim=Skipped (missing IDs)
# Comparing cd8.cm (None) vs tem/trm cytotoxic t cell (CL:0000815) (Author Fuzzy=False and Cell Typist Fuzzy=True): sim=Skipped (missing IDs)
# Comparing cd8.cm (None) vs tem/trm cytotoxic t cell (CL:0002038) (Author Fuzzy=False and Cell Typist Fuzzy=True): sim=Skipped (missing IDs)
# Comparing cd8.cm (None) vs tem/trm cytotoxic t cell (CL:0000899) (Author Fuzzy=False and Cell Typist Fuzzy=True): sim=Skipped (missing IDs)
# Comparing cd8.cm (None) vs tem/trm cytotoxic t cell (CL:0002430) (Author Fuzzy=False and Cell Typist Fuzzy=True): sim=Skipped (missing IDs)
# Max Sim 0
# Comparing nk (CL:0000623) vs cd16+ nk cell (None) (Author Fuzzy=True and Cell Typist Fuzzy=True): sim=Skipped (missing IDs)
# Max Sim 0
# Comparing unk (CL:4052028) vs naive b cell (CL:0000844) (Author Fuzzy=True and Cell Typist Fuzzy=True): sim=0.5925925925925926
# Comparing unk (CL:4052028) vs naive b cell (CL:0000787) (Author Fuzzy=True and Cell Typist Fuzzy=True): sim=0.5925925925925926
# Comparing unk (CL:4052028) vs naive b cell (CL:0000818) (Author Fuzzy=True and Cell Typist Fuzzy=True): sim=0.64
# Comparing unk (CL:4052028) vs naive b cell (CL:0000843) (Author Fuzzy=True and Cell Typist Fuzzy=True): sim=0.5714285714285714
# Comparing unk (CL:4052028) vs naive b cell (CL:0000236) (Author Fuzzy=True and Cell Typist Fuzzy=True): sim=0.7272727272727273
# Comparing unk (CL:4052028) vs naive b cell (CL:0000788) (Author Fuzzy=True and Cell Typist Fuzzy=True): sim=0.5925925925925926
# Max Sim 0.7272727272727273
#    BioClassification              cluster_cell_type  similarity_score
# 0             01_HSC                        HSC/MPP          1.000000
# 1     02_Early.Eryth                           MEMP          0.000000
# 2      03_Late.Eryth                  Mid erythroid          0.750000
# 3      04_Early.Baso                     Mast cells          0.000000
# 4        05_CMP.LMPP                        HSC/MPP          0.000000
# 5           06_CLP.1                    Pro-B cells          0.000000
# 6             07_GMP            Classical monocytes          0.406250
# 7        08_GMP.Neut  Neutrophil-myeloid progenitor          0.000000
# 8             09_pDC                            pDC          0.916667
# 9             10_cDC                            DC2          1.000000
# 10    11_CD14.Mono.1            Classical monocytes          0.000000
# 11    12_CD14.Mono.2            Classical monocytes          0.000000
# 12      13_CD16.Mono        Non-classical monocytes          0.000000
# 13            14_Unk            Classical monocytes          0.517241
# 14          15_CLP.2                    Pro-B cells          0.000000
# 15          16_Pre.B              Small pre-B cells          0.800000
# 16              17_B                  Naive B cells          0.370370
# 17         18_Plasma                   Plasma cells          0.434783
# 18          19_CD8.N    Tcm/Naive cytotoxic T cells          0.000000
# 19         20_CD4.N1       Tcm/Naive helper T cells          0.000000
# 20         21_CD4.N2       Tcm/Naive helper T cells          0.000000
# 21          22_CD4.M       Tcm/Naive helper T cells          0.000000
# 22         23_CD8.EM                     MAIT cells          0.000000
# 23         24_CD8.CM      Tem/Trm cytotoxic T cells          0.000000
# 24             25_NK                 CD16+ NK cells          0.000000
# 25            26_Unk                  Naive B cells          0.727273
#
# Processing: author_vs_Grok3Beta.csv as General Annotation
# Comparing hsc (CL:0000037) vs hsc/mpp (CL:0000037) (fuzzy author =False and fuzzy llm =True): sim=1.0
# Comparing early.eryth (CL:0000549) vs memp (CL:0000050) (fuzzy author =True and fuzzy llm =True): sim=0.6842105263157895
# Comparing late.eryth (CL:0000552) vs mid erythroid (CL:0000038) (fuzzy author =True and fuzzy llm =True): sim=0.7
# Comparing early.baso (None) vs mast cell (CL:0000097) (fuzzy author =False and fuzzy llm =False): sim=0
# Comparing cmp.lmpp (CL:0001059) vs hsc/mpp (CL:0000037) (fuzzy author =True and fuzzy llm =True): sim=0.6842105263157895
# Comparing clp.1 (CL:0000051) vs pro-b cell (CL:0000826) (fuzzy author =True and fuzzy llm =False): sim=0.7222222222222222
# Comparing gmp (CL:0000557) vs classical monocyte (CL:0000860) (fuzzy author =False and fuzzy llm =False): sim=0.3939393939393939
# Comparing gmp.neut (CL:0000557) vs neutrophil-myeloid progenitor (CL:0000775) (fuzzy author =True and fuzzy llm =True): sim=0.39285714285714285
# Comparing pdc (CL:0000784) vs pdc (CL:0000784) (fuzzy author =False and fuzzy llm =False): sim=1.0
# Comparing cdc (CL:0000990) vs dc2 (CL:0000784) (fuzzy author =False and fuzzy llm =False): sim=0.9130434782608695
# Comparing cd14.mono.1 (None) vs classical monocyte (CL:0000860) (fuzzy author =False and fuzzy llm =False): sim=0
# Comparing cd14.mono.2 (None) vs classical monocyte (CL:0000860) (fuzzy author =False and fuzzy llm =False): sim=0
# Comparing cd16.mono (None) vs non-classical monocyte (CL:0000875) (fuzzy author =False and fuzzy llm =False): sim=0
# Comparing unk (CL:4052028) vs classical monocyte (CL:0000860) (fuzzy author =True and fuzzy llm =False): sim=0.5
# Comparing clp.2 (CL:0000051) vs pro-b cell (CL:0000826) (fuzzy author =True and fuzzy llm =False): sim=0.7222222222222222
# Comparing pre.b (CL:0000952) vs small pre-b cell (CL:0002053) (fuzzy author =True and fuzzy llm =False): sim=0.8461538461538461
# Comparing b (CL:0001066) vs naive b cell (CL:0000788) (fuzzy author =True and fuzzy llm =False): sim=0.3125
# Comparing plasma (CL:0000394) vs plasma cell (CL:0000786) (fuzzy author =True and fuzzy llm =False): sim=0.43478260869565216
# Comparing cd8.n (None) vs tcm/naive cytotoxic t cell (CL:0000000) (fuzzy author =False and fuzzy llm =True): sim=0
# Comparing cd4.n1 (None) vs tcm/naive helper t cell (CL:0000000) (fuzzy author =False and fuzzy llm =True): sim=0
# Comparing cd4.n2 (None) vs tcm/naive helper t cell (CL:0000000) (fuzzy author =False and fuzzy llm =True): sim=0
# Comparing cd4.m (None) vs tcm/naive helper t cell (CL:0000000) (fuzzy author =False and fuzzy llm =True): sim=0
# Comparing cd8.em (None) vs mait cell (CL:0000000) (fuzzy author =False and fuzzy llm =True): sim=0
# Comparing cd8.cm (None) vs tem/trm cytotoxic t cell (CL:0000000) (fuzzy author =False and fuzzy llm =True): sim=0
# Comparing nk (CL:0000623) vs cd16+ nk cell (CL:0000000) (fuzzy author =True and fuzzy llm =True): sim=0.3684210526315789
# Comparing unk (CL:4052028) vs naive b cell (CL:0000788) (fuzzy author =True and fuzzy llm =False): sim=0.5925925925925926
#    BioClassification              cluster_cell_type  similarity_score
# 0             01_HSC                        HSC/MPP          1.000000
# 1     02_Early.Eryth                           MEMP          0.684211
# 2      03_Late.Eryth                  Mid erythroid          0.700000
# 3      04_Early.Baso                     Mast cells          0.000000
# 4        05_CMP.LMPP                        HSC/MPP          0.684211
# 5           06_CLP.1                    Pro-B cells          0.722222
# 6             07_GMP            Classical monocytes          0.393939
# 7        08_GMP.Neut  Neutrophil-myeloid progenitor          0.392857
# 8             09_pDC                            pDC          1.000000
# 9             10_cDC                            DC2          0.913043
# 10    11_CD14.Mono.1            Classical monocytes          0.000000
# 11    12_CD14.Mono.2            Classical monocytes          0.000000
# 12      13_CD16.Mono        Non-classical monocytes          0.000000
# 13            14_Unk            Classical monocytes          0.500000
# 14          15_CLP.2                    Pro-B cells          0.722222
# 15          16_Pre.B              Small pre-B cells          0.846154
# 16              17_B                  Naive B cells          0.312500
# 17         18_Plasma                   Plasma cells          0.434783
# 18          19_CD8.N    Tcm/Naive cytotoxic T cells          0.000000
# 19         20_CD4.N1       Tcm/Naive helper T cells          0.000000
# 20         21_CD4.N2       Tcm/Naive helper T cells          0.000000
# 21          22_CD4.M       Tcm/Naive helper T cells          0.000000
# 22         23_CD8.EM                     MAIT cells          0.000000
# 23         24_CD8.CM      Tem/Trm cytotoxic T cells          0.000000
# 24             25_NK                 CD16+ NK cells          0.368421
# 25            26_Unk                  Naive B cells          0.592593
#
# Processing: author_vs_celltypist_Granja_Immune_All_High.csv as High Granularity CellTypist Annotation
# Comparing hsc (CL:0000037) vs hsc/mpp (CL:0000837) (fuzzy author =False and fuzzy llm =False): sim=0.6470588235294118
# Comparing early.eryth (CL:0000549) vs hsc/mpp (CL:0000837) (fuzzy author =True and fuzzy llm =False): sim=0.5555555555555556
# Comparing late.eryth (CL:0000552) vs erythroid (None) (fuzzy author =True and fuzzy llm =True): sim=0
# Comparing early.baso (None) vs mast cell (CL:0000097) (fuzzy author =False and fuzzy llm =True): sim=0
# Comparing cmp.lmpp (CL:0001059) vs hsc/mpp (CL:0000837) (fuzzy author =True and fuzzy llm =False): sim=0.6470588235294118
# Comparing clp.1 (CL:0000051) vs b-cell lineage (None) (fuzzy author =True and fuzzy llm =True): sim=0
# Comparing gmp (CL:0000557) vs promyelocyte (CL:0000836) (fuzzy author =False and fuzzy llm =True): sim=0.56
# Comparing gmp.neut (CL:0000557) vs hsc/mpp (CL:0000837) (fuzzy author =True and fuzzy llm =False): sim=0.5
# Comparing pdc (CL:0000784) vs pdc (CL:0001058) (fuzzy author =False and fuzzy llm =False): sim=0.9166666666666666
# Comparing cdc (CL:0000990) vs dc (CL:0001056) (fuzzy author =False and fuzzy llm =False): sim=0.9130434782608695
# Comparing cd14.mono.1 (None) vs monocyte (CL:0000576) (fuzzy author =False and fuzzy llm =True): sim=0
# Comparing cd14.mono.2 (None) vs monocyte (CL:0000576) (fuzzy author =False and fuzzy llm =True): sim=0
# Comparing cd16.mono (None) vs monocyte (CL:0000576) (fuzzy author =False and fuzzy llm =True): sim=0
# Comparing unk (CL:4052028) vs monocyte (CL:0000576) (fuzzy author =True and fuzzy llm =True): sim=0.5172413793103449
# Comparing clp.2 (CL:0000051) vs b-cell lineage (None) (fuzzy author =True and fuzzy llm =True): sim=0
# Comparing pre.b (CL:0000952) vs b-cell lineage (None) (fuzzy author =True and fuzzy llm =True): sim=0
# Comparing b (CL:0001066) vs b cell (CL:0000236) (fuzzy author =True and fuzzy llm =True): sim=0.37037037037037035
# Comparing plasma (CL:0000394) vs plasma cell (CL:0000786) (fuzzy author =True and fuzzy llm =True): sim=0.43478260869565216
# Comparing cd8.n (None) vs t cell (None) (fuzzy author =False and fuzzy llm =True): sim=0
# Comparing cd4.n1 (None) vs t cell (None) (fuzzy author =False and fuzzy llm =True): sim=0
# Comparing cd4.n2 (None) vs t cell (None) (fuzzy author =False and fuzzy llm =True): sim=0
# Comparing cd4.m (None) vs t cell (None) (fuzzy author =False and fuzzy llm =True): sim=0
# Comparing cd8.em (None) vs t cell (None) (fuzzy author =False and fuzzy llm =True): sim=0
# Comparing cd8.cm (None) vs t cell (None) (fuzzy author =False and fuzzy llm =True): sim=0
# Comparing nk (CL:0000623) vs ilc (CL:0001065) (fuzzy author =True and fuzzy llm =False): sim=0.8947368421052632
# Comparing unk (CL:4052028) vs b cell (CL:0000236) (fuzzy author =True and fuzzy llm =True): sim=0.7272727272727273
#    BioClassification cluster_cell_type  similarity_score
# 0             01_HSC           HSC/MPP          0.647059
# 1     02_Early.Eryth           HSC/MPP          0.555556
# 2      03_Late.Eryth         Erythroid          0.000000
# 3      04_Early.Baso        Mast cells          0.000000
# 4        05_CMP.LMPP           HSC/MPP          0.647059
# 5           06_CLP.1    B-cell lineage          0.000000
# 6             07_GMP     Promyelocytes          0.560000
# 7        08_GMP.Neut           HSC/MPP          0.500000
# 8             09_pDC               pDC          0.916667
# 9             10_cDC                DC          0.913043
# 10    11_CD14.Mono.1         Monocytes          0.000000
# 11    12_CD14.Mono.2         Monocytes          0.000000
# 12      13_CD16.Mono         Monocytes          0.000000
# 13            14_Unk         Monocytes          0.517241
# 14          15_CLP.2    B-cell lineage          0.000000
# 15          16_Pre.B    B-cell lineage          0.000000
# 16              17_B           B cells          0.370370
# 17         18_Plasma      Plasma cells          0.434783
# 18          19_CD8.N           T cells          0.000000
# 19         20_CD4.N1           T cells          0.000000
# 20         21_CD4.N2           T cells          0.000000
# 21          22_CD4.M           T cells          0.000000
# 22         23_CD8.EM           T cells          0.000000
# 23         24_CD8.CM           T cells          0.000000
# 24             25_NK               ILC          0.894737
# 25            26_Unk           B cells          0.727273
#
# Processing: author_vs_celltypist_Granja_Immune_All_Low.csv as Low Granularity CellTypist Annotation
# Comparing hsc (CL:0000236) vs hsc/mpp (CL:0000844) (Author Fuzzy=True and Cell Typist Fuzzy=True): sim=0.782608695652174
# Comparing hsc (CL:0000236) vs hsc/mpp (CL:0000787) (Author Fuzzy=True and Cell Typist Fuzzy=True): sim=0.782608695652174
# Comparing hsc (CL:0000236) vs hsc/mpp (CL:0000818) (Author Fuzzy=True and Cell Typist Fuzzy=True): sim=0.8571428571428571
# Comparing hsc (CL:0000236) vs hsc/mpp (CL:0000843) (Author Fuzzy=True and Cell Typist Fuzzy=True): sim=0.75
# Comparing hsc (CL:0000236) vs hsc/mpp (CL:0000236) (Author Fuzzy=True and Cell Typist Fuzzy=True): sim=1.0
# Comparing hsc (CL:0000236) vs hsc/mpp (CL:0000788) (Author Fuzzy=True and Cell Typist Fuzzy=True): sim=0.782608695652174
# Max Sim 1.0
# Comparing early.eryth (CL:0000549) vs megakaryocyte precursor (None) (Author Fuzzy=True and Cell Typist Fuzzy=True): sim=Skipped (missing IDs)
# Max Sim 0
# Comparing late.eryth (CL:0000552) vs mid erythroid (CL:0000764) (Author Fuzzy=True and Cell Typist Fuzzy=True): sim=0.75
# Max Sim 0.75
# Comparing early.baso (None) vs mast cell (CL:0000097) (Author Fuzzy=False and Cell Typist Fuzzy=True): sim=Skipped (missing IDs)
# Max Sim 0
# Comparing cmp.lmpp (CL:0001059) vs hsc/mpp (None) (Author Fuzzy=True and Cell Typist Fuzzy=True): sim=Skipped (missing IDs)
# Max Sim 0
# Comparing clp.1 (CL:0000051) vs pro-b cell (None) (Author Fuzzy=True and Cell Typist Fuzzy=True): sim=Skipped (missing IDs)
# Max Sim 0
# Comparing gmp (CL:0000557) vs promyelocyte (CL:0000836) (Author Fuzzy=False and Cell Typist Fuzzy=True): sim=0.56
# Max Sim 0.56
# Comparing gmp.neut (CL:0000557) vs cmp (None) (Author Fuzzy=True and Cell Typist Fuzzy=True): sim=Skipped (missing IDs)
# Max Sim 0
# Comparing pdc (CL:0000784) vs pdc (CL:0001058) (Author Fuzzy=False and Cell Typist Fuzzy=True): sim=0.9166666666666666
# Max Sim 0.9166666666666666
# Comparing cdc (CL:0000990) vs dc2 (CL:0000990) (Author Fuzzy=False and Cell Typist Fuzzy=True): sim=1.0
# Comparing cdc (CL:0000990) vs dc2 (CL:0001056) (Author Fuzzy=False and Cell Typist Fuzzy=True): sim=0.9130434782608695
# Comparing cdc (CL:0000990) vs dc2 (CL:0000840) (Author Fuzzy=False and Cell Typist Fuzzy=True): sim=0.88
# Max Sim 1.0
# Comparing cd14.mono.1 (None) vs classical monocyte (CL:0000875) (Author Fuzzy=False and Cell Typist Fuzzy=True): sim=Skipped (missing IDs)
# Comparing cd14.mono.1 (None) vs classical monocyte (CL:0000576) (Author Fuzzy=False and Cell Typist Fuzzy=True): sim=Skipped (missing IDs)
# Comparing cd14.mono.1 (None) vs classical monocyte (CL:0000860) (Author Fuzzy=False and Cell Typist Fuzzy=True): sim=Skipped (missing IDs)
# Max Sim 0
# Comparing cd14.mono.2 (None) vs classical monocyte (CL:0000875) (Author Fuzzy=False and Cell Typist Fuzzy=True): sim=Skipped (missing IDs)
# Comparing cd14.mono.2 (None) vs classical monocyte (CL:0000576) (Author Fuzzy=False and Cell Typist Fuzzy=True): sim=Skipped (missing IDs)
# Comparing cd14.mono.2 (None) vs classical monocyte (CL:0000860) (Author Fuzzy=False and Cell Typist Fuzzy=True): sim=Skipped (missing IDs)
# Max Sim 0
# Comparing cd16.mono (None) vs non-classical monocyte (CL:0000875) (Author Fuzzy=False and Cell Typist Fuzzy=True): sim=Skipped (missing IDs)
# Comparing cd16.mono (None) vs non-classical monocyte (CL:0000576) (Author Fuzzy=False and Cell Typist Fuzzy=True): sim=Skipped (missing IDs)
# Comparing cd16.mono (None) vs non-classical monocyte (CL:0000860) (Author Fuzzy=False and Cell Typist Fuzzy=True): sim=Skipped (missing IDs)
# Max Sim 0
# Comparing unk (CL:4052028) vs classical monocyte (CL:0000875) (Author Fuzzy=True and Cell Typist Fuzzy=True): sim=0.5
# Comparing unk (CL:4052028) vs classical monocyte (CL:0000576) (Author Fuzzy=True and Cell Typist Fuzzy=True): sim=0.5172413793103449
# Comparing unk (CL:4052028) vs classical monocyte (CL:0000860) (Author Fuzzy=True and Cell Typist Fuzzy=True): sim=0.5
# Max Sim 0.5172413793103449
# Comparing clp.2 (CL:0000051) vs pro-b cell (None) (Author Fuzzy=True and Cell Typist Fuzzy=True): sim=Skipped (missing IDs)
# Max Sim 0
# Comparing pre.b (CL:0000952) vs small pre-b cell (CL:0000844) (Author Fuzzy=True and Cell Typist Fuzzy=True): sim=0.7407407407407407
# Comparing pre.b (CL:0000952) vs small pre-b cell (CL:0000787) (Author Fuzzy=True and Cell Typist Fuzzy=True): sim=0.7407407407407407
# Comparing pre.b (CL:0000952) vs small pre-b cell (CL:0000818) (Author Fuzzy=True and Cell Typist Fuzzy=True): sim=0.8
# Comparing pre.b (CL:0000952) vs small pre-b cell (CL:0000843) (Author Fuzzy=True and Cell Typist Fuzzy=True): sim=0.7142857142857143
# Comparing pre.b (CL:0000952) vs small pre-b cell (CL:0000236) (Author Fuzzy=True and Cell Typist Fuzzy=True): sim=0.75
# Comparing pre.b (CL:0000952) vs small pre-b cell (CL:0000788) (Author Fuzzy=True and Cell Typist Fuzzy=True): sim=0.7407407407407407
# Max Sim 0.8
# Comparing b (CL:0001066) vs naive b cell (CL:0000844) (Author Fuzzy=True and Cell Typist Fuzzy=True): sim=0.3125
# Comparing b (CL:0001066) vs naive b cell (CL:0000787) (Author Fuzzy=True and Cell Typist Fuzzy=True): sim=0.3125
# Comparing b (CL:0001066) vs naive b cell (CL:0000818) (Author Fuzzy=True and Cell Typist Fuzzy=True): sim=0.3333333333333333
# Comparing b (CL:0001066) vs naive b cell (CL:0000843) (Author Fuzzy=True and Cell Typist Fuzzy=True): sim=0.30303030303030304
# Comparing b (CL:0001066) vs naive b cell (CL:0000236) (Author Fuzzy=True and Cell Typist Fuzzy=True): sim=0.37037037037037035
# Comparing b (CL:0001066) vs naive b cell (CL:0000788) (Author Fuzzy=True and Cell Typist Fuzzy=True): sim=0.3125
# Max Sim 0.37037037037037035
# Comparing plasma (CL:0000394) vs plasma cell (CL:0000980) (Author Fuzzy=True and Cell Typist Fuzzy=True): sim=0.35714285714285715
# Comparing plasma (CL:0000394) vs plasma cell (CL:0000786) (Author Fuzzy=True and Cell Typist Fuzzy=True): sim=0.43478260869565216
# Max Sim 0.43478260869565216
# Comparing cd8.n (None) vs tcm/naive cytotoxic t cell (CL:0000798) (Author Fuzzy=False and Cell Typist Fuzzy=True): sim=Skipped (missing IDs)
# Comparing cd8.n (None) vs tcm/naive cytotoxic t cell (CL:0000084) (Author Fuzzy=False and Cell Typist Fuzzy=True): sim=Skipped (missing IDs)
# Comparing cd8.n (None) vs tcm/naive cytotoxic t cell (CL:0000934) (Author Fuzzy=False and Cell Typist Fuzzy=True): sim=Skipped (missing IDs)
# Comparing cd8.n (None) vs tcm/naive cytotoxic t cell (CL:0000940) (Author Fuzzy=False and Cell Typist Fuzzy=True): sim=Skipped (missing IDs)
# Comparing cd8.n (None) vs tcm/naive cytotoxic t cell (CL:0000913) (Author Fuzzy=False and Cell Typist Fuzzy=True): sim=Skipped (missing IDs)
# Comparing cd8.n (None) vs tcm/naive cytotoxic t cell (CL:0001062) (Author Fuzzy=False and Cell Typist Fuzzy=True): sim=Skipped (missing IDs)
# Comparing cd8.n (None) vs tcm/naive cytotoxic t cell (CL:0000905) (Author Fuzzy=False and Cell Typist Fuzzy=True): sim=Skipped (missing IDs)
# Comparing cd8.n (None) vs tcm/naive cytotoxic t cell (CL:0000545) (Author Fuzzy=False and Cell Typist Fuzzy=True): sim=Skipped (missing IDs)
# Comparing cd8.n (None) vs tcm/naive cytotoxic t cell (CL:0000814) (Author Fuzzy=False and Cell Typist Fuzzy=True): sim=Skipped (missing IDs)
# Comparing cd8.n (None) vs tcm/naive cytotoxic t cell (CL:0000907) (Author Fuzzy=False and Cell Typist Fuzzy=True): sim=Skipped (missing IDs)
# Comparing cd8.n (None) vs tcm/naive cytotoxic t cell (CL:0000904) (Author Fuzzy=False and Cell Typist Fuzzy=True): sim=Skipped (missing IDs)
# Comparing cd8.n (None) vs tcm/naive cytotoxic t cell (CL:0000815) (Author Fuzzy=False and Cell Typist Fuzzy=True): sim=Skipped (missing IDs)
# Comparing cd8.n (None) vs tcm/naive cytotoxic t cell (CL:0002038) (Author Fuzzy=False and Cell Typist Fuzzy=True): sim=Skipped (missing IDs)
# Comparing cd8.n (None) vs tcm/naive cytotoxic t cell (CL:0000899) (Author Fuzzy=False and Cell Typist Fuzzy=True): sim=Skipped (missing IDs)
# Comparing cd8.n (None) vs tcm/naive cytotoxic t cell (CL:0002430) (Author Fuzzy=False and Cell Typist Fuzzy=True): sim=Skipped (missing IDs)
# Max Sim 0
# Comparing cd4.n1 (None) vs tcm/naive helper t cell (CL:0000798) (Author Fuzzy=False and Cell Typist Fuzzy=True): sim=Skipped (missing IDs)
# Comparing cd4.n1 (None) vs tcm/naive helper t cell (CL:0000084) (Author Fuzzy=False and Cell Typist Fuzzy=True): sim=Skipped (missing IDs)
# Comparing cd4.n1 (None) vs tcm/naive helper t cell (CL:0000934) (Author Fuzzy=False and Cell Typist Fuzzy=True): sim=Skipped (missing IDs)
# Comparing cd4.n1 (None) vs tcm/naive helper t cell (CL:0000940) (Author Fuzzy=False and Cell Typist Fuzzy=True): sim=Skipped (missing IDs)
# Comparing cd4.n1 (None) vs tcm/naive helper t cell (CL:0000913) (Author Fuzzy=False and Cell Typist Fuzzy=True): sim=Skipped (missing IDs)
# Comparing cd4.n1 (None) vs tcm/naive helper t cell (CL:0001062) (Author Fuzzy=False and Cell Typist Fuzzy=True): sim=Skipped (missing IDs)
# Comparing cd4.n1 (None) vs tcm/naive helper t cell (CL:0000905) (Author Fuzzy=False and Cell Typist Fuzzy=True): sim=Skipped (missing IDs)
# Comparing cd4.n1 (None) vs tcm/naive helper t cell (CL:0000545) (Author Fuzzy=False and Cell Typist Fuzzy=True): sim=Skipped (missing IDs)
# ...
# 7        08_GMP.Neut                          CMP          0.608696
# 8             09_pDC                          pDC          1.000000
# 9             10_cDC                          DC2          0.913043
# 10    11_CD14.Mono.1          Classical monocytes          0.000000
# 11    12_CD14.Mono.2          Classical monocytes          0.000000
# 12      13_CD16.Mono      Non-classical monocytes          0.000000
# 13            14_Unk          Classical monocytes          0.500000
# 14          15_CLP.2                  Pro-B cells          0.722222
# 15          16_Pre.B            Small pre-B cells          0.846154
# 16              17_B                Naive B cells          0.312500
# 17         18_Plasma                 Plasma cells          0.434783
# 18          19_CD8.N  Tcm/Naive cytotoxic T cells          0.000000
# 19         20_CD4.N1     Tcm/Naive helper T cells          0.000000
# 20         21_CD4.N2     Tcm/Naive helper T cells          0.000000
# 21          22_CD4.M     Tcm/Naive helper T cells          0.000000
# 22         23_CD8.EM                   MAIT cells          0.000000
# 23         24_CD8.CM    Tem/Trm cytotoxic T cells          0.000000
# 24             25_NK               CD16+ NK cells          0.368421
# 25            26_Unk                Naive B cells          0.592593
#
# Processing: author_vs_Claude3_7Sonnet.csv as General Annotation
# Comparing hsc (CL:0000037) vs hsc/mpp (CL:0000037) (fuzzy author =False and fuzzy llm =True): sim=1.0
# Comparing early.eryth (CL:0000549) vs megakaryocyte precursor (CL:0000556) (fuzzy author =True and fuzzy llm =True): sim=0.6470588235294118
# Comparing late.eryth (CL:0000552) vs mid erythroid (CL:0000038) (fuzzy author =True and fuzzy llm =True): sim=0.7
# Comparing early.baso (None) vs mast cell (CL:0000097) (fuzzy author =False and fuzzy llm =False): sim=0
# Comparing cmp.lmpp (CL:0001059) vs hsc/mpp (CL:0000037) (fuzzy author =True and fuzzy llm =True): sim=0.6842105263157895
# Comparing clp.1 (CL:0000051) vs pro-b cell (CL:0000826) (fuzzy author =True and fuzzy llm =False): sim=0.7222222222222222
# Comparing gmp (CL:0000557) vs promyelocyte (CL:0000836) (fuzzy author =False and fuzzy llm =False): sim=0.56
# Comparing gmp.neut (CL:0000557) vs cmp (CL:0001059) (fuzzy author =True and fuzzy llm =False): sim=0.6086956521739131
# Comparing pdc (CL:0000784) vs pdc (CL:0000784) (fuzzy author =False and fuzzy llm =False): sim=1.0
# Comparing cdc (CL:0000990) vs dc2 (CL:0000784) (fuzzy author =False and fuzzy llm =False): sim=0.9130434782608695
# Comparing cd14.mono.1 (None) vs classical monocyte (CL:0000860) (fuzzy author =False and fuzzy llm =False): sim=0
# Comparing cd14.mono.2 (None) vs classical monocyte (CL:0000860) (fuzzy author =False and fuzzy llm =False): sim=0
# Comparing cd16.mono (None) vs non-classical monocyte (CL:0000875) (fuzzy author =False and fuzzy llm =False): sim=0
# Comparing unk (CL:4052028) vs classical monocyte (CL:0000860) (fuzzy author =True and fuzzy llm =False): sim=0.5
# Comparing clp.2 (CL:0000051) vs pro-b cell (CL:0000826) (fuzzy author =True and fuzzy llm =False): sim=0.7222222222222222
# Comparing pre.b (CL:0000952) vs small pre-b cell (CL:0002053) (fuzzy author =True and fuzzy llm =False): sim=0.8461538461538461
# Comparing b (CL:0001066) vs naive b cell (CL:0000788) (fuzzy author =True and fuzzy llm =False): sim=0.3125
# Comparing plasma (CL:0000394) vs plasma cell (CL:0000786) (fuzzy author =True and fuzzy llm =False): sim=0.43478260869565216
# Comparing cd8.n (None) vs tcm/naive cytotoxic t cell (CL:0000000) (fuzzy author =False and fuzzy llm =True): sim=0
# Comparing cd4.n1 (None) vs tcm/naive helper t cell (CL:0000000) (fuzzy author =False and fuzzy llm =True): sim=0
# Comparing cd4.n2 (None) vs tcm/naive helper t cell (CL:0000000) (fuzzy author =False and fuzzy llm =True): sim=0
# Comparing cd4.m (None) vs tcm/naive helper t cell (CL:0000000) (fuzzy author =False and fuzzy llm =True): sim=0
# Comparing cd8.em (None) vs mait cell (CL:0000000) (fuzzy author =False and fuzzy llm =True): sim=0
# Comparing cd8.cm (None) vs tem/trm cytotoxic t cell (CL:0000000) (fuzzy author =False and fuzzy llm =True): sim=0
# Comparing nk (CL:0000623) vs cd16+ nk cell (CL:0000000) (fuzzy author =True and fuzzy llm =True): sim=0.3684210526315789
# Comparing unk (CL:4052028) vs naive b cell (CL:0000788) (fuzzy author =True and fuzzy llm =False): sim=0.5925925925925926
#    BioClassification            cluster_cell_type  similarity_score
# 0             01_HSC                      HSC/MPP          1.000000
# 1     02_Early.Eryth      Megakaryocyte precursor          0.647059
# 2      03_Late.Eryth                Mid erythroid          0.700000
# 3      04_Early.Baso                   Mast cells          0.000000
# 4        05_CMP.LMPP                      HSC/MPP          0.684211
# 5           06_CLP.1                  Pro-B cells          0.722222
# 6             07_GMP                Promyelocytes          0.560000
# 7        08_GMP.Neut                          CMP          0.608696
# 8             09_pDC                          pDC          1.000000
# 9             10_cDC                          DC2          0.913043
# 10    11_CD14.Mono.1          Classical monocytes          0.000000
# 11    12_CD14.Mono.2          Classical monocytes          0.000000
# 12      13_CD16.Mono      Non-classical monocytes          0.000000
# 13            14_Unk          Classical monocytes          0.500000
# 14          15_CLP.2                  Pro-B cells          0.722222
# 15          16_Pre.B            Small pre-B cells          0.846154
# 16              17_B                Naive B cells          0.312500
# 17         18_Plasma                 Plasma cells          0.434783
# 18          19_CD8.N  Tcm/Naive cytotoxic T cells          0.000000
# 19         20_CD4.N1     Tcm/Naive helper T cells          0.000000
# 20         21_CD4.N2     Tcm/Naive helper T cells          0.000000
# 21          22_CD4.M     Tcm/Naive helper T cells          0.000000
# 22         23_CD8.EM                   MAIT cells          0.000000
# 23         24_CD8.CM    Tem/Trm cytotoxic T cells          0.000000
# 24             25_NK               CD16+ NK cells          0.368421
# 25            26_Unk                Naive B cells          0.592593
#
# Processing: author_vs_gpt4_1mini.csv as General Annotation
# Comparing hsc (CL:0000037) vs hsc/mpp (CL:0000037) (fuzzy author =False and fuzzy llm =True): sim=1.0
# Comparing early.eryth (CL:0000549) vs megakaryocyte precursor (CL:0000556) (fuzzy author =True and fuzzy llm =True): sim=0.6470588235294118
# Comparing late.eryth (CL:0000552) vs mid erythroid (CL:0000038) (fuzzy author =True and fuzzy llm =True): sim=0.7
# Comparing early.baso (None) vs mast cell (CL:0000097) (fuzzy author =False and fuzzy llm =False): sim=0
# Comparing cmp.lmpp (CL:0001059) vs hsc/mpp (CL:0000037) (fuzzy author =True and fuzzy llm =True): sim=0.6842105263157895
# Comparing clp.1 (CL:0000051) vs pro-b cell (CL:0000826) (fuzzy author =True and fuzzy llm =False): sim=0.7222222222222222
# Comparing gmp (CL:0000557) vs promyelocyte (CL:0000836) (fuzzy author =False and fuzzy llm =False): sim=0.56
# Comparing gmp.neut (CL:0000557) vs cmp (CL:0001059) (fuzzy author =True and fuzzy llm =False): sim=0.6086956521739131
# Comparing pdc (CL:0000784) vs pdc (CL:0000784) (fuzzy author =False and fuzzy llm =False): sim=1.0
# Comparing cdc (CL:0000990) vs dc2 (CL:0000784) (fuzzy author =False and fuzzy llm =False): sim=0.9130434782608695
# Comparing cd14.mono.1 (None) vs classical monocyte (CL:0000860) (fuzzy author =False and fuzzy llm =False): sim=0
# Comparing cd14.mono.2 (None) vs classical monocyte (CL:0000860) (fuzzy author =False and fuzzy llm =False): sim=0
# Comparing cd16.mono (None) vs non-classical monocyte (CL:0000875) (fuzzy author =False and fuzzy llm =False): sim=0
# Comparing unk (CL:4052028) vs classical monocyte (CL:0000860) (fuzzy author =True and fuzzy llm =False): sim=0.5
# Comparing clp.2 (CL:0000051) vs pro-b cell (CL:0000826) (fuzzy author =True and fuzzy llm =False): sim=0.7222222222222222
# Comparing pre.b (CL:0000952) vs small pre-b cell (CL:0002053) (fuzzy author =True and fuzzy llm =False): sim=0.8461538461538461
# Comparing b (CL:0001066) vs naive b cell (CL:0000788) (fuzzy author =True and fuzzy llm =False): sim=0.3125
# Comparing plasma (CL:0000394) vs plasma cell (CL:0000786) (fuzzy author =True and fuzzy llm =False): sim=0.43478260869565216
# Comparing cd8.n (None) vs tcm/naive cytotoxic t cell (CL:0000000) (fuzzy author =False and fuzzy llm =True): sim=0
# Comparing cd4.n1 (None) vs tcm/naive helper t cell (CL:0000000) (fuzzy author =False and fuzzy llm =True): sim=0
# Comparing cd4.n2 (None) vs tcm/naive helper t cell (CL:0000000) (fuzzy author =False and fuzzy llm =True): sim=0
# Comparing cd4.m (None) vs tcm/naive helper t cell (CL:0000000) (fuzzy author =False and fuzzy llm =True): sim=0
# Comparing cd8.em (None) vs mait cell (CL:0000000) (fuzzy author =False and fuzzy llm =True): sim=0
# Comparing cd8.cm (None) vs tem/trm cytotoxic t cell (CL:0000000) (fuzzy author =False and fuzzy llm =True): sim=0
# Comparing nk (CL:0000623) vs cd16+ nk cell (CL:0000000) (fuzzy author =True and fuzzy llm =True): sim=0.3684210526315789
# Comparing unk (CL:4052028) vs naive b cell (CL:0000788) (fuzzy author =True and fuzzy llm =False): sim=0.5925925925925926
#    BioClassification            cluster_cell_type  similarity_score
# 0             01_HSC                      HSC/MPP          1.000000
# 1     02_Early.Eryth      Megakaryocyte precursor          0.647059
# 2      03_Late.Eryth                Mid erythroid          0.700000
# 3      04_Early.Baso                   Mast cells          0.000000
# 4        05_CMP.LMPP                      HSC/MPP          0.684211
# 5           06_CLP.1                  Pro-B cells          0.722222
# 6             07_GMP                Promyelocytes          0.560000
# 7        08_GMP.Neut                          CMP          0.608696
# 8             09_pDC                          pDC          1.000000
# 9             10_cDC                          DC2          0.913043
# 10    11_CD14.Mono.1          Classical monocytes          0.000000
# 11    12_CD14.Mono.2          Classical monocytes          0.000000
# 12      13_CD16.Mono      Non-classical monocytes          0.000000
# 13            14_Unk          Classical monocytes          0.500000
# 14          15_CLP.2                  Pro-B cells          0.722222
# 15          16_Pre.B            Small pre-B cells          0.846154
# 16              17_B                Naive B cells          0.312500
# 17         18_Plasma                 Plasma cells          0.434783
# 18          19_CD8.N  Tcm/Naive cytotoxic T cells          0.000000
# 19         20_CD4.N1     Tcm/Naive helper T cells          0.000000
# 20         21_CD4.N2     Tcm/Naive helper T cells          0.000000
# 21          22_CD4.M     Tcm/Naive helper T cells          0.000000
# 22         23_CD8.EM                   MAIT cells          0.000000
# 23         24_CD8.CM    Tem/Trm cytotoxic T cells          0.000000
# 24             25_NK               CD16+ NK cells          0.368421
# 25            26_Unk                Naive B cells          0.592593
#
# Processing: author_vs_Gemini2_5_Acc_Exp.csv as General Annotation
# Comparing hsc (CL:0000037) vs hsc/mpp (CL:0000037) (fuzzy author =False and fuzzy llm =True): sim=1.0
# Comparing early.eryth (CL:0000549) vs megakaryocyte precursor (CL:0000556) (fuzzy author =True and fuzzy llm =True): sim=0.6470588235294118
# Comparing late.eryth (CL:0000552) vs mid erythroid (CL:0000038) (fuzzy author =True and fuzzy llm =True): sim=0.7
# Comparing early.baso (None) vs mast cell (CL:0000097) (fuzzy author =False and fuzzy llm =False): sim=0
# Comparing cmp.lmpp (CL:0001059) vs hsc/mpp (CL:0000037) (fuzzy author =True and fuzzy llm =True): sim=0.6842105263157895
# Comparing clp.1 (CL:0000051) vs pro-b cell (CL:0000826) (fuzzy author =True and fuzzy llm =False): sim=0.7222222222222222
# Comparing gmp (CL:0000557) vs promyelocyte (CL:0000836) (fuzzy author =False and fuzzy llm =False): sim=0.56
# Comparing gmp.neut (CL:0000557) vs cmp (CL:0001059) (fuzzy author =True and fuzzy llm =False): sim=0.6086956521739131
# Comparing pdc (CL:0000784) vs pdc (CL:0000784) (fuzzy author =False and fuzzy llm =False): sim=1.0
# Comparing cdc (CL:0000990) vs dc2 (CL:0000784) (fuzzy author =False and fuzzy llm =False): sim=0.9130434782608695
# Comparing cd14.mono.1 (None) vs classical monocyte (CL:0000860) (fuzzy author =False and fuzzy llm =False): sim=0
# Comparing cd14.mono.2 (None) vs classical monocyte (CL:0000860) (fuzzy author =False and fuzzy llm =False): sim=0
# Comparing cd16.mono (None) vs non-classical monocyte (CL:0000875) (fuzzy author =False and fuzzy llm =False): sim=0
# Comparing unk (CL:4052028) vs classical monocyte (CL:0000860) (fuzzy author =True and fuzzy llm =False): sim=0.5
# Comparing clp.2 (CL:0000051) vs pro-b cell (CL:0000826) (fuzzy author =True and fuzzy llm =False): sim=0.7222222222222222
# Comparing pre.b (CL:0000952) vs small pre-b cell (CL:0002053) (fuzzy author =True and fuzzy llm =False): sim=0.8461538461538461
# Comparing b (CL:0001066) vs naive b cell (CL:0000788) (fuzzy author =True and fuzzy llm =False): sim=0.3125
# Comparing plasma (CL:0000394) vs plasma cell (CL:0000786) (fuzzy author =True and fuzzy llm =False): sim=0.43478260869565216
# Comparing cd8.n (None) vs tcm/naive cytotoxic t cell (CL:0000000) (fuzzy author =False and fuzzy llm =True): sim=0
# Comparing cd4.n1 (None) vs tcm/naive helper t cell (CL:0000000) (fuzzy author =False and fuzzy llm =True): sim=0
# Comparing cd4.n2 (None) vs tcm/naive helper t cell (CL:0000000) (fuzzy author =False and fuzzy llm =True): sim=0
# Comparing cd4.m (None) vs tcm/naive helper t cell (CL:0000000) (fuzzy author =False and fuzzy llm =True): sim=0
# Comparing cd8.em (None) vs mait cell (CL:0000000) (fuzzy author =False and fuzzy llm =True): sim=0
# Comparing cd8.cm (None) vs tem/trm cytotoxic t cell (CL:0000000) (fuzzy author =False and fuzzy llm =True): sim=0
# Comparing nk (CL:0000623) vs cd16+ nk cell (CL:0000000) (fuzzy author =True and fuzzy llm =True): sim=0.3684210526315789
# Comparing unk (CL:4052028) vs naive b cell (CL:0000788) (fuzzy author =True and fuzzy llm =False): sim=0.5925925925925926
#    BioClassification            cluster_cell_type  similarity_score
# 0             01_HSC                      HSC/MPP          1.000000
# 1     02_Early.Eryth      Megakaryocyte precursor          0.647059
# 2      03_Late.Eryth                Mid erythroid          0.700000
# 3      04_Early.Baso                   Mast cells          0.000000
# 4        05_CMP.LMPP                      HSC/MPP          0.684211
# 5           06_CLP.1                  Pro-B cells          0.722222
# 6             07_GMP                Promyelocytes          0.560000
# 7        08_GMP.Neut                          CMP          0.608696
# 8             09_pDC                          pDC          1.000000
# 9             10_cDC                          DC2          0.913043
# 10    11_CD14.Mono.1          Classical monocytes          0.000000
# 11    12_CD14.Mono.2          Classical monocytes          0.000000
# 12      13_CD16.Mono      Non-classical monocytes          0.000000
# 13            14_Unk          Classical monocytes          0.500000
# 14          15_CLP.2                  Pro-B cells          0.722222
# 15          16_Pre.B            Small pre-B cells          0.846154
# 16              17_B                Naive B cells          0.312500
# 17         18_Plasma                 Plasma cells          0.434783
# 18          19_CD8.N  Tcm/Naive cytotoxic T cells          0.000000
# 19         20_CD4.N1     Tcm/Naive helper T cells          0.000000
# 20         21_CD4.N2     Tcm/Naive helper T cells          0.000000
# 21          22_CD4.M     Tcm/Naive helper T cells          0.000000
# 22         23_CD8.EM                   MAIT cells          0.000000
# 23         24_CD8.CM    Tem/Trm cytotoxic T cells          0.000000
# 24             25_NK               CD16+ NK cells          0.368421
# 25            26_Unk                Naive B cells          0.592593
