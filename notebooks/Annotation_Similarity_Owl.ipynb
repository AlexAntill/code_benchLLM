# %% [markdown]
# # Cell Ontology Similarity from CSV
# A notebook that assesses cell similarities from a .csv containing two congruent columns of cell types. Jaccard similarity is calculated using Owlready.
# <br> <b/> N.B. </b> For cell ontology labelling from general sources utilise the upper cell and for cell ontology labelling from CellTypist labelled data use the lower cell. Automatic choice based on file name are the bottom cells.
# <br> <b/> N.B. </b> CellTypist granularity (low and high immune reference) can be changed affceting similarity.

# %%
import pandas as pd
import numpy as np
import os
import glob
import re
from rapidfuzz import process
from owlready2 import get_ontology

# %% [markdown]
# In mapping refernece choose which 'label_to_id_2' depending on cell typist granularity

# %%
## Load Datasets and Mapping Reference (Text to Cell Ontology ID)
# Base Directory of Dataset
base_dir = os.path.expanduser("~/Göran_Karlsson_Lab/benchLLM/Granja_et_al")
input_pattern = os.path.join(base_dir, "author_vs_*.csv")
input_pattern_cellTypist = os.path.join(base_dir, "author_vs_celltypist_*.csv")

## Mapping Reference 
# General 
mapping_df = pd.read_csv(os.path.expanduser("~/Göran_Karlsson_Lab/benchLLM/cell_to_cell_ontology.csv"))
label_to_id = dict(zip(mapping_df['label'], mapping_df['ontology_id']))
label_to_id_ci = {k.lower(): v for k, v in label_to_id.items()} # Remove Case Sentivity

# CellTypist (Switch 'label_to_id_2' Depending on Granularity of CellTypist Annotation)
mapping_df_2 = pd.read_csv(os.path.expanduser("~/Göran_Karlsson_Lab/benchLLM/CellTypist_to_Cell_Ontology.csv"))
#label_to_id_2 = dict(zip(mapping_df_2['Low-hierarchy cell types'], mapping_df_2['Cell Ontology ID'])) # High Granularity
label_to_id_2 = (mapping_df_2
    .groupby('High-hierarchy cell types')['Cell Ontology ID']
    .apply(set)
    .to_dict()
) # Low Granularity
label_to_id_ci_2 = {k.lower(): v for k, v in label_to_id_2.items()}

# %%
# Load Cell Ontology Map (OWL)
print("Loading Cell Ontology (OWL)...")
G = get_ontology("http://purl.obolibrary.org/obo/cl.owl").load()
print("Ontology loaded.")
# Out:
# Loading Cell Ontology (OWL)...
# Ontology loaded.

# %% [markdown]
# General Purpose Cell Ontology Based Similarity

# %%
def get_ancestors(cls):
    return set(cls.ancestors()) if cls else set()

def compute_similarity(id1, id2, onto):
    if id1 is None or id2 is None:
        return 0

    class1 = onto.search_one(iri="*" + id1.replace(":", "_")) # Convert ID1 to be Compatible with OWL
    class2 = onto.search_one(iri="*" + id2.replace(":", "_")) # Convert ID2 to be Compatible with OWL

    if not class1 or not class2:
        return 0

    ancestors1 = get_ancestors(class1)
    ancestors2 = get_ancestors(class2)

    intersection = ancestors1 & ancestors2
    union = ancestors1 | ancestors2

    if not union:
        return 0

    return len(intersection) / len(union)  # Jaccard Similarity

def normalize_label(label):
    label = str(label).lower().strip() # Remove Case Sensitivity
    label = re.sub(r'\s*\(.*?\)', '', label)  # Remove Special Characters
    if label.endswith('s') and len(label) > 1:
        label = label[:-1]
    return label # Remove Plural

def fuzzy_match_label(label, choices, threshold=80):
    if label is None:
        return None
    result = process.extractOne(label, choices)
    if result is None:
        return None
    if len(result) == 2:
        match, score = result
    elif len(result) == 3:
        # Sometimes it returns (match, score, index)
        match, score, _ = result
    else:
        return None
    if score >= threshold:
        return match
    return None # Use Fuzzy Match if Exact Match is Null


for file_path in glob.glob(input_pattern):
    if '_similarity' in os.path.basename(file_path) or '_celltypist_' in os.path.basename(file_path):
        continue

    print(f"\nProcessing: {os.path.basename(file_path)}")
    df = pd.read_csv(file_path)

    colnames = df.columns.tolist()
    if len(colnames) < 2:
        print(f"  Skipping {file_path} — not enough columns.")
        continue

    author_col = colnames[0]
    llm_col = colnames[1]

    similarity_scores = []
    for _, row in df.iterrows():
        author_label = normalize_label(row[author_col])
        llm_label = normalize_label(row[llm_col])

        if author_label in ["nan", "none"] or pd.isna(author_label):
            author_label = None
        if llm_label in ["nan", "none"] or pd.isna(llm_label):
            llm_label = None

        fuzzy_used_author = False
        fuzzy_used_llm = False

        id1 = label_to_id_ci.get(author_label) if author_label else None
        id2 = label_to_id_ci.get(llm_label) if llm_label else None

        if id1 is None and author_label is not None:
            matched_label = fuzzy_match_label(author_label, label_to_id_ci.keys())
            if matched_label:
                fuzzy_used_author = True
            id1 = label_to_id_ci.get(matched_label)

        if id2 is None and llm_label is not None:
            matched_label = fuzzy_match_label(llm_label, label_to_id_ci.keys())
            if matched_label:
                fuzzy_used_llm = True
            id2 = label_to_id_ci.get(matched_label)

        sim = compute_similarity(id1, id2, G)
        print(f"Comparing {author_label} ({id1}) vs {llm_label} ({id2}) (fuzzy author ={fuzzy_used_author} and fuzzy llm ={fuzzy_used_llm}): sim={sim}")
        similarity_scores.append(sim)


    df['similarity_score'] = similarity_scores

    #out_path = file_path.replace(".csv", "_similarity.csv")
    #df.to_csv(out_path, index=False)
    #print(f"  Saved: {os.path.basename(out_path)}")
# Out:
# Processing: author_vs_Gemini2_5.csv
# Comparing 01_hsc (CL:0000037) vs leukemic blast (CL:4070012) (fuzzy author =True and fuzzy llm =True): sim=0.3333333333333333
# Comparing 02_early.eryth (None) vs erythroid progenitor cell (CL:0000038) (fuzzy author =False and fuzzy llm =False): sim=0
# Comparing 03_late.eryth (None) vs erythroid lineage cell (CL:0000764) (fuzzy author =False and fuzzy llm =False): sim=0
# Comparing 04_early.baso (None) vs None (None) (fuzzy author =False and fuzzy llm =False): sim=0
# Comparing 05_cmp.lmpp (CL:0001059) vs mixed-phenotype acute leukemia blast (CL:0000055) (fuzzy author =True and fuzzy llm =True): sim=0.47058823529411764
# Comparing 06_clp.1 (CL:0000051) vs b-lymphoid progenitor (CL:0000050) (fuzzy author =True and fuzzy llm =True): sim=0.8235294117647058
# Comparing 07_gmp (CL:0000557) vs myeloid blast (CL:0000835) (fuzzy author =True and fuzzy llm =True): sim=0.56
# Comparing 08_gmp.neut,"mixed-phenotype acute leukemia blasts, b/myeloid" (None) vs None (None) (fuzzy author =False and fuzzy llm =False): sim=0
# Comparing 09_pdc (CL:0000784) vs plasmacytoid dendritic cell (CL:0001058) (fuzzy author =True and fuzzy llm =False): sim=0.9166666666666666
# Comparing 10_cdc (CL:0000990) vs None (None) (fuzzy author =True and fuzzy llm =False): sim=0
# Comparing 11_cd14.mono.1 (None) vs None (None) (fuzzy author =False and fuzzy llm =False): sim=0
# Comparing 12_cd14.mono.2 (None) vs monocyte (CL:0001054) (fuzzy author =False and fuzzy llm =False): sim=0
# Comparing 13_cd16.mono (None) vs non-classical monocyte (CL:0000875) (fuzzy author =False and fuzzy llm =False): sim=0
# Comparing 14_unk (None) vs monocyte (CL:0001054) (fuzzy author =False and fuzzy llm =False): sim=0
# Comparing 15_clp.2 (CL:0000051) vs pre-b cell (CL:0000817) (fuzzy author =True and fuzzy llm =False): sim=0.38461538461538464
# Comparing 16_pre.b (None) vs pre-b cell (CL:0000817) (fuzzy author =False and fuzzy llm =False): sim=0
# Comparing 17_b (None) vs b cell (CL:0000236) (fuzzy author =False and fuzzy llm =False): sim=0
# Comparing 18_plasma (None) vs None (None) (fuzzy author =False and fuzzy llm =False): sim=0
# Comparing 19_cd8.n (None) vs cd8+ t cell (CL:0000917) (fuzzy author =False and fuzzy llm =True): sim=0
# Comparing 20_cd4.n1 (None) vs t cell (CL:0000084) (fuzzy author =False and fuzzy llm =False): sim=0
# Comparing 21_cd4.n2 (None) vs t cell (CL:0000084) (fuzzy author =False and fuzzy llm =False): sim=0
# Comparing 22_cd4.m (None) vs t cell (CL:0000084) (fuzzy author =False and fuzzy llm =False): sim=0
# Comparing 23_cd8.em (None) vs cytotoxic t lymphocyte (CL:0000910) (fuzzy author =False and fuzzy llm =False): sim=0
# Comparing 24_cd8.cm (None) vs cd8+ t cell (CL:0000917) (fuzzy author =False and fuzzy llm =True): sim=0
# Comparing 25_nk (None) vs natural killer cell (CL:0000623) (fuzzy author =False and fuzzy llm =False): sim=0
# Comparing 26_unk (None) vs b-cell (CL:0000236) (fuzzy author =False and fuzzy llm =False): sim=0
#
# Processing: author_vs_Grok3Beta.csv
# Comparing 01_hsc (CL:0000037) vs leukemic blast (CL:4070012) (fuzzy author =True and fuzzy llm =True): sim=0.3333333333333333
# Comparing 02_early.eryth (None) vs hematopoietic progenitor-like leukemic blast (CL:0000037) (fuzzy author =False and fuzzy llm =True): sim=0
# Comparing 03_late.eryth (None) vs erythroid progenitor (CL:0000038) (fuzzy author =False and fuzzy llm =True): sim=0
# Comparing 04_early.baso (None) vs basophil (CL:0000767) (fuzzy author =False and fuzzy llm =False): sim=0
# Comparing 05_cmp.lmpp (CL:0001059) vs myeloid leukemic blast (CL:0000055) (fuzzy author =True and fuzzy llm =True): sim=0.47058823529411764
# Comparing 06_clp.1 (CL:0000051) vs b-cell precursor (CL:0000000) (fuzzy author =True and fuzzy llm =True): sim=0.4666666666666667
# Comparing 07_gmp (CL:0000557) vs myeloid monocytic blast (CL:0000055) (fuzzy author =True and fuzzy llm =True): sim=0.36363636363636365
# Comparing 08_gmp.neut (CL:0000557) vs myeloblast (CL:0000835) (fuzzy author =True and fuzzy llm =False): sim=0.56
# Comparing 09_pdc (CL:0000784) vs plasmacytoid dendritic cell (CL:0001058) (fuzzy author =True and fuzzy llm =False): sim=0.9166666666666666
# Comparing 10_cdc (CL:0000990) vs monocyte (CL:0001054) (fuzzy author =True and fuzzy llm =False): sim=0.6785714285714286
# Comparing 11_cd14.mono.1 (None) vs monocyte (CL:0001054) (fuzzy author =False and fuzzy llm =False): sim=0
# Comparing 12_cd14.mono.2 (None) vs monocyte (CL:0001054) (fuzzy author =False and fuzzy llm =False): sim=0
# Comparing 13_cd16.mono (None) vs monocyte (CL:0001054) (fuzzy author =False and fuzzy llm =False): sim=0
# Comparing 14_unk (None) vs monocyte (CL:0001054) (fuzzy author =False and fuzzy llm =False): sim=0
# Comparing 15_clp.2 (CL:0000051) vs b-cell precursor (CL:0000000) (fuzzy author =True and fuzzy llm =True): sim=0.4666666666666667
# Comparing 16_pre.b (None) vs b-cell lineage leukemic blast (CL:0000000) (fuzzy author =False and fuzzy llm =True): sim=0
# Comparing 17_b (None) vs b cell (CL:0000236) (fuzzy author =False and fuzzy llm =False): sim=0
# Comparing 18_plasma (None) vs plasma cell (CL:0000786) (fuzzy author =False and fuzzy llm =False): sim=0
# Comparing 19_cd8.n (None) vs cd8-positive t cell (CL:0000917) (fuzzy author =False and fuzzy llm =True): sim=0
# Comparing 20_cd4.n1 (None) vs t cell (CL:0000084) (fuzzy author =False and fuzzy llm =False): sim=0
# Comparing 21_cd4.n2 (None) vs t cell (CL:0000084) (fuzzy author =False and fuzzy llm =False): sim=0
# Comparing 22_cd4.m (None) vs t cell (CL:0000084) (fuzzy author =False and fuzzy llm =False): sim=0
# Comparing 23_cd8.em (None) vs cytotoxic t cell (CL:0000910) (fuzzy author =False and fuzzy llm =False): sim=0
# Comparing 24_cd8.cm (None) vs cytotoxic t cell (CL:0000910) (fuzzy author =False and fuzzy llm =False): sim=0
# Comparing 25_nk (None) vs natural killer cell (CL:0000623) (fuzzy author =False and fuzzy llm =False): sim=0
# Comparing 26_unk (None) vs b cell (CL:0000236) (fuzzy author =False and fuzzy llm =False): sim=0
#
# Processing: author_vs_gpt4_1.csv
# Comparing 01_hsc (CL:0000037) vs None (None) (fuzzy author =True and fuzzy llm =False): sim=0
# Comparing 02_early.eryth (None) vs None (None) (fuzzy author =False and fuzzy llm =False): sim=0
# Comparing 03_late.eryth (None) vs None (None) (fuzzy author =False and fuzzy llm =False): sim=0
# Comparing 04_early.baso (None) vs None (None) (fuzzy author =False and fuzzy llm =False): sim=0
# Comparing 05_cmp.lmpp (CL:0001059) vs None (None) (fuzzy author =True and fuzzy llm =False): sim=0
# Comparing 06_clp.1 (CL:0000051) vs None (None) (fuzzy author =True and fuzzy llm =False): sim=0
# Comparing 07_gmp (CL:0000557) vs None (None) (fuzzy author =True and fuzzy llm =False): sim=0
# Comparing 08_gmp.neut (CL:0000557) vs None (None) (fuzzy author =True and fuzzy llm =False): sim=0
# Comparing 09_pdc (CL:0000784) vs None (None) (fuzzy author =True and fuzzy llm =False): sim=0
# Comparing 10_cdc (CL:0000990) vs None (None) (fuzzy author =True and fuzzy llm =False): sim=0
# Comparing 11_cd14.mono.1 (None) vs None (None) (fuzzy author =False and fuzzy llm =False): sim=0
# Comparing 12_cd14.mono.2 (None) vs classical monocyte (CL:0000860) (fuzzy author =False and fuzzy llm =False): sim=0
# Comparing 13_cd16.mono (None) vs None (None) (fuzzy author =False and fuzzy llm =False): sim=0
# Comparing 14_unk (None) vs classical monocyte (CL:0000860) (fuzzy author =False and fuzzy llm =False): sim=0
# Comparing 15_clp.2 (CL:0000051) vs None (None) (fuzzy author =True and fuzzy llm =False): sim=0
# Comparing 16_pre.b (None) vs None (None) (fuzzy author =False and fuzzy llm =False): sim=0
# Comparing 17_b (None) vs None (None) (fuzzy author =False and fuzzy llm =False): sim=0
# Comparing 18_plasma (None) vs None (None) (fuzzy author =False and fuzzy llm =False): sim=0
# Comparing 19_cd8.n (None) vs None (None) (fuzzy author =False and fuzzy llm =False): sim=0
# Comparing 20_cd4.n1 (None) vs None (None) (fuzzy author =False and fuzzy llm =False): sim=0
# Comparing 21_cd4.n2 (None) vs None (None) (fuzzy author =False and fuzzy llm =False): sim=0
# Comparing 22_cd4.m (None) vs None (None) (fuzzy author =False and fuzzy llm =False): sim=0
# Comparing 23_cd8.em (None) vs None (None) (fuzzy author =False and fuzzy llm =False): sim=0
# Comparing 24_cd8.cm (None) vs None (None) (fuzzy author =False and fuzzy llm =False): sim=0
# Comparing 25_nk (None) vs None (None) (fuzzy author =False and fuzzy llm =False): sim=0
# Comparing 26_unk (None) vs None (None) (fuzzy author =False and fuzzy llm =False): sim=0
#
# Processing: author_vs_Llama4.csv
# Comparing 01_hsc (CL:0000037) vs immature hematopoietic cell (CL:0000000) (fuzzy author =True and fuzzy llm =True): sim=0.4375
# Comparing 02_early.eryth (None) vs hematopoietic stem cell (CL:0000037) (fuzzy author =False and fuzzy llm =False): sim=0
# Comparing 03_late.eryth (None) vs erythrocyte (CL:0000232) (fuzzy author =False and fuzzy llm =False): sim=0
# Comparing 04_early.baso (None) vs myeloid cell (CL:0000763) (fuzzy author =False and fuzzy llm =False): sim=0
# Comparing 05_cmp.lmpp (CL:0001059) vs b cell progenitor (CL:0000826) (fuzzy author =True and fuzzy llm =True): sim=0.6842105263157895
# Comparing 06_clp.1 (CL:0000051) vs b cell (CL:0000236) (fuzzy author =True and fuzzy llm =False): sim=0.43478260869565216
# Comparing 07_gmp (CL:0000557) vs dendritic cell (CL:0001056) (fuzzy author =True and fuzzy llm =False): sim=0.30303030303030304
# Comparing 08_gmp.neut (CL:0000557) vs neutrophil (CL:0000775) (fuzzy author =True and fuzzy llm =False): sim=0.39285714285714285
# Comparing 09_pdc (CL:0000784) vs b cell (CL:0000236) (fuzzy author =True and fuzzy llm =False): sim=0.6
# Comparing 10_cdc (CL:0000990) vs None (None) (fuzzy author =True and fuzzy llm =False): sim=0
# Comparing 11_cd14.mono.1 (None) vs monocyte (CL:0001054) (fuzzy author =False and fuzzy llm =False): sim=0
# Comparing 12_cd14.mono.2 (None) vs myeloid cell (CL:0000763) (fuzzy author =False and fuzzy llm =False): sim=0
# Comparing 13_cd16.mono (None) vs monocyte (CL:0001054) (fuzzy author =False and fuzzy llm =False): sim=0
# Comparing 14_unk (None) vs t cell (CL:0000084) (fuzzy author =False and fuzzy llm =False): sim=0
# Comparing 15_clp.2 (CL:0000051) vs b cell progenitor (CL:0000826) (fuzzy author =True and fuzzy llm =True): sim=0.7222222222222222
# Comparing 16_pre.b (None) vs b cell (CL:0000236) (fuzzy author =False and fuzzy llm =False): sim=0
# Comparing 17_b (None) vs b cell (CL:0000236) (fuzzy author =False and fuzzy llm =False): sim=0
# Comparing 18_plasma (None) vs plasma b cell (CL:0000786) (fuzzy author =False and fuzzy llm =False): sim=0
# Comparing 19_cd8.n (None) vs t cell (CL:0000084) (fuzzy author =False and fuzzy llm =False): sim=0
# Comparing 20_cd4.n1 (None) vs t cell (CL:0000084) (fuzzy author =False and fuzzy llm =False): sim=0
# Comparing 21_cd4.n2 (None) vs cd4-positive t cell (CL:0000492) (fuzzy author =False and fuzzy llm =True): sim=0
# Comparing 22_cd4.m (None) vs t cell (CL:0000084) (fuzzy author =False and fuzzy llm =False): sim=0
# Comparing 23_cd8.em (None) vs t cell (CL:0000084) (fuzzy author =False and fuzzy llm =False): sim=0
# Comparing 24_cd8.cm (None) vs cytotoxic t cell (CL:0000910) (fuzzy author =False and fuzzy llm =False): sim=0
# Comparing 25_nk (None) vs cd8-positive t cell (CL:0000917) (fuzzy author =False and fuzzy llm =True): sim=0
# Comparing 26_unk (None) vs b cell (CL:0000236) (fuzzy author =False and fuzzy llm =False): sim=0
#
# Processing: author_vs_Claude3_7Sonnet.csv
# Comparing 01_hsc (CL:0000037) vs hematopoietic stem and progenitor cell (CL:0011026) (fuzzy author =True and fuzzy llm =True): sim=0.6875
# Comparing 02_early.eryth (None) vs hematopoietic stem and progenitor cell (CL:0011026) (fuzzy author =False and fuzzy llm =True): sim=0
# Comparing 03_late.eryth (None) vs erythroid precursor (CL:0001066) (fuzzy author =False and fuzzy llm =True): sim=0
# Comparing 04_early.baso (None) vs mast cell precursor (CL:0011115) (fuzzy author =False and fuzzy llm =True): sim=0
# Comparing 05_cmp.lmpp (CL:0001059) vs hematopoietic stem and progenitor cell (CL:0011026) (fuzzy author =True and fuzzy llm =True): sim=0.6875
# Comparing 06_clp.1 (CL:0000051) vs b-cell precursor (CL:0000000) (fuzzy author =True and fuzzy llm =True): sim=0.4666666666666667
# Comparing 07_gmp (CL:0000557) vs myeloid progenitor cell (CL:0000839) (fuzzy author =True and fuzzy llm =False): sim=0.5652173913043478
# Comparing 08_gmp.neut (CL:0000557) vs promyelocyte (CL:0000836) (fuzzy author =True and fuzzy llm =False): sim=0.56
# Comparing 09_pdc (CL:0000784) vs plasmacytoid dendritic cell (CL:0001058) (fuzzy author =True and fuzzy llm =False): sim=0.9166666666666666
# Comparing 10_cdc (CL:0000990) vs monocyte (CL:0001054) (fuzzy author =True and fuzzy llm =False): sim=0.6785714285714286
# Comparing 11_cd14.mono.1 (None) vs neutrophil (CL:0000775) (fuzzy author =False and fuzzy llm =False): sim=0
# Comparing 12_cd14.mono.2 (None) vs classical monocyte (CL:0000860) (fuzzy author =False and fuzzy llm =False): sim=0
# Comparing 13_cd16.mono (None) vs non-classical monocyte (CL:0000875) (fuzzy author =False and fuzzy llm =False): sim=0
# Comparing 14_unk (None) vs monocyte (CL:0001054) (fuzzy author =False and fuzzy llm =False): sim=0
# Comparing 15_clp.2 (CL:0000051) vs b cell precursor (CL:0000817) (fuzzy author =True and fuzzy llm =True): sim=0.38461538461538464
# Comparing 16_pre.b (None) vs pre-b cell (CL:0000817) (fuzzy author =False and fuzzy llm =False): sim=0
# Comparing 17_b (None) vs b cell (CL:0000236) (fuzzy author =False and fuzzy llm =False): sim=0
# Comparing 18_plasma (None) vs plasma cell (CL:0000786) (fuzzy author =False and fuzzy llm =False): sim=0
# Comparing 19_cd8.n (None) vs cd8+ t cell (CL:0000917) (fuzzy author =False and fuzzy llm =True): sim=0
# Comparing 20_cd4.n1 (None) vs cd4+ t cell (CL:0000545) (fuzzy author =False and fuzzy llm =True): sim=0
# Comparing 21_cd4.n2 (None) vs cd4+ t cell (CL:0000545) (fuzzy author =False and fuzzy llm =True): sim=0
# Comparing 22_cd4.m (None) vs t cell (CL:0000084) (fuzzy author =False and fuzzy llm =False): sim=0
# Comparing 23_cd8.em (None) vs cd8+ t cell (CL:0000917) (fuzzy author =False and fuzzy llm =True): sim=0
# Comparing 24_cd8.cm (None) vs cd8+ t cell (CL:0000917) (fuzzy author =False and fuzzy llm =True): sim=0
# Comparing 25_nk (None) vs natural killer cell (CL:0000623) (fuzzy author =False and fuzzy llm =False): sim=0
# Comparing 26_unk (None) vs b cell (CL:0000236) (fuzzy author =False and fuzzy llm =False): sim=0
#
# Processing: author_vs_gpt4_1mini.csv
# Comparing 01_hsc (CL:0000037) vs hematopoietic stem and progenitor cell (CL:0011026) (fuzzy author =True and fuzzy llm =True): sim=0.6875
# Comparing 02_early.eryth (None) vs mpal blast with early hematopoietic progenitor phenotype (CL:0000007) (fuzzy author =False and fuzzy llm =True): sim=0
# Comparing 03_late.eryth (None) vs erythroid progenitor cell (CL:0000038) (fuzzy author =False and fuzzy llm =False): sim=0
# Comparing 04_early.baso (None) vs None (None) (fuzzy author =False and fuzzy llm =False): sim=0
# Comparing 05_cmp.lmpp (CL:0001059) vs None (None) (fuzzy author =True and fuzzy llm =False): sim=0
# Comparing 06_clp.1 (CL:0000051) vs None (None) (fuzzy author =True and fuzzy llm =False): sim=0
# Comparing 07_gmp (CL:0000557) vs None (None) (fuzzy author =True and fuzzy llm =False): sim=0
# Comparing 08_gmp.neut (CL:0000557) vs None (None) (fuzzy author =True and fuzzy llm =False): sim=0
# Comparing 09_pdc (CL:0000784) vs None (None) (fuzzy author =True and fuzzy llm =False): sim=0
# Comparing 10_cdc (CL:0000990) vs monocyte / macrophage (CL:0000394) (fuzzy author =True and fuzzy llm =True): sim=0.38461538461538464
# Comparing 11_cd14.mono.1 (None) vs monocyte (CL:0001054) (fuzzy author =False and fuzzy llm =False): sim=0
# Comparing 12_cd14.mono.2 (None) vs monocyte (CL:0001054) (fuzzy author =False and fuzzy llm =False): sim=0
# Comparing 13_cd16.mono (None) vs monocyte (CL:0001054) (fuzzy author =False and fuzzy llm =False): sim=0
# Comparing 14_unk (None) vs monocyte/macrophage (CL:0000394) (fuzzy author =False and fuzzy llm =True): sim=0
# Comparing 15_clp.2 (CL:0000051) vs b cell progenitor (CL:0000826) (fuzzy author =True and fuzzy llm =True): sim=0.7222222222222222
# Comparing 16_pre.b (None) vs b cell (CL:0000236) (fuzzy author =False and fuzzy llm =False): sim=0
# Comparing 17_b (None) vs b cell (CL:0000236) (fuzzy author =False and fuzzy llm =False): sim=0
# Comparing 18_plasma (None) vs plasma cell (CL:0000786) (fuzzy author =False and fuzzy llm =False): sim=0
# Comparing 19_cd8.n (None) vs cd8-positive t cell (CL:0000917) (fuzzy author =False and fuzzy llm =True): sim=0
# Comparing 20_cd4.n1 (None) vs t lymphocyte (CL:0000084) (fuzzy author =False and fuzzy llm =False): sim=0
# Comparing 21_cd4.n2 (None) vs t cell (CL:0000084) (fuzzy author =False and fuzzy llm =False): sim=0
# Comparing 22_cd4.m (None) vs t cell (CL:0000084) (fuzzy author =False and fuzzy llm =False): sim=0
# Comparing 23_cd8.em (None) vs cytotoxic t cell (CL:0000910) (fuzzy author =False and fuzzy llm =False): sim=0
# Comparing 24_cd8.cm (None) vs cytotoxic cd8-positive t cell (CL:0000000) (fuzzy author =False and fuzzy llm =True): sim=0
# Comparing 25_nk (None) vs None (None) (fuzzy author =False and fuzzy llm =False): sim=0
# Comparing 26_unk (None) vs b cell (CL:0000236) (fuzzy author =False and fuzzy llm =False): sim=0
#
# Processing: author_vs_Gemini2_5_Acc_Exp.csv
# Comparing hematopoietic stem cell (CL:0000037) vs leukemic blast (CL:4070012) (fuzzy author =False and fuzzy llm =True): sim=0.3333333333333333
# Comparing early erythroid cell (CL:0000000) vs erythroid progenitor cell (CL:0000038) (fuzzy author =True and fuzzy llm =False): sim=0.3888888888888889
# Comparing late erythroid cell (CL:0000000) vs erythroid lineage cell (CL:0000764) (fuzzy author =True and fuzzy llm =False): sim=0.5833333333333334
# Comparing early basophil cell (CL:0000000) vs None (None) (fuzzy author =True and fuzzy llm =False): sim=0
# Comparing common myeloid progenitor / lymphoid-primed multipotent progenitor (CL:0000049) vs mixed-phenotype acute leukemia blast (CL:0000055) (fuzzy author =True and fuzzy llm =True): sim=0.4666666666666667
# Comparing common lymphoid progenitor (CL:0000051) vs b-lymphoid progenitor (CL:0000050) (fuzzy author =False and fuzzy llm =True): sim=0.8235294117647058
# Comparing granulocyte-monocyte progenitor (CL:0000557) vs myeloid blast (CL:0000835) (fuzzy author =True and fuzzy llm =True): sim=0.56
# Comparing granulocyte-monocyte progenitors / neutrophil,"mixed-phenotype acute leukemia blasts, b/myeloid" (CL:0000557) vs None (None) (fuzzy author =True and fuzzy llm =False): sim=0
# Comparing plasmacytoid dendritic cell (CL:0001058) vs plasmacytoid dendritic cell (CL:0001058) (fuzzy author =False and fuzzy llm =False): sim=1.0
# Comparing classical dendritic cell (CL:0000000) vs None (None) (fuzzy author =True and fuzzy llm =False): sim=0
# Comparing cd14+ monocyte cell (CL:0000000) vs None (None) (fuzzy author =True and fuzzy llm =False): sim=0
# Comparing cd14+ monocyte cell (CL:0000000) vs monocyte (CL:0001054) (fuzzy author =True and fuzzy llm =False): sim=0.28
# Comparing cd16+ monocyte cell (CL:0002397) vs non-classical monocyte (CL:0000875) (fuzzy author =True and fuzzy llm =False): sim=0.8888888888888888
# Comparing unknown (None) vs monocyte (CL:0001054) (fuzzy author =False and fuzzy llm =False): sim=0
# Comparing common lymphoid progenitor (CL:0000051) vs pre-b cell (CL:0000817) (fuzzy author =False and fuzzy llm =False): sim=0.38461538461538464
# Comparing pre b-cell progenitor (CL:0000826) vs pre-b cell (CL:0000817) (fuzzy author =True and fuzzy llm =False): sim=0.37037037037037035
# Comparing b cell (CL:0000236) vs b cell (CL:0000236) (fuzzy author =False and fuzzy llm =False): sim=1.0
# Comparing plasma cell (CL:0000786) vs None (None) (fuzzy author =False and fuzzy llm =False): sim=0
# Comparing cd8+ naive cell (CL:0000900) vs cd8+ t cell (CL:0000917) (fuzzy author =True and fuzzy llm =True): sim=0.84
# Comparing cd4+ naive cell (CL:0000895) vs t cell (CL:0000084) (fuzzy author =True and fuzzy llm =False): sim=0.7391304347826086
# Comparing cd4+ naive cell (CL:0000895) vs t cell (CL:0000084) (fuzzy author =True and fuzzy llm =False): sim=0.7391304347826086
# Comparing cd4+ memory cell (CL:0000000) vs t cell (CL:0000084) (fuzzy author =True and fuzzy llm =False): sim=0.4117647058823529
# Comparing cd8+ effector memory cell (CL:0000913) vs cytotoxic t lymphocyte (CL:0000910) (fuzzy author =True and fuzzy llm =False): sim=0.6666666666666666
# Comparing cd8+ central memory cell (CL:0000907) vs cd8+ t cell (CL:0000917) (fuzzy author =True and fuzzy llm =True): sim=0.7777777777777778
# Comparing natural killer cell (CL:0000623) vs natural killer cell (CL:0000623) (fuzzy author =False and fuzzy llm =False): sim=1.0
# Comparing unknown (None) vs b-cell (CL:0000236) (fuzzy author =False and fuzzy llm =False): sim=0

# %% [markdown]
# CellTypist Annotated Cell Ontology Based Similarity

# %%
for file_path in glob.glob(input_pattern_cellTypist):
    if '_similarity' in os.path.basename(file_path):
        continue

    print(f"\nProcessing: {os.path.basename(file_path)}")
    df = pd.read_csv(file_path)

    colnames = df.columns.tolist()
    if len(colnames) < 2:
        print(f"  Skipping {file_path} — not enough columns.")
        continue

    author_col = colnames[0]
    cellTypist_col = colnames[1]

    similarity_scores = []

    for _, row in df.iterrows():
        author_label = normalize_label(row[author_col])
        cellTypist_label = normalize_label(row[cellTypist_col])

        fuzzy_used = False

        ids1 = label_to_id_ci.get(author_label)
        ids2 = label_to_id_ci_2.get(cellTypist_label)

        # Fuzzy match fallback if not found
        if not ids1 and author_label:
            match = fuzzy_match_label(author_label, label_to_id_ci.keys())
            if match:
                ids1 = label_to_id_ci[match]
                fuzzy_used_author = True

        if not ids2 and llm_label:
            match = fuzzy_match_label(cellTypist_label, label_to_id_ci_2.keys())
            if match:
                ids2 = label_to_id_ci_2[match]
                fuzzy_used_cellTypist = True

        # Normalize to sets
        if isinstance(ids1, str):
            ids1 = {ids1}
        if isinstance(ids2, str):
            ids2 = {ids2}

        max_sim = 0
        if ids1 and ids2:
            for id1 in ids1:
                for id2 in ids2:
                    sim = compute_similarity(id1, id2, G)
                    print(f"Comparing {author_label} ({id1}) vs {cellTypist_label} ({id2}) (Author Fuzzy={fuzzy_used_author} and Cell Typist Fuzzy={fuzzy_used_cellTypist}): sim={sim}")
                    if sim > max_sim:
                        max_sim = sim
                       
        else:
            print(f"Skipping row: {author_label} or {cellTypist_label} not found.")
        
        print(f"Max Sim {max_sim}") 
        similarity_scores.append(max_sim)

    df['similarity_score'] = similarity_scores
    #out_path = file_path.replace(".csv", "_similarity.csv")
    #df.to_csv(out_path, index=False)
    #print(f"  Saved: {os.path.basename(out_path)}")
# Out:
# Processing: author_vs_celltypist_Roy_Immune_All_High_new.csv
# Comparing 01_hsc (CL:0000037) vs hsc/mpp (CL:0000049) (Author Fuzzy=True and Cell Typist Fuzzy=True): sim=0.6111111111111112
# Comparing 01_hsc (CL:0000037) vs hsc/mpp (CL:0000557) (Author Fuzzy=True and Cell Typist Fuzzy=True): sim=0.5416666666666666
# Comparing 01_hsc (CL:0000037) vs hsc/mpp (CL:0000837) (Author Fuzzy=True and Cell Typist Fuzzy=True): sim=0.6470588235294118
# Comparing 01_hsc (CL:0000037) vs hsc/mpp (CL:0000936) (Author Fuzzy=True and Cell Typist Fuzzy=True): sim=0.7222222222222222
# Comparing 01_hsc (CL:0000037) vs hsc/mpp (CL:0000834) (Author Fuzzy=True and Cell Typist Fuzzy=True): sim=0.6190476190476191
# Comparing 01_hsc (CL:0000037) vs hsc/mpp (CL:0000050) (Author Fuzzy=True and Cell Typist Fuzzy=True): sim=0.6842105263157895
# Max Sim 0.7222222222222222
# Skipping row: 02_early.eryth or memp not found.
# Max Sim 0
# Skipping row: 03_late.eryth or mid erythroid not found.
# Max Sim 0
# Skipping row: 04_early.baso or mast cell not found.
# Max Sim 0
# Comparing 05_cmp.lmpp (CL:0001059) vs hsc/mpp (CL:0000049) (Author Fuzzy=True and Cell Typist Fuzzy=True): sim=0.8125
# Comparing 05_cmp.lmpp (CL:0001059) vs hsc/mpp (CL:0000557) (Author Fuzzy=True and Cell Typist Fuzzy=True): sim=0.6086956521739131
# Comparing 05_cmp.lmpp (CL:0001059) vs hsc/mpp (CL:0000837) (Author Fuzzy=True and Cell Typist Fuzzy=True): sim=0.6470588235294118
# Comparing 05_cmp.lmpp (CL:0001059) vs hsc/mpp (CL:0000936) (Author Fuzzy=True and Cell Typist Fuzzy=True): sim=0.7222222222222222
# Comparing 05_cmp.lmpp (CL:0001059) vs hsc/mpp (CL:0000834) (Author Fuzzy=True and Cell Typist Fuzzy=True): sim=0.6190476190476191
# Comparing 05_cmp.lmpp (CL:0001059) vs hsc/mpp (CL:0000050) (Author Fuzzy=True and Cell Typist Fuzzy=True): sim=0.7777777777777778
# Max Sim 0.8125
# Skipping row: 06_clp.1 or pro-b cell not found.
# Max Sim 0
# Comparing 07_gmp (CL:0000557) vs classical monocyte (CL:0000875) (Author Fuzzy=True and Cell Typist Fuzzy=True): sim=0.3939393939393939
# Comparing 07_gmp (CL:0000557) vs classical monocyte (CL:0000576) (Author Fuzzy=True and Cell Typist Fuzzy=True): sim=0.40625
# Comparing 07_gmp (CL:0000557) vs classical monocyte (CL:0000860) (Author Fuzzy=True and Cell Typist Fuzzy=True): sim=0.3939393939393939
# Max Sim 0.40625
# Skipping row: 08_gmp.neut or neutrophil-myeloid progenitor not found.
# Max Sim 0
# Comparing 09_pdc (CL:0000784) vs pdc (CL:0001058) (Author Fuzzy=True and Cell Typist Fuzzy=True): sim=0.9166666666666666
# Max Sim 0.9166666666666666
# Comparing 10_cdc (CL:0000990) vs dc2 (CL:0000990) (Author Fuzzy=True and Cell Typist Fuzzy=True): sim=1.0
# Comparing 10_cdc (CL:0000990) vs dc2 (CL:0001056) (Author Fuzzy=True and Cell Typist Fuzzy=True): sim=0.9130434782608695
# Comparing 10_cdc (CL:0000990) vs dc2 (CL:0000840) (Author Fuzzy=True and Cell Typist Fuzzy=True): sim=0.88
# Max Sim 1.0
# Skipping row: 11_cd14.mono.1 or classical monocyte not found.
# Max Sim 0
# Skipping row: 12_cd14.mono.2 or classical monocyte not found.
# Max Sim 0
# Skipping row: 13_cd16.mono or non-classical monocyte not found.
# Max Sim 0
# Skipping row: 14_unk or classical monocyte not found.
# Max Sim 0
# Skipping row: 15_clp.2 or pro-b cell not found.
# Max Sim 0
# Skipping row: 16_pre.b or small pre-b cell not found.
# Max Sim 0
# Skipping row: 17_b or naive b cell not found.
# Max Sim 0
# Skipping row: 18_plasma or plasma cell not found.
# Max Sim 0
# Skipping row: 19_cd8.n or tcm/naive cytotoxic t cell not found.
# Max Sim 0
# Skipping row: 20_cd4.n1 or tcm/naive helper t cell not found.
# Max Sim 0
# Skipping row: 21_cd4.n2 or tcm/naive helper t cell not found.
# Max Sim 0
# Skipping row: 22_cd4.m or tcm/naive helper t cell not found.
# Max Sim 0
# Skipping row: 23_cd8.em or mait cell not found.
# Max Sim 0
# Skipping row: 24_cd8.cm or tem/trm cytotoxic t cell not found.
# Max Sim 0
# Skipping row: 25_nk or cd16+ nk cell not found.
# Max Sim 0
# Skipping row: 26_unk or naive b cell not found.
# Max Sim 0
#
# Processing: author_vs_celltypist_Roy_Immune_All_Low_new.csv
# Comparing 01_hsc (CL:0000037) vs hsc/mpp (CL:0000049) (Author Fuzzy=True and Cell Typist Fuzzy=True): sim=0.6111111111111112
# Comparing 01_hsc (CL:0000037) vs hsc/mpp (CL:0000557) (Author Fuzzy=True and Cell Typist Fuzzy=True): sim=0.5416666666666666
# Comparing 01_hsc (CL:0000037) vs hsc/mpp (CL:0000837) (Author Fuzzy=True and Cell Typist Fuzzy=True): sim=0.6470588235294118
# Comparing 01_hsc (CL:0000037) vs hsc/mpp (CL:0000936) (Author Fuzzy=True and Cell Typist Fuzzy=True): sim=0.7222222222222222
# Comparing 01_hsc (CL:0000037) vs hsc/mpp (CL:0000834) (Author Fuzzy=True and Cell Typist Fuzzy=True): sim=0.6190476190476191
# Comparing 01_hsc (CL:0000037) vs hsc/mpp (CL:0000050) (Author Fuzzy=True and Cell Typist Fuzzy=True): sim=0.6842105263157895
# Max Sim 0.7222222222222222
# Skipping row: 02_early.eryth or memp not found.
# Max Sim 0
# Skipping row: 03_late.eryth or mid erythroid not found.
# Max Sim 0
# Skipping row: 04_early.baso or mast cell not found.
# Max Sim 0
# Comparing 05_cmp.lmpp (CL:0001059) vs hsc/mpp (CL:0000049) (Author Fuzzy=True and Cell Typist Fuzzy=True): sim=0.8125
# Comparing 05_cmp.lmpp (CL:0001059) vs hsc/mpp (CL:0000557) (Author Fuzzy=True and Cell Typist Fuzzy=True): sim=0.6086956521739131
# Comparing 05_cmp.lmpp (CL:0001059) vs hsc/mpp (CL:0000837) (Author Fuzzy=True and Cell Typist Fuzzy=True): sim=0.6470588235294118
# Comparing 05_cmp.lmpp (CL:0001059) vs hsc/mpp (CL:0000936) (Author Fuzzy=True and Cell Typist Fuzzy=True): sim=0.7222222222222222
# Comparing 05_cmp.lmpp (CL:0001059) vs hsc/mpp (CL:0000834) (Author Fuzzy=True and Cell Typist Fuzzy=True): sim=0.6190476190476191
# Comparing 05_cmp.lmpp (CL:0001059) vs hsc/mpp (CL:0000050) (Author Fuzzy=True and Cell Typist Fuzzy=True): sim=0.7777777777777778
# Max Sim 0.8125
# Skipping row: 06_clp.1 or pro-b cell not found.
# Max Sim 0
# Comparing 07_gmp (CL:0000557) vs classical monocyte (CL:0000875) (Author Fuzzy=True and Cell Typist Fuzzy=True): sim=0.3939393939393939
# Comparing 07_gmp (CL:0000557) vs classical monocyte (CL:0000576) (Author Fuzzy=True and Cell Typist Fuzzy=True): sim=0.40625
# Comparing 07_gmp (CL:0000557) vs classical monocyte (CL:0000860) (Author Fuzzy=True and Cell Typist Fuzzy=True): sim=0.3939393939393939
# Max Sim 0.40625
# Skipping row: 08_gmp.neut or neutrophil-myeloid progenitor not found.
# Max Sim 0
# Comparing 09_pdc (CL:0000784) vs pdc (CL:0001058) (Author Fuzzy=True and Cell Typist Fuzzy=True): sim=0.9166666666666666
# Max Sim 0.9166666666666666
# Comparing 10_cdc (CL:0000990) vs dc2 (CL:0000990) (Author Fuzzy=True and Cell Typist Fuzzy=True): sim=1.0
# Comparing 10_cdc (CL:0000990) vs dc2 (CL:0001056) (Author Fuzzy=True and Cell Typist Fuzzy=True): sim=0.9130434782608695
# Comparing 10_cdc (CL:0000990) vs dc2 (CL:0000840) (Author Fuzzy=True and Cell Typist Fuzzy=True): sim=0.88
# Max Sim 1.0
# Skipping row: 11_cd14.mono.1 or classical monocyte not found.
# Max Sim 0
# Skipping row: 12_cd14.mono.2 or classical monocyte not found.
# Max Sim 0
# Skipping row: 13_cd16.mono or non-classical monocyte not found.
# Max Sim 0
# Skipping row: 14_unk or classical monocyte not found.
# Max Sim 0
# Skipping row: 15_clp.2 or pro-b cell not found.
# Max Sim 0
# Skipping row: 16_pre.b or small pre-b cell not found.
# Max Sim 0
# Skipping row: 17_b or naive b cell not found.
# Max Sim 0
# Skipping row: 18_plasma or plasma cell not found.
# Max Sim 0
# Skipping row: 19_cd8.n or tcm/naive cytotoxic t cell not found.
# Max Sim 0
# Skipping row: 20_cd4.n1 or tcm/naive helper t cell not found.
# Max Sim 0
# Skipping row: 21_cd4.n2 or tcm/naive helper t cell not found.
# Max Sim 0
# Skipping row: 22_cd4.m or tcm/naive helper t cell not found.
# Max Sim 0
# Skipping row: 23_cd8.em or mait cell not found.
# Max Sim 0
# Skipping row: 24_cd8.cm or tem/trm cytotoxic t cell not found.
# Max Sim 0
# Skipping row: 25_nk or cd16+ nk cell not found.
# Max Sim 0
# Skipping row: 26_unk or naive b cell not found.
# Max Sim 0
#
# Processing: author_vs_celltypist_Granja_Immune_All_High.csv
# Comparing 01_hsc (CL:0000037) vs hsc/mpp (CL:0000049) (Author Fuzzy=True and Cell Typist Fuzzy=True): sim=0.6111111111111112
# Comparing 01_hsc (CL:0000037) vs hsc/mpp (CL:0000557) (Author Fuzzy=True and Cell Typist Fuzzy=True): sim=0.5416666666666666
# Comparing 01_hsc (CL:0000037) vs hsc/mpp (CL:0000837) (Author Fuzzy=True and Cell Typist Fuzzy=True): sim=0.6470588235294118
# Comparing 01_hsc (CL:0000037) vs hsc/mpp (CL:0000936) (Author Fuzzy=True and Cell Typist Fuzzy=True): sim=0.7222222222222222
# Comparing 01_hsc (CL:0000037) vs hsc/mpp (CL:0000834) (Author Fuzzy=True and Cell Typist Fuzzy=True): sim=0.6190476190476191
# Comparing 01_hsc (CL:0000037) vs hsc/mpp (CL:0000050) (Author Fuzzy=True and Cell Typist Fuzzy=True): sim=0.6842105263157895
# Max Sim 0.7222222222222222
# Skipping row: 02_early.eryth or hsc/mpp not found.
# Max Sim 0
# Skipping row: 03_late.eryth or erythroid not found.
# Max Sim 0
# Skipping row: 04_early.baso or mast cell not found.
# Max Sim 0
# Comparing 05_cmp.lmpp (CL:0001059) vs hsc/mpp (CL:0000049) (Author Fuzzy=True and Cell Typist Fuzzy=True): sim=0.8125
# Comparing 05_cmp.lmpp (CL:0001059) vs hsc/mpp (CL:0000557) (Author Fuzzy=True and Cell Typist Fuzzy=True): sim=0.6086956521739131
# Comparing 05_cmp.lmpp (CL:0001059) vs hsc/mpp (CL:0000837) (Author Fuzzy=True and Cell Typist Fuzzy=True): sim=0.6470588235294118
# Comparing 05_cmp.lmpp (CL:0001059) vs hsc/mpp (CL:0000936) (Author Fuzzy=True and Cell Typist Fuzzy=True): sim=0.7222222222222222
# Comparing 05_cmp.lmpp (CL:0001059) vs hsc/mpp (CL:0000834) (Author Fuzzy=True and Cell Typist Fuzzy=True): sim=0.6190476190476191
# Comparing 05_cmp.lmpp (CL:0001059) vs hsc/mpp (CL:0000050) (Author Fuzzy=True and Cell Typist Fuzzy=True): sim=0.7777777777777778
# Max Sim 0.8125
# Comparing 06_clp.1 (CL:0000051) vs b-cell lineage (CL:0000826) (Author Fuzzy=True and Cell Typist Fuzzy=True): sim=0.7222222222222222
# Comparing 06_clp.1 (CL:0000051) vs b-cell lineage (CL:0002046) (Author Fuzzy=True and Cell Typist Fuzzy=True): sim=0.6842105263157895
# Comparing 06_clp.1 (CL:0000051) vs b-cell lineage (CL:0000817) (Author Fuzzy=True and Cell Typist Fuzzy=True): sim=0.38461538461538464
# Max Sim 0.7222222222222222
# Comparing 07_gmp (CL:0000557) vs promyelocyte (CL:0000836) (Author Fuzzy=True and Cell Typist Fuzzy=True): sim=0.56
# Max Sim 0.56
# Comparing 08_gmp.neut (CL:0000557) vs hsc/mpp (CL:0000049) (Author Fuzzy=True and Cell Typist Fuzzy=True): sim=0.5454545454545454
# Comparing 08_gmp.neut (CL:0000557) vs hsc/mpp (CL:0000557) (Author Fuzzy=True and Cell Typist Fuzzy=True): sim=1.0
# Comparing 08_gmp.neut (CL:0000557) vs hsc/mpp (CL:0000837) (Author Fuzzy=True and Cell Typist Fuzzy=True): sim=0.5
# Comparing 08_gmp.neut (CL:0000557) vs hsc/mpp (CL:0000936) (Author Fuzzy=True and Cell Typist Fuzzy=True): sim=0.5652173913043478
# Comparing 08_gmp.neut (CL:0000557) vs hsc/mpp (CL:0000834) (Author Fuzzy=True and Cell Typist Fuzzy=True): sim=0.56
# Comparing 08_gmp.neut (CL:0000557) vs hsc/mpp (CL:0000050) (Author Fuzzy=True and Cell Typist Fuzzy=True): sim=0.6818181818181818
# Max Sim 1.0
# Comparing 09_pdc (CL:0000784) vs pdc (CL:0001058) (Author Fuzzy=True and Cell Typist Fuzzy=True): sim=0.9166666666666666
# Max Sim 0.9166666666666666
# Comparing 10_cdc (CL:0000990) vs dc (CL:0000990) (Author Fuzzy=True and Cell Typist Fuzzy=True): sim=1.0
# Comparing 10_cdc (CL:0000990) vs dc (CL:0001056) (Author Fuzzy=True and Cell Typist Fuzzy=True): sim=0.9130434782608695
# Comparing 10_cdc (CL:0000990) vs dc (CL:0000840) (Author Fuzzy=True and Cell Typist Fuzzy=True): sim=0.88
# Max Sim 1.0
# Skipping row: 11_cd14.mono.1 or monocyte not found.
# Max Sim 0
# Skipping row: 12_cd14.mono.2 or monocyte not found.
# Max Sim 0
# Skipping row: 13_cd16.mono or monocyte not found.
# Max Sim 0
# Skipping row: 14_unk or monocyte not found.
# Max Sim 0
# Comparing 15_clp.2 (CL:0000051) vs b-cell lineage (CL:0000826) (Author Fuzzy=True and Cell Typist Fuzzy=True): sim=0.7222222222222222
# Comparing 15_clp.2 (CL:0000051) vs b-cell lineage (CL:0002046) (Author Fuzzy=True and Cell Typist Fuzzy=True): sim=0.6842105263157895
# Comparing 15_clp.2 (CL:0000051) vs b-cell lineage (CL:0000817) (Author Fuzzy=True and Cell Typist Fuzzy=True): sim=0.38461538461538464
# Max Sim 0.7222222222222222
# Skipping row: 16_pre.b or b-cell lineage not found.
# Max Sim 0
# Skipping row: 17_b or b cell not found.
# Max Sim 0
# Skipping row: 18_plasma or plasma cell not found.
# Max Sim 0
# Skipping row: 19_cd8.n or t cell not found.
# Max Sim 0
# Skipping row: 20_cd4.n1 or t cell not found.
# Max Sim 0
# Skipping row: 21_cd4.n2 or t cell not found.
# Max Sim 0
# Skipping row: 22_cd4.m or t cell not found.
# Max Sim 0
# Skipping row: 23_cd8.em or t cell not found.
# Max Sim 0
# Skipping row: 24_cd8.cm or t cell not found.
# Max Sim 0
# Skipping row: 25_nk or ilc not found.
# Max Sim 0
# Skipping row: 26_unk or b cell not found.
# Max Sim 0
#
# Processing: author_vs_celltypist_Granja_Immune_All_Low.csv
# Comparing 01_hsc (CL:0000037) vs hsc/mpp (CL:0000049) (Author Fuzzy=True and Cell Typist Fuzzy=True): sim=0.6111111111111112
# Comparing 01_hsc (CL:0000037) vs hsc/mpp (CL:0000557) (Author Fuzzy=True and Cell Typist Fuzzy=True): sim=0.5416666666666666
# Comparing 01_hsc (CL:0000037) vs hsc/mpp (CL:0000837) (Author Fuzzy=True and Cell Typist Fuzzy=True): sim=0.6470588235294118
# Comparing 01_hsc (CL:0000037) vs hsc/mpp (CL:0000936) (Author Fuzzy=True and Cell Typist Fuzzy=True): sim=0.7222222222222222
# Comparing 01_hsc (CL:0000037) vs hsc/mpp (CL:0000834) (Author Fuzzy=True and Cell Typist Fuzzy=True): sim=0.6190476190476191
# Comparing 01_hsc (CL:0000037) vs hsc/mpp (CL:0000050) (Author Fuzzy=True and Cell Typist Fuzzy=True): sim=0.6842105263157895
# Max Sim 0.7222222222222222
# Skipping row: 02_early.eryth or megakaryocyte precursor not found.
# Max Sim 0
# Skipping row: 03_late.eryth or mid erythroid not found.
# Max Sim 0
# Skipping row: 04_early.baso or mast cell not found.
# Max Sim 0
# Comparing 05_cmp.lmpp (CL:0001059) vs hsc/mpp (CL:0000049) (Author Fuzzy=True and Cell Typist Fuzzy=True): sim=0.8125
# Comparing 05_cmp.lmpp (CL:0001059) vs hsc/mpp (CL:0000557) (Author Fuzzy=True and Cell Typist Fuzzy=True): sim=0.6086956521739131
# Comparing 05_cmp.lmpp (CL:0001059) vs hsc/mpp (CL:0000837) (Author Fuzzy=True and Cell Typist Fuzzy=True): sim=0.6470588235294118
# Comparing 05_cmp.lmpp (CL:0001059) vs hsc/mpp (CL:0000936) (Author Fuzzy=True and Cell Typist Fuzzy=True): sim=0.7222222222222222
# Comparing 05_cmp.lmpp (CL:0001059) vs hsc/mpp (CL:0000834) (Author Fuzzy=True and Cell Typist Fuzzy=True): sim=0.6190476190476191
# Comparing 05_cmp.lmpp (CL:0001059) vs hsc/mpp (CL:0000050) (Author Fuzzy=True and Cell Typist Fuzzy=True): sim=0.7777777777777778
# Max Sim 0.8125
# Skipping row: 06_clp.1 or pro-b cell not found.
# Max Sim 0
# Comparing 07_gmp (CL:0000557) vs promyelocyte (CL:0000836) (Author Fuzzy=True and Cell Typist Fuzzy=True): sim=0.56
# Max Sim 0.56
# Skipping row: 08_gmp.neut or cmp not found.
# Max Sim 0
# Comparing 09_pdc (CL:0000784) vs pdc (CL:0001058) (Author Fuzzy=True and Cell Typist Fuzzy=True): sim=0.9166666666666666
# Max Sim 0.9166666666666666
# Comparing 10_cdc (CL:0000990) vs dc2 (CL:0000990) (Author Fuzzy=True and Cell Typist Fuzzy=True): sim=1.0
# Comparing 10_cdc (CL:0000990) vs dc2 (CL:0001056) (Author Fuzzy=True and Cell Typist Fuzzy=True): sim=0.9130434782608695
# Comparing 10_cdc (CL:0000990) vs dc2 (CL:0000840) (Author Fuzzy=True and Cell Typist Fuzzy=True): sim=0.88
# Max Sim 1.0
# Skipping row: 11_cd14.mono.1 or classical monocyte not found.
# Max Sim 0
# Skipping row: 12_cd14.mono.2 or classical monocyte not found.
# Max Sim 0
# Skipping row: 13_cd16.mono or non-classical monocyte not found.
# Max Sim 0
# Skipping row: 14_unk or classical monocyte not found.
# Max Sim 0
# Skipping row: 15_clp.2 or pro-b cell not found.
# Max Sim 0
# Skipping row: 16_pre.b or small pre-b cell not found.
# Max Sim 0
# Skipping row: 17_b or naive b cell not found.
# Max Sim 0
# Skipping row: 18_plasma or plasma cell not found.
# Max Sim 0
# Skipping row: 19_cd8.n or tcm/naive cytotoxic t cell not found.
# Max Sim 0
# Skipping row: 20_cd4.n1 or tcm/naive helper t cell not found.
# Max Sim 0
# Skipping row: 21_cd4.n2 or tcm/naive helper t cell not found.
# Max Sim 0
# Skipping row: 22_cd4.m or tcm/naive helper t cell not found.
# Max Sim 0
# Skipping row: 23_cd8.em or mait cell not found.
# Max Sim 0
# Skipping row: 24_cd8.cm or tem/trm cytotoxic t cell not found.
# Max Sim 0
# Skipping row: 25_nk or cd16+ nk cell not found.
# Max Sim 0
# Skipping row: 26_unk or naive b cell not found.
# Max Sim 0

# %% [markdown]
# ## Automatic Classifcation
# Cell ontology based simlarity via a optimised system (celltypist annotation is detected and processed seperately via file name)

# %%
## Load Datasets and Mapping Reference (Text to Cell Ontology ID)
# Base Directory of Dataset
base_dir = os.path.expanduser("~/Göran_Karlsson_Lab/benchLLM/Heimlich_et_al")
input_pattern = os.path.join(base_dir, "author_vs_*.csv")

## Mapping Reference 
# General 
mapping_df = pd.read_csv(os.path.expanduser("~/Göran_Karlsson_Lab/benchLLM/cell_to_cell_ontology.csv"))
# CellTypist
mapping_df_cellTypist = pd.read_csv(os.path.expanduser("~/Göran_Karlsson_Lab/benchLLM/CellTypist_to_Cell_Ontology.csv"))

# %%
# Load Cell Ontology Map (OWL)
print("Loading Cell Ontology (OWL)...")
G = get_ontology("http://purl.obolibrary.org/obo/cl.owl").load()
print("Ontology loaded.")
# Out:
# Loading Cell Ontology (OWL)...
# Ontology loaded.

# %%
def get_ancestors(cls):
    return set(cls.ancestors()) if cls else set()

def compute_similarity(id1, id2, onto):
    if id1 is None or id2 is None:
        return 0

    class1 = onto.search_one(iri="*" + id1.replace(":", "_")) # Convert ID1 to be Compatible with OWL
    class2 = onto.search_one(iri="*" + id2.replace(":", "_")) # Convert ID2 to be Compatible with OWL

    if not class1 or not class2:
        return 0

    ancestors1 = get_ancestors(class1)
    ancestors2 = get_ancestors(class2)

    intersection = ancestors1 & ancestors2
    union = ancestors1 | ancestors2

    if not union:
        return 0

    return len(intersection) / len(union)  # Jaccard Similarity

def normalize_label(label):
    label = str(label).lower().strip()                      # Remove Case Sensitivity and Trim
    label = re.sub(r'^\d+_?', '', label)                    # Remove Leading Numbers and Underscore
    label = re.sub(r'\s*\(.*?\)', '', label)                # Remove text in parentheses
    #label = re.sub(r'"', '', label)                # Remove Quotation Marks
    if label.endswith('s') and len(label) > 1:
        label = label[:-1]                                  # Remove Plural
    return label.strip()

#def normalize_label(label):
#    label = str(label).lower().strip() # Remove Case Sensitivity
#    label = re.sub(r'\s*\(.*?\)', '', label)  # Remove Special Characters
#    if label.endswith('s') and len(label) > 1:
#        label = label[:-1]
#    return label # Remove Plural

def fuzzy_match_label(label, choices, threshold=80):
    if label is None:
        return None
    result = process.extractOne(label, choices)
    if result is None:
        return None
    if len(result) == 2:
        match, score = result
    elif len(result) == 3:
        # Sometimes it returns (match, score, index)
        match, score, _ = result
    else:
        return None
    if score >= threshold:
        return match
    return None # Use Fuzzy Match if Exact Match is Null

# %%
# Read in all .CSVs that are relavent
for file_path in glob.glob(input_pattern):
    basename = os.path.basename(file_path)
    
    if '_similarity' in basename:
        continue # Exclude already completed file (Already made similarity files)
    
    if '_celltypist_' in basename:
        if 'Low' in basename:
            # Isolate CellTypist Files with High Granularity
            print(f'\nProcessing: {basename} as High Granularity CellTypist Annotation')
            label_to_id_high = dict(zip(mapping_df_cellTypist['Low-hierarchy cell types'], mapping_df_cellTypist['Cell Ontology ID']))
            label_to_id_ci_high = {k.lower(): v for k, v in label_to_id_high.items()}
            
            df = pd.read_csv(file_path)

            colnames = df.columns.tolist()
            if len(colnames) < 2:
                print(f"  Skipping {file_path} — not enough columns.")
                continue

            author_col = colnames[0]
            cellTypist_high_col = colnames[1]

            similarity_scores = []
            for _, row in df.iterrows():
                author_label = normalize_label(row[author_col])
                cellTypist_high_label = normalize_label(row[cellTypist_high_col])

                if author_label in ["nan", "none"] or pd.isna(author_label):
                    author_label = None
                if cellTypist_high_label in ["nan", "none"] or pd.isna(cellTypist_high_label):
                    cellTypist_high_label = None

                fuzzy_used_author = False
                fuzzy_used_cellTypist_high = False

                id1 = label_to_id_ci.get(author_label) if author_label else None
                id2 = label_to_id_ci_high.get(cellTypist_high_label) if cellTypist_high_label else None

                if id1 is None and author_label is not None:
                    matched_label = fuzzy_match_label(author_label, label_to_id_ci.keys())
                    if matched_label:
                        fuzzy_used_author = True
                    id1 = label_to_id_ci.get(matched_label)

                if id2 is None and cellTypist_high_label is not None:
                    matched_label = fuzzy_match_label(cellTypist_high_label, label_to_id_ci_low.keys())
                    if matched_label:
                        fuzzy_used_cellTypist_high = True
                    id2 = label_to_id_ci_high.get(matched_label)

                sim = compute_similarity(id1, id2, G)
                print(f"Comparing {author_label} ({id1}) vs {cellTypist_high_label} ({id2}) (fuzzy author ={fuzzy_used_author} and fuzzy llm ={fuzzy_used_cellTypist_high}): sim={sim}")
                similarity_scores.append(sim)


            df['similarity_score'] = similarity_scores
            print(df)
            
        elif 'High' in basename:
            # Isolate CellTypist Files with Low Granularity
            print(f'\nProcessing: {basename} as Low Granularity CellTypist Annotation')
            label_to_id_low = (mapping_df_cellTypist
                .groupby('High-hierarchy cell types')['Cell Ontology ID']
                .apply(set)
                .to_dict()
            )
            label_to_id_ci_low = {k.lower(): v for k, v in label_to_id_low.items()}
            df = pd.read_csv(file_path)

            colnames = df.columns.tolist()
            if len(colnames) < 2:
                print(f"  Skipping {file_path} — not enough columns.")
                continue

            author_col = colnames[0]
            cellTypist_col = colnames[1]

            similarity_scores = []

            for _, row in df.iterrows():
                author_label = normalize_label(row[author_col])
                cellTypist_low_label = normalize_label(row[cellTypist_col])

                fuzzy_used_author = False
                fuzzy_used_cellTypist_low = False

                ids1 = label_to_id_ci.get(author_label)
                ids2 = label_to_id_ci_low.get(cellTypist_low_label)

                # Fuzzy match fallback if not found
                if not ids1 and author_label:
                    match = fuzzy_match_label(author_label, label_to_id_ci.keys())
                    if match:
                        ids1 = label_to_id_ci.get(normalize_label(match))
                        fuzzy_used_author = True

                if not ids2 and cellTypist_low_label:
                    match = fuzzy_match_label(cellTypist_low_label, label_to_id_ci_low.keys())
                if match:
                    ids2 = label_to_id_ci_low.get(match.lower())
                    if ids2:
                        fuzzy_used_cellTypist_low = True

                # Normalize to sets
                if isinstance(ids1, str):
                    ids1 = {ids1}
                if isinstance(ids2, str):
                    ids2 = {ids2}

                max_sim = 0
                if ids1 and ids2:
                    for id1 in ids1:
                        for id2 in ids2:
                            sim = compute_similarity(id1, id2, G)
                            print(f"Comparing {author_label} ({id1}) vs {cellTypist_low_label} ({id2}) (Author Fuzzy={fuzzy_used_author} and Cell Typist Fuzzy={fuzzy_used_cellTypist_low}): sim={sim}")
                            if sim > max_sim:
                                max_sim = sim
                       
                else:
                    id1_vals = ids1 if ids1 else [None]
                    id2_vals = ids2 if ids2 else [None]
                    for id1 in id1_vals:
                        for id2 in id2_vals:
                            print(f"Comparing {author_label} ({id1}) vs {cellTypist_low_label} ({id2}) (Author Fuzzy={fuzzy_used_author} and Cell Typist Fuzzy={fuzzy_used_cellTypist_low}): sim=Skipped (missing IDs)")
        
                print(f"Max Sim {max_sim}") 
                similarity_scores.append(max_sim)

            df['similarity_score'] = similarity_scores
            print(df)
            #out_path = file_path.replace(".csv", "_similarity.csv")
            #df.to_csv(out_path, index=False)
            #print(f"  Saved: {os.path.basename(out_path)}")
            
    else:
        # Isolate General Files
        print(f'\nProcessing: {basename} as General Annotation')
        label_to_id = dict(zip(mapping_df['label'], mapping_df['ontology_id']))
        label_to_id_ci = {k.lower(): v for k, v in label_to_id.items()}

        df = pd.read_csv(file_path, , quotechar='"')
    
        colnames = df.columns.tolist()
        if len(colnames) < 2:
            print(f"  Skipping {file_path} — not enough columns.")
            continue

        author_col = colnames[0]
        llm_col = colnames[1]

        similarity_scores = []
        for _, row in df.iterrows():
            author_label = normalize_label(row[author_col])
            llm_label = normalize_label(row[llm_col])

            if author_label in ["nan", "none"] or pd.isna(author_label):
                author_label = None
            if llm_label in ["nan", "none"] or pd.isna(llm_label):
                llm_label = None

            fuzzy_used_author = False
            fuzzy_used_llm = False

            id1 = label_to_id_ci.get(author_label) if author_label else None
            id2 = label_to_id_ci.get(llm_label) if llm_label else None

            if id1 is None and author_label is not None:
                matched_label = fuzzy_match_label(author_label, label_to_id_ci.keys())
                if matched_label:
                    fuzzy_used_author = True
                id1 = label_to_id_ci.get(matched_label)

            if id2 is None and llm_label is not None:
                matched_label = fuzzy_match_label(llm_label, label_to_id_ci.keys())
                if matched_label:
                    fuzzy_used_llm = True
                id2 = label_to_id_ci.get(matched_label)

            sim = compute_similarity(id1, id2, G)
            print(f"Comparing {author_label} ({id1}) vs {llm_label} ({id2}) (fuzzy author ={fuzzy_used_author} and fuzzy llm ={fuzzy_used_llm}): sim={sim}")
            similarity_scores.append(sim)


        df['similarity_score'] = similarity_scores
        print(df)

        #out_path = file_path.replace(".csv", "_similarity.csv")
        #df.to_csv(out_path, index=False)
        #print(f"  Saved: {os.path.basename(out_path)}")
# Out:
# Processing: author_vs_Qwen3.csv as General Annotation
# Comparing platelet (CL:0000233) vs hematopoietic stem cell (CL:0000037) (fuzzy author =False and fuzzy llm =False): sim=0.43478260869565216
# Comparing b cell (CL:0000236) vs None (None) (fuzzy author =False and fuzzy llm =False): sim=0
# Comparing dendritic cell (CL:0001056) vs b cell (CL:0000236) (fuzzy author =False and fuzzy llm =False): sim=0.6
# Comparing natural killer cell (CL:0000623) vs None (None) (fuzzy author =False and fuzzy llm =False): sim=0
# Comparing cd4-positive, alpha-beta t cell (CL:0000624) vs myeloid progenitor (CL:0000049) (fuzzy author =False and fuzzy llm =True): sim=0.4166666666666667
# Comparing cd8-positive, alpha-beta t cell (CL:0000625) vs hematopoietic progenitor cell (CL:0000837) (fuzzy author =False and fuzzy llm =True): sim=0.43478260869565216
# Comparing erythroid lineage cell (CL:0000764) vs myeloid cell (CL:0000763) (fuzzy author =False and fuzzy llm =False): sim=0.9166666666666666
# Comparing cd16-positive, cd56-dim natural killer cell, human (CL:0000939) vs myeloid cell (CL:0000763) (fuzzy author =False and fuzzy llm =False): sim=0.45454545454545453
# Comparing cd14-positive monocyte (CL:0001054) vs myeloid cell (CL:0000763) (fuzzy author =False and fuzzy llm =False): sim=0.44
#                                            cell_type  \
# 0                                           platelet
# 1                                             B cell
# 2                                     dendritic cell
# 3                                natural killer cell
# 4                    CD4-positive, alpha-beta T cell
# 5                    CD8-positive, alpha-beta T cell
# 6                             erythroid lineage cell
# 7  CD16-positive, CD56-dim natural killer cell, h...
# 8                             CD14-positive monocyte
#
#                                   0  similarity_score
# 0           Hematopoietic stem cell          0.434783
# 1                               NaN          0.000000
# 2                            B cell          0.600000
# 3                               NaN          0.000000
# 4                Myeloid Progenitor          0.416667
# 5     Hematopoietic progenitor cell          0.434783
# 6  Myeloid cell (uncertain subtype)          0.916667
# 7                      Myeloid cell          0.454545
# 8                      Myeloid cell          0.440000
#
# Processing: author_vs_celltypist_Heimlich_Immune_All_High.csv as Low Granularity CellTypist Annotation
# Comparing platelet (CL:0000233) vs megakaryocytes/platelet (CL:0000556) (Author Fuzzy=False and Cell Typist Fuzzy=True): sim=0.6111111111111112
# Max Sim 0.6111111111111112
# Comparing b cell (CL:0000236) vs b cell (CL:0000787) (Author Fuzzy=False and Cell Typist Fuzzy=True): sim=0.782608695652174
# Comparing b cell (CL:0000236) vs b cell (CL:0000788) (Author Fuzzy=False and Cell Typist Fuzzy=True): sim=0.782608695652174
# Comparing b cell (CL:0000236) vs b cell (CL:0000236) (Author Fuzzy=False and Cell Typist Fuzzy=True): sim=1.0
# Comparing b cell (CL:0000236) vs b cell (CL:0000843) (Author Fuzzy=False and Cell Typist Fuzzy=True): sim=0.75
# Comparing b cell (CL:0000236) vs b cell (CL:0000844) (Author Fuzzy=False and Cell Typist Fuzzy=True): sim=0.782608695652174
# Comparing b cell (CL:0000236) vs b cell (CL:0000818) (Author Fuzzy=False and Cell Typist Fuzzy=True): sim=0.8571428571428571
# Max Sim 1.0
# Comparing dendritic cell (CL:0001056) vs pdc (CL:0000787) (Author Fuzzy=False and Cell Typist Fuzzy=True): sim=0.5517241379310345
# Comparing dendritic cell (CL:0001056) vs pdc (CL:0000788) (Author Fuzzy=False and Cell Typist Fuzzy=True): sim=0.5517241379310345
# Comparing dendritic cell (CL:0001056) vs pdc (CL:0000236) (Author Fuzzy=False and Cell Typist Fuzzy=True): sim=0.6
# Comparing dendritic cell (CL:0001056) vs pdc (CL:0000843) (Author Fuzzy=False and Cell Typist Fuzzy=True): sim=0.5333333333333333
# Comparing dendritic cell (CL:0001056) vs pdc (CL:0000844) (Author Fuzzy=False and Cell Typist Fuzzy=True): sim=0.5517241379310345
# Comparing dendritic cell (CL:0001056) vs pdc (CL:0000818) (Author Fuzzy=False and Cell Typist Fuzzy=True): sim=0.5357142857142857
# Max Sim 0.6
# Comparing natural killer cell (CL:0000623) vs ilc (CL:0000787) (Author Fuzzy=False and Cell Typist Fuzzy=True): sim=0.6153846153846154
# Comparing natural killer cell (CL:0000623) vs ilc (CL:0000788) (Author Fuzzy=False and Cell Typist Fuzzy=True): sim=0.6153846153846154
# Comparing natural killer cell (CL:0000623) vs ilc (CL:0000236) (Author Fuzzy=False and Cell Typist Fuzzy=True): sim=0.7619047619047619
# Comparing natural killer cell (CL:0000623) vs ilc (CL:0000843) (Author Fuzzy=False and Cell Typist Fuzzy=True): sim=0.5925925925925926
# Comparing natural killer cell (CL:0000623) vs ilc (CL:0000844) (Author Fuzzy=False and Cell Typist Fuzzy=True): sim=0.6153846153846154
# Comparing natural killer cell (CL:0000623) vs ilc (CL:0000818) (Author Fuzzy=False and Cell Typist Fuzzy=True): sim=0.6666666666666666
# Max Sim 0.7619047619047619
# Comparing cd4-positive, alpha-beta t cell (CL:0000624) vs t cell (CL:0001062) (Author Fuzzy=False and Cell Typist Fuzzy=True): sim=0.7692307692307693
# Comparing cd4-positive, alpha-beta t cell (CL:0000624) vs t cell (CL:0000913) (Author Fuzzy=False and Cell Typist Fuzzy=True): sim=0.7692307692307693
# Comparing cd4-positive, alpha-beta t cell (CL:0000624) vs t cell (CL:0000907) (Author Fuzzy=False and Cell Typist Fuzzy=True): sim=0.7692307692307693
# Comparing cd4-positive, alpha-beta t cell (CL:0000624) vs t cell (CL:0000814) (Author Fuzzy=False and Cell Typist Fuzzy=True): sim=0.9090909090909091
# Comparing cd4-positive, alpha-beta t cell (CL:0000624) vs t cell (CL:0000905) (Author Fuzzy=False and Cell Typist Fuzzy=True): sim=0.84
# Comparing cd4-positive, alpha-beta t cell (CL:0000624) vs t cell (CL:0000545) (Author Fuzzy=False and Cell Typist Fuzzy=True): sim=0.9130434782608695
# Comparing cd4-positive, alpha-beta t cell (CL:0000624) vs t cell (CL:0000940) (Author Fuzzy=False and Cell Typist Fuzzy=True): sim=0.9090909090909091
# Comparing cd4-positive, alpha-beta t cell (CL:0000624) vs t cell (CL:0000798) (Author Fuzzy=False and Cell Typist Fuzzy=True): sim=0.7727272727272727
# Comparing cd4-positive, alpha-beta t cell (CL:0000624) vs t cell (CL:0000934) (Author Fuzzy=False and Cell Typist Fuzzy=True): sim=0.9545454545454546
# Comparing cd4-positive, alpha-beta t cell (CL:0000624) vs t cell (CL:0002430) (Author Fuzzy=False and Cell Typist Fuzzy=True): sim=0.6923076923076923
# Comparing cd4-positive, alpha-beta t cell (CL:0000624) vs t cell (CL:0000815) (Author Fuzzy=False and Cell Typist Fuzzy=True): sim=0.8181818181818182
# Comparing cd4-positive, alpha-beta t cell (CL:0000624) vs t cell (CL:0000084) (Author Fuzzy=False and Cell Typist Fuzzy=True): sim=0.8095238095238095
# Comparing cd4-positive, alpha-beta t cell (CL:0000624) vs t cell (CL:0000904) (Author Fuzzy=False and Cell Typist Fuzzy=True): sim=0.84
# Comparing cd4-positive, alpha-beta t cell (CL:0000624) vs t cell (CL:0000899) (Author Fuzzy=False and Cell Typist Fuzzy=True): sim=0.9130434782608695
# Comparing cd4-positive, alpha-beta t cell (CL:0000624) vs t cell (CL:0002038) (Author Fuzzy=False and Cell Typist Fuzzy=True): sim=0.9130434782608695
# Max Sim 0.9545454545454546
# Comparing cd8-positive, alpha-beta t cell (CL:0000625) vs t cell (CL:0001062) (Author Fuzzy=False and Cell Typist Fuzzy=True): sim=0.84
# Comparing cd8-positive, alpha-beta t cell (CL:0000625) vs t cell (CL:0000913) (Author Fuzzy=False and Cell Typist Fuzzy=True): sim=0.84
# Comparing cd8-positive, alpha-beta t cell (CL:0000625) vs t cell (CL:0000907) (Author Fuzzy=False and Cell Typist Fuzzy=True): sim=0.84
# Comparing cd8-positive, alpha-beta t cell (CL:0000625) vs t cell (CL:0000814) (Author Fuzzy=False and Cell Typist Fuzzy=True): sim=0.9090909090909091
# Comparing cd8-positive, alpha-beta t cell (CL:0000625) vs t cell (CL:0000905) (Author Fuzzy=False and Cell Typist Fuzzy=True): sim=0.7692307692307693
# Comparing cd8-positive, alpha-beta t cell (CL:0000625) vs t cell (CL:0000545) (Author Fuzzy=False and Cell Typist Fuzzy=True): sim=0.8333333333333334
# Comparing cd8-positive, alpha-beta t cell (CL:0000625) vs t cell (CL:0000940) (Author Fuzzy=False and Cell Typist Fuzzy=True): sim=0.9090909090909091
# Comparing cd8-positive, alpha-beta t cell (CL:0000625) vs t cell (CL:0000798) (Author Fuzzy=False and Cell Typist Fuzzy=True): sim=0.7727272727272727
# Comparing cd8-positive, alpha-beta t cell (CL:0000625) vs t cell (CL:0000934) (Author Fuzzy=False and Cell Typist Fuzzy=True): sim=0.8695652173913043
# Comparing cd8-positive, alpha-beta t cell (CL:0000625) vs t cell (CL:0002430) (Author Fuzzy=False and Cell Typist Fuzzy=True): sim=0.6923076923076923
# Comparing cd8-positive, alpha-beta t cell (CL:0000625) vs t cell (CL:0000815) (Author Fuzzy=False and Cell Typist Fuzzy=True): sim=0.8181818181818182
# Comparing cd8-positive, alpha-beta t cell (CL:0000625) vs t cell (CL:0000084) (Author Fuzzy=False and Cell Typist Fuzzy=True): sim=0.8095238095238095
# Comparing cd8-positive, alpha-beta t cell (CL:0000625) vs t cell (CL:0000904) (Author Fuzzy=False and Cell Typist Fuzzy=True): sim=0.7692307692307693
# Comparing cd8-positive, alpha-beta t cell (CL:0000625) vs t cell (CL:0000899) (Author Fuzzy=False and Cell Typist Fuzzy=True): sim=0.8333333333333334
# Comparing cd8-positive, alpha-beta t cell (CL:0000625) vs t cell (CL:0002038) (Author Fuzzy=False and Cell Typist Fuzzy=True): sim=0.8333333333333334
# Max Sim 0.9090909090909091
# Comparing erythroid lineage cell (CL:0000764) vs t cell (CL:0001062) (Author Fuzzy=False and Cell Typist Fuzzy=True): sim=0.37037037037037035
# Comparing erythroid lineage cell (CL:0000764) vs t cell (CL:0000913) (Author Fuzzy=False and Cell Typist Fuzzy=True): sim=0.37037037037037035
# Comparing erythroid lineage cell (CL:0000764) vs t cell (CL:0000907) (Author Fuzzy=False and Cell Typist Fuzzy=True): sim=0.37037037037037035
# Comparing erythroid lineage cell (CL:0000764) vs t cell (CL:0000814) (Author Fuzzy=False and Cell Typist Fuzzy=True): sim=0.43478260869565216
# Comparing erythroid lineage cell (CL:0000764) vs t cell (CL:0000905) (Author Fuzzy=False and Cell Typist Fuzzy=True): sim=0.37037037037037035
# Comparing erythroid lineage cell (CL:0000764) vs t cell (CL:0000545) (Author Fuzzy=False and Cell Typist Fuzzy=True): sim=0.4
# Comparing erythroid lineage cell (CL:0000764) vs t cell (CL:0000940) (Author Fuzzy=False and Cell Typist Fuzzy=True): sim=0.43478260869565216
# Comparing erythroid lineage cell (CL:0000764) vs t cell (CL:0000798) (Author Fuzzy=False and Cell Typist Fuzzy=True): sim=0.5
# Comparing erythroid lineage cell (CL:0000764) vs t cell (CL:0000934) (Author Fuzzy=False and Cell Typist Fuzzy=True): sim=0.4166666666666667
# Comparing erythroid lineage cell (CL:0000764) vs t cell (CL:0002430) (Author Fuzzy=False and Cell Typist Fuzzy=True): sim=0.4
# Comparing erythroid lineage cell (CL:0000764) vs t cell (CL:0000815) (Author Fuzzy=False and Cell Typist Fuzzy=True): sim=0.47619047619047616
# Comparing erythroid lineage cell (CL:0000764) vs t cell (CL:0000084) (Author Fuzzy=False and Cell Typist Fuzzy=True): sim=0.5263157894736842
# Comparing erythroid lineage cell (CL:0000764) vs t cell (CL:0000904) (Author Fuzzy=False and Cell Typist Fuzzy=True): sim=0.37037037037037035
# Comparing erythroid lineage cell (CL:0000764) vs t cell (CL:0000899) (Author Fuzzy=False and Cell Typist Fuzzy=True): sim=0.4
# Comparing erythroid lineage cell (CL:0000764) vs t cell (CL:0002038) (Author Fuzzy=False and Cell Typist Fuzzy=True): sim=0.4
# Max Sim 0.5263157894736842
# Comparing cd16-positive, cd56-dim natural killer cell, human (CL:0000939) vs monocyte (CL:0000875) (Author Fuzzy=False and Cell Typist Fuzzy=True): sim=0.4838709677419355
# Comparing cd16-positive, cd56-dim natural killer cell, human (CL:0000939) vs monocyte (CL:0000576) (Author Fuzzy=False and Cell Typist Fuzzy=True): sim=0.5
# Comparing cd16-positive, cd56-dim natural killer cell, human (CL:0000939) vs monocyte (CL:0000860) (Author Fuzzy=False and Cell Typist Fuzzy=True): sim=0.4838709677419355
# Max Sim 0.5
# Comparing cd14-positive monocyte (CL:0001054) vs monocyte (CL:0000875) (Author Fuzzy=False and Cell Typist Fuzzy=True): sim=0.9230769230769231
# Comparing cd14-positive monocyte (CL:0001054) vs monocyte (CL:0000576) (Author Fuzzy=False and Cell Typist Fuzzy=True): sim=0.96
# Comparing cd14-positive monocyte (CL:0001054) vs monocyte (CL:0000860) (Author Fuzzy=False and Cell Typist Fuzzy=True): sim=0.9230769230769231
# Max Sim 0.96
#                                            cell_type  \
# 0                                           platelet
# 1                                             B cell
# 2                                     dendritic cell
# 3                                natural killer cell
# 4                    CD4-positive, alpha-beta T cell
# 5                    CD8-positive, alpha-beta T cell
# 6                             erythroid lineage cell
# 7  CD16-positive, CD56-dim natural killer cell, h...
# 8                             CD14-positive monocyte
#
#           cluster_cell_type  similarity_score
# 0  Megakaryocytes/platelets          0.611111
# 1                   B cells          1.000000
# 2                       pDC          0.600000
# 3                       ILC          0.761905
# 4                   T cells          0.954545
# 5                   T cells          0.909091
# 6                   T cells          0.526316
# 7                 Monocytes          0.500000
# 8                 Monocytes          0.960000
#
# Processing: author_vs_Gemini2_5.csv as General Annotation
# Comparing platelet (CL:0000233) vs None (None) (fuzzy author =False and fuzzy llm =False): sim=0
# Comparing b cell (CL:0000236) vs None (None) (fuzzy author =False and fuzzy llm =False): sim=0
# Comparing dendritic cell (CL:0001056) vs None (None) (fuzzy author =False and fuzzy llm =False): sim=0
# Comparing natural killer cell (CL:0000623) vs peripheral blood mononuclear cell (CL:2000001) (fuzzy author =False and fuzzy llm =False): sim=0.7142857142857143
# Comparing cd4-positive, alpha-beta t cell, (CL:0000624) vs None (None) (fuzzy author =True and fuzzy llm =False): sim=0
# Comparing cd8-positive, alpha-beta t cell, (CL:0000625) vs None (None) (fuzzy author =True and fuzzy llm =False): sim=0
# Comparing erythroid lineage cell (CL:0000764) vs None (None) (fuzzy author =False and fuzzy llm =False): sim=0
# Comparing cd16-positive, cd56-dim natural killer cell, human, (CL:0000939) vs None (None) (fuzzy author =True and fuzzy llm =False): sim=0
# Comparing cd14-positive monocyte (CL:0001054) vs uncharacterized hematopoietic cell (CL:0000570) (fuzzy author =False and fuzzy llm =True): sim=0.24324324324324326
#                                            cell_type  \
# 0                                           platelet
# 1                                             B cell
# 2                                     dendritic cell
# 3                                natural killer cell
# 4                 "CD4-positive, alpha-beta T cell",
# 5                 "CD8-positive, alpha-beta T cell",
# 6                             erythroid lineage cell
# 7  "CD16-positive, CD56-dim natural killer cell, ...
# 8                             CD14-positive monocyte
#
#                                     0  similarity_score
# 0                                 NaN          0.000000
# 1                                 NaN          0.000000
# 2                                 NaN          0.000000
# 3   peripheral blood mononuclear cell          0.714286
# 4                                 NaN          0.000000
# 5                                 NaN          0.000000
# 6                                 NaN          0.000000
# 7                                 NaN          0.000000
# 8  Uncharacterized hematopoietic cell          0.243243
#
# Processing: author_vs_Gemini2_0.csv as General Annotation
# Comparing platelet (CL:0000233) vs None (None) (fuzzy author =False and fuzzy llm =False): sim=0
# Comparing b cell (CL:0000236) vs None (None) (fuzzy author =False and fuzzy llm =False): sim=0
# Comparing dendritic cell (CL:0001056) vs None (None) (fuzzy author =False and fuzzy llm =False): sim=0
# Comparing natural killer cell (CL:0000623) vs None (None) (fuzzy author =False and fuzzy llm =False): sim=0
# Comparing cd4-positive, alpha-beta t cell (CL:0000624) vs None (None) (fuzzy author =False and fuzzy llm =False): sim=0
# Comparing cd8-positive, alpha-beta t cell (CL:0000625) vs None (None) (fuzzy author =False and fuzzy llm =False): sim=0
# Comparing erythroid lineage cell (CL:0000764) vs None (None) (fuzzy author =False and fuzzy llm =False): sim=0
# Comparing cd16-positive, cd56-dim natural killer cell, human (CL:0000939) vs None (None) (fuzzy author =False and fuzzy llm =False): sim=0
# Comparing cd14-positive monocyte (CL:0001054) vs None (None) (fuzzy author =False and fuzzy llm =False): sim=0
#                                            cell_type   0  similarity_score
# 0                                           platelet NaN                 0
# 1                                             B cell NaN                 0
# 2                                     dendritic cell NaN                 0
# 3                                natural killer cell NaN                 0
# 4                    CD4-positive, alpha-beta T cell NaN                 0
# 5                    CD8-positive, alpha-beta T cell NaN                 0
# 6                             erythroid lineage cell NaN                 0
# 7  CD16-positive, CD56-dim natural killer cell, h... NaN                 0
# 8                             CD14-positive monocyte NaN                 0
#
# Processing: author_vs_Grok3Beta.csv as General Annotation
# Comparing platelet (CL:0000233) vs cytotoxic t cell (CL:0000910) (fuzzy author =False and fuzzy llm =False): sim=0.37037037037037035
# Comparing b cell (CL:0000236) vs b cell (CL:0000236) (fuzzy author =False and fuzzy llm =False): sim=1.0
# Comparing dendritic cell (CL:0001056) vs b cell (CL:0000236) (fuzzy author =False and fuzzy llm =False): sim=0.6
# Comparing natural killer cell (CL:0000623) vs neutrophil (CL:0000775) (fuzzy author =False and fuzzy llm =False): sim=0.5416666666666666
# Comparing cd4-positive, alpha-beta t cell (CL:0000624) vs t cell (CL:0000084) (fuzzy author =False and fuzzy llm =False): sim=0.8095238095238095
# Comparing cd8-positive, alpha-beta t cell (CL:0000625) vs t cell (CL:0000084) (fuzzy author =False and fuzzy llm =False): sim=0.8095238095238095
# Comparing erythroid lineage cell (CL:0000764) vs b cell (CL:0000236) (fuzzy author =False and fuzzy llm =False): sim=0.5
# Comparing cd16-positive, cd56-dim natural killer cell, human (CL:0000939) vs b cell (CL:0000236) (fuzzy author =False and fuzzy llm =False): sim=0.6956521739130435
# Comparing cd14-positive monocyte (CL:0001054) vs neutrophil (CL:0000775) (fuzzy author =False and fuzzy llm =False): sim=0.5357142857142857
#                                            cell_type                 0  \
# 0                                           platelet  Cytotoxic T cell
# 1                                             B cell            B cell
# 2                                     dendritic cell            B cell
# 3                                natural killer cell        Neutrophil
# 4                    CD4-positive, alpha-beta T cell            T cell
# 5                    CD8-positive, alpha-beta T cell            T cell
# 6                             erythroid lineage cell            B cell
# 7  CD16-positive, CD56-dim natural killer cell, h...            B cell
# 8                             CD14-positive monocyte        Neutrophil
#
#    similarity_score
# 0          0.370370
# 1          1.000000
# 2          0.600000
# 3          0.541667
# 4          0.809524
# 5          0.809524
# 6          0.500000
# 7          0.695652
# 8          0.535714
#
# Processing: author_vs_Llama4.csv as General Annotation
# Comparing platelet (CL:0000233) vs mononuclear leukocyte (CL:0000842) (fuzzy author =False and fuzzy llm =False): sim=0.45454545454545453
# Comparing b cell (CL:0000236) vs cd8 t cell (CL:0000000) (fuzzy author =False and fuzzy llm =True): sim=0.3888888888888889
# Comparing dendritic cell (CL:0001056) vs mononuclear leukocyte (CL:0000842) (fuzzy author =False and fuzzy llm =False): sim=0.6818181818181818
# Comparing natural killer cell (CL:0000623) vs monocyte (CL:0001054) (fuzzy author =False and fuzzy llm =False): sim=0.5172413793103449
# Comparing cd4-positive, alpha-beta t cell,t cell (CL:0000624) vs None (None) (fuzzy author =True and fuzzy llm =False): sim=0
# Comparing cd8-positive, alpha-beta t cell,t cell (CL:0000625) vs None (None) (fuzzy author =True and fuzzy llm =False): sim=0
# Comparing erythroid lineage cell (CL:0000764) vs None (None) (fuzzy author =False and fuzzy llm =False): sim=0
# Comparing cd16-positive, cd56-dim natural killer cell, human,t cell (CL:0000939) vs None (None) (fuzzy author =True and fuzzy llm =False): sim=0
# Comparing cd14-positive monocyte (CL:0001054) vs t cell (CL:0000084) (fuzzy author =False and fuzzy llm =False): sim=0.5555555555555556
#                                            cell_type                      0  \
# 0                                           platelet  mononuclear leukocyte
# 1                                             B cell             CD8 T cell
# 2                                     dendritic cell  mononuclear leukocyte
# 3                                natural killer cell               Monocyte
# 4           "CD4-positive, alpha-beta T cell",T cell                    NaN
# 5           "CD8-positive, alpha-beta T cell",T cell                    NaN
# 6                             erythroid lineage cell                    NaN
# 7  "CD16-positive, CD56-dim natural killer cell, ...                    NaN
# 8                             CD14-positive monocyte                 T cell
#
#    similarity_score
# 0          0.454545
# 1          0.388889
# 2          0.681818
# 3          0.517241
# 4          0.000000
# 5          0.000000
# 6          0.000000
# 7          0.000000
# 8          0.555556
#
# Processing: author_vs_Claude3_7Sonnet.csv as General Annotation
# Comparing platelet (CL:0000233) vs megakaryocyte (CL:0000556) (fuzzy author =False and fuzzy llm =False): sim=0.6111111111111112
# Comparing b cell (CL:0000236) vs t lymphocyte (CL:0000084) (fuzzy author =False and fuzzy llm =False): sim=0.8421052631578947
# Comparing dendritic cell (CL:0001056) vs monocyte (CL:0001054) (fuzzy author =False and fuzzy llm =False): sim=0.6785714285714286
# Comparing natural killer cell (CL:0000623) vs monocyte (CL:0001054) (fuzzy author =False and fuzzy llm =False): sim=0.5172413793103449
# Comparing cd4-positive, alpha-beta t cell (CL:0000624) vs cd16+ monocyte (CL:0002397) (fuzzy author =False and fuzzy llm =False): sim=0.46875
# Comparing cd8-positive, alpha-beta t cell (CL:0000625) vs t cell (CL:0000084) (fuzzy author =False and fuzzy llm =False): sim=0.8095238095238095
# Comparing erythroid lineage cell (CL:0000764) vs megakaryocyte (CL:0000556) (fuzzy author =False and fuzzy llm =False): sim=0.8461538461538461
# Comparing cd16-positive, cd56-dim natural killer cell, human (CL:0000939) vs hla-positive b cell (CL:0000000) (fuzzy author =False and fuzzy llm =True): sim=0.3333333333333333
# Comparing cd14-positive monocyte (CL:0001054) vs monocyte (CL:0001054) (fuzzy author =False and fuzzy llm =False): sim=1.0
#                                            cell_type                    0  \
# 0                                           platelet        Megakaryocyte
# 1                                             B cell         T lymphocyte
# 2                                     dendritic cell            Monocytes
# 3                                natural killer cell             Monocyte
# 4                    CD4-positive, alpha-beta T cell       CD16+ Monocyte
# 5                    CD8-positive, alpha-beta T cell              T cells
# 6                             erythroid lineage cell       Megakaryocytes
# 7  CD16-positive, CD56-dim natural killer cell, h...  HLA-positive B cell
# 8                             CD14-positive monocyte             Monocyte
#
#    similarity_score
# 0          0.611111
# 1          0.842105
# 2          0.678571
# 3          0.517241
# 4          0.468750
# 5          0.809524
# 6          0.846154
# 7          0.333333
# 8          1.000000
#
# Processing: author_vs_gpt4_1mini.csv as General Annotation
# Comparing platelet (CL:0000233) vs None (None) (fuzzy author =False and fuzzy llm =False): sim=0
# Comparing b cell (CL:0000236) vs None (None) (fuzzy author =False and fuzzy llm =False): sim=0
# Comparing dendritic cell (CL:0001056) vs None (None) (fuzzy author =False and fuzzy llm =False): sim=0
# Comparing natural killer cell (CL:0000623) vs None (None) (fuzzy author =False and fuzzy llm =False): sim=0
# Comparing cd4-positive, alpha-beta t cell (CL:0000624) vs None (None) (fuzzy author =False and fuzzy llm =False): sim=0
# Comparing cd8-positive, alpha-beta t cell (CL:0000625) vs None (None) (fuzzy author =False and fuzzy llm =False): sim=0
# Comparing erythroid lineage cell (CL:0000764) vs None (None) (fuzzy author =False and fuzzy llm =False): sim=0
# Comparing cd16-positive, cd56-dim natural killer cell, human (CL:0000939) vs None (None) (fuzzy author =False and fuzzy llm =False): sim=0
# Comparing cd14-positive monocyte (CL:0001054) vs None (None) (fuzzy author =False and fuzzy llm =False): sim=0
#                                            cell_type   0  similarity_score
# 0                                           platelet NaN                 0
# 1                                             B cell NaN                 0
# 2                                     dendritic cell NaN                 0
# 3                                natural killer cell NaN                 0
# 4                    CD4-positive, alpha-beta T cell NaN                 0
# 5                    CD8-positive, alpha-beta T cell NaN                 0
# 6                             erythroid lineage cell NaN                 0
# 7  CD16-positive, CD56-dim natural killer cell, h... NaN                 0
# 8                             CD14-positive monocyte NaN                 0
#
# Processing: author_vs_celltypist_Heimlich_Immune_All_Low.csv as High Granularity CellTypist Annotation
# Comparing platelet (CL:0000233) vs megakaryocytes/platelet (CL:0000556) (fuzzy author =False and fuzzy llm =True): sim=0.6111111111111112
# Comparing b cell (CL:0000236) vs naive b cell (CL:0000236) (fuzzy author =False and fuzzy llm =True): sim=1.0
# Comparing dendritic cell (CL:0001056) vs pdc (CL:0001058) (fuzzy author =False and fuzzy llm =False): sim=0.9166666666666666
# Comparing natural killer cell (CL:0000623) vs cd16+ nk cell (None) (fuzzy author =False and fuzzy llm =False): sim=0
# Comparing cd4-positive, alpha-beta t cell (CL:0000624) vs tem/effector helper t cell (None) (fuzzy author =False and fuzzy llm =True): sim=0
# Comparing cd8-positive, alpha-beta t cell (CL:0000625) vs tem/temra cytotoxic t cell (None) (fuzzy author =False and fuzzy llm =True): sim=0
# Comparing erythroid lineage cell (CL:0000764) vs tem/trm cytotoxic t cell (None) (fuzzy author =False and fuzzy llm =True): sim=0
# Comparing cd16-positive, cd56-dim natural killer cell, human (CL:0000939) vs non-classical monocyte (CL:0000576) (fuzzy author =False and fuzzy llm =True): sim=0.5
# Comparing cd14-positive monocyte (CL:0001054) vs classical monocyte (CL:0000576) (fuzzy author =False and fuzzy llm =True): sim=0.96
#                                            cell_type  \
# 0                                           platelet
# 1                                             B cell
# 2                                     dendritic cell
# 3                                natural killer cell
# 4                    CD4-positive, alpha-beta T cell
# 5                    CD8-positive, alpha-beta T cell
# 6                             erythroid lineage cell
# 7  CD16-positive, CD56-dim natural killer cell, h...
# 8                             CD14-positive monocyte
#
#              cluster_cell_type  similarity_score
# 0     Megakaryocytes/platelets          0.611111
# 1                Naive B cells          1.000000
# 2                          pDC          0.916667
# 3               CD16+ NK cells          0.000000
# 4  Tem/Effector helper T cells          0.000000
# 5  Tem/Temra cytotoxic T cells          0.000000
# 6    Tem/Trm cytotoxic T cells          0.000000
# 7      Non-classical monocytes          0.500000
# 8          Classical monocytes          0.960000

# %% [markdown]
# ## From the large datafiles

# %%
base_dirs = [
    #os.path.expanduser("~/Göran_Karlsson_Lab/benchLLM/Heimlich_et_al"),
    #os.path.expanduser("~/Göran_Karlsson_Lab/benchLLM/Granja_et_al"),
    #os.path.expanduser("~/Göran_Karlsson_Lab/benchLLM/Simone_et_al"),
    #os.path.expanduser("~/Göran_Karlsson_Lab/benchLLM/Jardine_et_al"),
    #os.path.expanduser("~/Göran_Karlsson_Lab/benchLLM/Roy_et_al"),
    os.path.expanduser("~/Göran_Karlsson_Lab/benchLLM/Zhang_et_al"),
]

## Mapping Reference 
# General 
mapping_df = pd.read_csv(os.path.expanduser("~/Göran_Karlsson_Lab/benchLLM/cell_to_cell_ontology.csv"))
label_to_id = dict(zip(mapping_df['label'], mapping_df['ontology_id']))
label_to_id_ci = {k.lower(): v for k, v in label_to_id.items()} # Remove Case Sentivity

# %%
for base_dir in base_dirs:
    input_pattern = os.path.join(base_dir, "*_with_author.csv")
    for file_path in glob.glob(input_pattern):
        basename = os.path.basename(file_path)

        if '_similarity' in basename:
            continue  # Skip already processed files

        print(f'\nProcessing: {base_dir} as General Annotation')

        df = pd.read_csv(file_path, sep=';')
        colnames = df.columns.tolist()

        required_cols = ["Ontology Term", "Author Label"]
        if not all(col in colnames for col in required_cols):
            print(f"  Skipping {file_path} — required columns not found.")
            continue

        author_col = "Author Label"
        llm_col = "Ontology Term"
        llm_name_col = "Cell Type"

        similarity_scores = []

        for _, row in df.iterrows():
            author_label = normalize_label(row[author_col])
            llm_label = row[llm_col]
            llm_label_name = row[llm_name_col]
        
            if author_label in ["nan", "none"] or pd.isna(author_label):
                author_label = None
            if llm_label in ["nan", "none"] or pd.isna(llm_label):
                llm_label = None
        
            fuzzy_used_author = False
        
            id1 = label_to_id_ci.get(author_label) if author_label else None
            id2 = llm_label  # already in ontology format
        
            # First fuzzy match attempt if id1 is not found
            if id1 is None and author_label:
                matched_label = fuzzy_match_label(author_label, label_to_id_ci.keys())
                if matched_label:
                    fuzzy_used_author = True
                    id1 = label_to_id_ci.get(matched_label)
        
            # Second attempt if id1 is still CL:0000000 (unknown) and "+" can be expanded
            if id1 == "CL:0000000" and author_label and "+" in author_label:
                expanded_label = author_label.replace("+", "-positive")
                matched_label = fuzzy_match_label(expanded_label, label_to_id_ci.keys())
                if matched_label:
                    fuzzy_used_author = True
                    id1 = label_to_id_ci.get(matched_label)

            # Third Atteempt if id1 is still (None) and contains term early
            if id1 is None and author_label and ("-early" in author_label or "early-" in author_label):
                for replacement_term in ["precursor", "immature", "developing", "pre"]:
                    if "-early" in author_label:
                        expanded_label = author_label.replace("-early", f" {replacement_term}")
                    elif "early-" in author_label:
                        expanded_label = author_label.replace("early-", f"{replacement_term} ")
                    
                    matched_label = fuzzy_match_label(expanded_label, label_to_id_ci.keys())
                    if matched_label:
                        fuzzy_used_author = True
                        id1 = label_to_id_ci.get(matched_label)
                        break
        
            sim = compute_similarity(id1, id2, G)
            print(f"Comparing {author_label} ({id1}) vs {llm_label_name} ({id2}) "
                  f"(fuzzy author={fuzzy_used_author}): sim={sim}")
            similarity_scores.append(sim)

        df['similarity_score'] = similarity_scores
        
        # Optional save
        out_path = file_path.replace(".csv", "_similarity.csv")
        df.to_csv(out_path, sep=';', index=False)
        print(f"  Saved: {os.path.basename(out_path)}")
# Out:
# Processing: /Users/alexantill/Göran_Karlsson_Lab/benchLLM/Zhang_et_al as General Annotation
# Comparing asdc (None) vs Dendritic Cell (CL_0001029) (fuzzy author=False): sim=0
# Comparing hsc (CL:0000037) vs Hematopoietic Stem Cell (HSC) (CL_0000037) (fuzzy author=False): sim=1.0
# Comparing mdp (CL:0002009) vs Pre-B cell (CL_0000817) (fuzzy author=False): sim=0.37037037037037035
# Comparing mep (CL:0000050) vs Megakaryocyte-Erythroid Progenitor (MEP) (CL_0000050) (fuzzy author=False): sim=1.0
# Comparing mkp (CL:0000553) vs Megakaryocyte (CL_0000556) (fuzzy author=False): sim=0.6111111111111112
# Comparing mpp (CL:0000837) vs Hematopoietic stem cell (HSC) (CL_0000037) (fuzzy author=False): sim=0.6470588235294118
# Comparing mac (CL:0000091) vs Macrophage (CL_0002476) (fuzzy author=True): sim=0.8
# Comparing mast-early (CL:0002354) vs Basophil (CL_0000767) (fuzzy author=True): sim=0.38461538461538464
# Comparing monocyte (CL:0001054) vs Monocyte Progenitor (CL_0000040) (fuzzy author=False): sim=0.43333333333333335
# Comparing multilin (CL:0011018) vs Hematopoietic progenitor (CL_0000936) (fuzzy author=True): sim=0.4166666666666667
# Comparing myeloid intermediate (CL:0001059) vs Neutrophil Progenitor (CL_0000834) (fuzzy author=True): sim=0.6190476190476191
# Comparing b cell (CL:0000236) vs Developing B-lymphocyte (CL_0000817) (fuzzy author=False): sim=0.8571428571428571
# Comparing plasma cell (CL:0000786) vs Plasma cell (CL_0000786) (fuzzy author=False): sim=1.0
# Comparing stromal (CL:0000134) vs Mesenchymal stromal cell (CL_0000134) (fuzzy author=True): sim=1.0
# Comparing t proliferating (CL:4033069) vs T-cell (CL_0000898) (fuzzy author=True): sim=0.85
# Comparing t/nk (None) vs Natural Killer (NK) cell (CL_0000623) (fuzzy author=False): sim=0
# Comparing th2 (CL:0000546) vs T-cell (CL_0000827) (fuzzy author=True): sim=0.3333333333333333
# Comparing transitional-b (CL:0000244) vs Pre-B cell (CL_0000817) (fuzzy author=True): sim=0.34782608695652173
# Comparing cdc (CL:0000990) vs Granulocyte-Monocyte Progenitor (GMP) (CL_0000557) (fuzzy author=False): sim=0.30303030303030304
# Comparing early-erythroid (CL:0001066) vs Erythroblast (CL_0000765) (fuzzy author=True): sim=0.7
# Comparing early-mono (CL:0000049) vs Promyelocyte (CL_0000564) (fuzzy author=True): sim=0.5
# Comparing early-neu (CL:0000049) vs Granulocyte precursor (CL_0000564) (fuzzy author=True): sim=0.5
# Comparing bmcp (CL:0002028) vs Mast cell (CL_0000831) (fuzzy author=False): sim=0.8421052631578947
# Comparing pdc (CL:0000784) vs Plasmacytoid Dendritic Cell (CL_0000784) (fuzzy author=False): sim=1.0
# Comparing pre-b (CL:0000817) vs Pro-B cell (CL_0000826) (fuzzy author=True): sim=0.37037037037037035
# Comparing pre-dc (CL:0002010) vs Conventional dendritic cell type 2 (CL_0000990) (fuzzy author=True): sim=0.38461538461538464
# Comparing cd4 t-cell (CL:0000000) vs T-cell (CL_0000084) (fuzzy author=True): sim=0.4117647058823529
# Comparing cd8 t-cell (CL:0000000) vs T-cell (CL_0000900) (fuzzy author=True): sim=0.30434782608695654
# Comparing clp (CL:0000051) vs B-cell progenitor (CL_0000826) (fuzzy author=False): sim=0.7222222222222222
# Comparing eos-early (CL:0000049) vs Basophil (CL_0000767) (fuzzy author=True): sim=0.47619047619047616
# Comparing erythroblast (CL:0000765) vs Erythroid precursor (CL_0000764) (fuzzy author=False): sim=0.8
# Comparing gmp (CL:0000557) vs Granulocyte-Monocyte Progenitor (CL_0001012) (fuzzy author=False): sim=0.7619047619047619
# Comparing asdc (None) vs Monocyte (CL_0000576) (fuzzy author=False): sim=0
# Comparing hsc (CL:0000037) vs Hematopoietic Stem/Progenitor Cells (CL_0001024) (fuzzy author=False): sim=0.9411764705882353
# Comparing mdp (CL:0002009) vs B cell (CL_0000788) (fuzzy author=False): sim=0.3448275862068966
# Comparing mep (CL:0000050) vs Hematopoietic Stem/Progenitor Cells (HSPCs) (CL_0001024) (fuzzy author=False): sim=0.65
# Comparing mkp (CL:0000553) vs Megakaryocyte (CL_0000556) (fuzzy author=False): sim=0.6111111111111112
# Comparing mpp (CL:0000837) vs Hematopoietic Stem Cell (CL_0000037) (fuzzy author=False): sim=0.6470588235294118
# Comparing mac (CL:0000091) vs Macrophage (CL_0000235) (fuzzy author=True): sim=0.92
# Comparing mast-early (CL:0002354) vs Basophil (CL_0000767) (fuzzy author=True): sim=0.38461538461538464
# Comparing monocyte (CL:0001054) vs Monocyte (CL_0000576) (fuzzy author=False): sim=0.96
# Comparing multilin (CL:0011018) vs Hematopoietic Stem/Progenitor Cell (CL_0001024) (fuzzy author=True): sim=0.38461538461538464
# Comparing myeloid intermediate (CL:0001059) vs Neutrophil (CL_0000775) (fuzzy author=True): sim=0.4166666666666667
# Comparing b cell (CL:0000236) vs B cell (CL_0000236) (fuzzy author=False): sim=1.0
# Comparing plasma cell (CL:0000786) vs Plasma Cell (CL_0000786) (fuzzy author=False): sim=1.0
# Comparing stromal (CL:0000134) vs Mesenchymal Stromal Cell (CL_0000134) (fuzzy author=True): sim=1.0
# Comparing t proliferating (CL:4033069) vs T cell (CL_0000084) (fuzzy author=True): sim=0.9444444444444444
# Comparing t/nk (None) vs Natural Killer Cell (CL_0000623) (fuzzy author=False): sim=0
# Comparing th2 (CL:0000546) vs T cell (CL_0000827) (fuzzy author=True): sim=0.3333333333333333
# Comparing transitional-b (CL:0000244) vs B cell progenitor (CL_0000826) (fuzzy author=True): sim=0.4444444444444444
# Comparing cdc (CL:0000990) vs Monocyte (CL_0000576) (fuzzy author=False): sim=0.7037037037037037
# Comparing early-erythroid (CL:0001066) vs Erythroid precursor (CL_0000038) (fuzzy author=True): sim=0.9473684210526315
# Comparing early-mono (CL:0000049) vs Myeloid Progenitor (CL_0000049) (fuzzy author=True): sim=1.0
# Comparing early-neu (CL:0000049) vs Neutrophil Progenitor (CL_0000834) (fuzzy author=True): sim=0.55
# Comparing bmcp (CL:0002028) vs Mast Cell (CL_0000097) (fuzzy author=False): sim=0.4230769230769231
# Comparing pdc (CL:0000784) vs B cell (CL_0000236) (fuzzy author=False): sim=0.6
# Comparing pre-b (CL:0000817) vs B cell progenitor (CL_0000826) (fuzzy author=True): sim=0.37037037037037035
# Comparing pre-dc (CL:0002010) vs Monocyte/Macrophage (CL_0000235) (fuzzy author=True): sim=0.4230769230769231
# Comparing cd4 t-cell (CL:0000000) vs T cell (CL_0000827) (fuzzy author=True): sim=0.4375
# Comparing cd8 t-cell (CL:0000000) vs T cell (CL_0000084) (fuzzy author=True): sim=0.4117647058823529
# Comparing clp (CL:0000051) vs B-cell progenitor (CL_0000826) (fuzzy author=False): sim=0.7222222222222222
# Comparing eos-early (CL:0000049) vs Basophil (CL_0000767) (fuzzy author=True): sim=0.47619047619047616
# Comparing erythroblast (CL:0000765) vs Erythroid precursors (CL_0000552) (fuzzy author=False): sim=0.9375
# Comparing gmp (CL:0000557) vs Hematopoietic Stem/Progenitor Cells (HSPCs) (CL_0001024) (fuzzy author=False): sim=0.52
# Comparing asdc (None) vs nan (CL_0000738) (fuzzy author=False): sim=0
# Comparing hsc (CL:0000037) vs HSPC (CL_0000037) (fuzzy author=False): sim=1.0
# Comparing mdp (CL:0002009) vs Immune cell (CL_0000738) (fuzzy author=False): sim=0.5263157894736842
# Comparing mep (CL:0000050) vs Hematopoietic progenitor cell (CL_0000038) (fuzzy author=False): sim=0.7
# Comparing mkp (CL:0000553) vs Megakaryocyte (CL_0000556) (fuzzy author=False): sim=0.6111111111111112
# Comparing mpp (CL:0000837) vs Multipotent progenitor cell (CL_0000837) (fuzzy author=False): sim=1.0
# Comparing mac (CL:0000091) vs Macrophage (CL_0000235) (fuzzy author=True): sim=0.92
# Comparing mast-early (CL:0002354) vs Eosinophil (CL_0000771) (fuzzy author=True): sim=0.38461538461538464
# Comparing monocyte (CL:0001054) vs Monocyte (CL_0000576) (fuzzy author=False): sim=0.96
# Comparing multilin (CL:0011018) vs nan (CL_0000738) (fuzzy author=True): sim=0.6842105263157895
# Comparing myeloid intermediate (CL:0001059) vs nan (CL_0000738) (fuzzy author=True): sim=0.5263157894736842
# Comparing b cell (CL:0000236) vs nan (CL_0000738) (fuzzy author=False): sim=0.7222222222222222
# Comparing plasma cell (CL:0000786) vs nan (CL_0000738) (fuzzy author=False): sim=0.6842105263157895
# Comparing stromal (CL:0000134) vs Mesenchymal stromal cell (CL_0000499) (fuzzy author=True): sim=0.6
# Comparing t proliferating (CL:4033069) vs T cell (CL_0000084) (fuzzy author=True): sim=0.9444444444444444
# Comparing t/nk (None) vs T cell (CL_0000084) (fuzzy author=False): sim=0
# Comparing th2 (CL:0000546) vs T cell (CL_0000084) (fuzzy author=True): sim=0.7083333333333334
# Comparing transitional-b (CL:0000244) vs B cell (CL_0000816) (fuzzy author=True): sim=0.34782608695652173
# Comparing cdc (CL:0000990) vs nan (CL_0000738) (fuzzy author=False): sim=0.5909090909090909
# Comparing early-erythroid (CL:0001066) vs nan (CL_0000738) (fuzzy author=True): sim=0.45454545454545453
# Comparing early-mono (CL:0000049) vs Monocyte (CL_0000576) (fuzzy author=True): sim=0.37037037037037035
# Comparing early-neu (CL:0000049) vs nan (CL_0000738) (fuzzy author=True): sim=0.625
# Comparing bmcp (CL:0002028) vs Mast cell (CL_0000097) (fuzzy author=False): sim=0.4230769230769231
# Comparing pdc (CL:0000784) vs nan (CL_0000738) (fuzzy author=False): sim=0.5909090909090909
# Comparing pre-b (CL:0000817) vs B cell (CL_0000940) (fuzzy author=True): sim=0.6153846153846154
# Comparing pre-dc (CL:0002010) vs Dendritic cell (CL_0000451) (fuzzy author=True): sim=0.4
# Comparing cd4 t-cell (CL:0000000) vs T cell (CL_0000084) (fuzzy author=True): sim=0.4117647058823529
# Comparing cd8 t-cell (CL:0000000) vs T cell (CL_0000084) (fuzzy author=True): sim=0.4117647058823529
# Comparing clp (CL:0000051) vs Lymphoid progenitor cell (CL_0000838) (fuzzy author=False): sim=0.7647058823529411
# Comparing eos-early (CL:0000049) vs Eosinophil (CL_0000775) (fuzzy author=True): sim=0.47619047619047616
# Comparing erythroblast (CL:0000765) vs Erythroid cells (CL_0000764) (fuzzy author=False): sim=0.8
# Comparing gmp (CL:0000557) vs nan (CL_0000738) (fuzzy author=False): sim=0.4166666666666667
# Comparing asdc (None) vs Monocyte progenitor (CL_0000040) (fuzzy author=False): sim=0
# Comparing hsc (CL:0000037) vs Progenitor cell (CL_0000837) (fuzzy author=False): sim=0.6470588235294118
# Comparing mdp (CL:0002009) vs Lymphoid Progenitor (CL_0000838) (fuzzy author=False): sim=0.7222222222222222
# Comparing mep (CL:0000050) vs Erythroid Progenitor (CL_0000038) (fuzzy author=False): sim=0.7
# Comparing mkp (CL:0000553) vs Megakaryocyte (CL_0000556) (fuzzy author=False): sim=0.6111111111111112
# Comparing mpp (CL:0000837) vs Hematopoietic Stem Cell (CL_0000037) (fuzzy author=False): sim=0.6470588235294118
# Comparing mac (CL:0000091) vs Macrophage (CL_0002476) (fuzzy author=True): sim=0.8
# Comparing mast-early (CL:0002354) vs Mast cell (CL_0000097) (fuzzy author=True): sim=0.37037037037037035
# Comparing monocyte (CL:0001054) vs Monocyte (CL_0000576) (fuzzy author=False): sim=0.96
# Comparing multilin (CL:0011018) vs Hematopoietic stem cell (CL_0000037) (fuzzy author=True): sim=0.4
# Comparing myeloid intermediate (CL:0001059) vs Neutrophil (CL_0000096) (fuzzy author=True): sim=0.37037037037037035
# Comparing b cell (CL:0000236) vs B cell (CL_0000816) (fuzzy author=False): sim=0.8571428571428571
# Comparing plasma cell (CL:0000786) vs B cells (CL_0000787) (fuzzy author=False): sim=0.68
# Comparing stromal (CL:0000134) vs Fibroblast (CL_0002240) (fuzzy author=True): sim=0.45
# Comparing t proliferating (CL:4033069) vs T-cell (CL_0000084) (fuzzy author=True): sim=0.9444444444444444
# Comparing t/nk (None) vs T/NK cell (CL_0000623) (fuzzy author=False): sim=0
# Comparing th2 (CL:0000546) vs T cell (CL_0000084) (fuzzy author=True): sim=0.7083333333333334
# Comparing transitional-b (CL:0000244) vs B cell (CL_0000817) (fuzzy author=True): sim=0.34782608695652173
# Comparing cdc (CL:0000990) vs Monocyte (CL_0000576) (fuzzy author=False): sim=0.7037037037037037
# Comparing early-erythroid (CL:0001066) vs Erythroid cell (CL_0000765) (fuzzy author=True): sim=0.7
# Comparing early-mono (CL:0000049) vs Myeloid cell (CL_0000096) (fuzzy author=True): sim=0.4166666666666667
# Comparing early-neu (CL:0000049) vs Neutrophil (CL_0000096) (fuzzy author=True): sim=0.4166666666666667
# Comparing bmcp (CL:0002028) vs Mast cell (CL_0000097) (fuzzy author=False): sim=0.4230769230769231
# Comparing pdc (CL:0000784) vs B cell (CL_0000816) (fuzzy author=False): sim=0.5357142857142857
# Comparing pre-b (CL:0000817) vs B cell progenitor (CL_0002046) (fuzzy author=True): sim=0.35714285714285715
# Comparing pre-dc (CL:0002010) vs Myeloid cells (CL_0000763) (fuzzy author=True): sim=0.7857142857142857
# Comparing cd4 t-cell (CL:0000000) vs T cell (CL_0000827) (fuzzy author=True): sim=0.4375
# Comparing cd8 t-cell (CL:0000000) vs T-cell (CL_0000084) (fuzzy author=True): sim=0.4117647058823529
# Comparing clp (CL:0000051) vs B-cell Progenitor (CL_0002046) (fuzzy author=False): sim=0.6842105263157895
# Comparing eos-early (CL:0000049) vs Mast Cell (CL_0000831) (fuzzy author=True): sim=0.5789473684210527
# Comparing erythroblast (CL:0000765) vs Erythroid cells (CL_0000232) (fuzzy author=False): sim=0.6666666666666666
# Comparing gmp (CL:0000557) vs Hematopoietic stem cell (CL_0000037) (fuzzy author=False): sim=0.5416666666666666
# Comparing asdc (None) vs Dendritic cell (CL_0000451) (fuzzy author=False): sim=0
# Comparing hsc (CL:0000037) vs Hematopoietic stem/progenitor cell (HSPC) (CL_0001024) (fuzzy author=False): sim=0.9411764705882353
# Comparing mdp (CL:0002009) vs Multipotent progenitor (MPP)/early lymphoid-primed progenitor (CL_0000936) (fuzzy author=False): sim=0.7222222222222222
# Comparing mep (CL:0000050) vs Hematopoietic stem/progenitor cell (HSPC) (CL_0000837) (fuzzy author=False): sim=0.6470588235294118
# Comparing mkp (CL:0000553) vs Megakaryocyte (CL_0000556) (fuzzy author=False): sim=0.6111111111111112
# Comparing mpp (CL:0000837) vs Hematopoietic stem/progenitor cell (HSPC) (CL_0000037) (fuzzy author=False): sim=0.6470588235294118
# Comparing mac (CL:0000091) vs Macrophage (CL_0002476) (fuzzy author=True): sim=0.8
# Comparing mast-early (CL:0002354) vs Mast cell (CL_0000097) (fuzzy author=True): sim=0.37037037037037035
# Comparing monocyte (CL:0001054) vs Monocyte (CL_0002057) (fuzzy author=False): sim=0.9259259259259259
# Comparing multilin (CL:0011018) vs Hematopoietic stem/progenitor cell (HSPC) (CL_0000037) (fuzzy author=True): sim=0.4
# Comparing myeloid intermediate (CL:0001059) vs Neutrophil (CL_0000775) (fuzzy author=True): sim=0.4166666666666667
# Comparing b cell (CL:0000236) vs B cell (CL_0000785) (fuzzy author=False): sim=0.8181818181818182
# Comparing plasma cell (CL:0000786) vs Plasma cell (CL_0000786) (fuzzy author=False): sim=1.0
# Comparing stromal (CL:0000134) vs Bone marrow mesenchymal stromal cell (MSC) (CL_0002540) (fuzzy author=True): sim=0.8125
# Comparing t proliferating (CL:4033069) vs T cell (CL_0000898) (fuzzy author=True): sim=0.85
# Comparing t/nk (None) vs nan (CL_0000000) (fuzzy author=False): sim=0
# Comparing th2 (CL:0000546) vs nan (CL_0000000) (fuzzy author=True): sim=0.2916666666666667
# Comparing transitional-b (CL:0000244) vs nan (CL_0000000) (fuzzy author=True): sim=0.7
# Comparing cdc (CL:0000990) vs nan (CL_0000000) (fuzzy author=False): sim=0.3181818181818182
# Comparing early-erythroid (CL:0001066) vs nan (CL_0000000) (fuzzy author=True): sim=0.3684210526315789
# Comparing early-mono (CL:0000049) vs nan (CL_0000000) (fuzzy author=True): sim=0.5384615384615384
# Comparing early-neu (CL:0000049) vs nan (CL_0000000) (fuzzy author=True): sim=0.5384615384615384
# Comparing bmcp (CL:0002028) vs nan (CL_0000000) (fuzzy author=False): sim=0.3888888888888889
# Comparing pdc (CL:0000784) vs nan (CL_0000000) (fuzzy author=False): sim=0.3181818181818182
# Comparing pre-b (CL:0000817) vs nan (CL_0000000) (fuzzy author=True): sim=0.3333333333333333
# Comparing pre-dc (CL:0002010) vs nan (CL_0000000) (fuzzy author=True): sim=0.5
# Comparing cd4 t-cell (CL:0000000) vs nan (CL_0000000) (fuzzy author=True): sim=1.0
# Comparing cd8 t-cell (CL:0000000) vs nan (CL_0000000) (fuzzy author=True): sim=1.0
# Comparing clp (CL:0000051) vs nan (CL_0000000) (fuzzy author=False): sim=0.4666666666666667
# Comparing eos-early (CL:0000049) vs nan (CL_0000000) (fuzzy author=True): sim=0.5384615384615384
# Comparing erythroblast (CL:0000765) vs nan (CL_0000000) (fuzzy author=False): sim=0.4666666666666667
# Comparing gmp (CL:0000557) vs nan (CL_0000000) (fuzzy author=False): sim=0.3333333333333333
# Comparing asdc (None) vs Dendritic cell (CL_0000782) (fuzzy author=False): sim=0
# Comparing hsc (CL:0000037) vs Hematopoietic Stem and Progenitor Cells (HSPCs) (CL_0000837) (fuzzy author=False): sim=0.6470588235294118
# Comparing mdp (CL:0002009) vs B-cell progenitor (CL_0000826) (fuzzy author=False): sim=0.6842105263157895
# Comparing mep (CL:0000050) vs Hematopoietic Stem and Progenitor Cell (HSPC) (CL_0000837) (fuzzy author=False): sim=0.6470588235294118
# Comparing mkp (CL:0000553) vs Megakaryocyte (CL_0000556) (fuzzy author=False): sim=0.6111111111111112
# Comparing mpp (CL:0000837) vs Hematopoietic Stem Cell (CL_0001024) (fuzzy author=False): sim=0.6111111111111112
# Comparing mac (CL:0000091) vs Tissue-resident macrophage (CL_0002476) (fuzzy author=True): sim=0.8
# Comparing mast-early (CL:0002354) vs Mast cell (CL_0000097) (fuzzy author=True): sim=0.37037037037037035
# Comparing monocyte (CL:0001054) vs Monocyte (CL_0002057) (fuzzy author=False): sim=0.9259259259259259
# Comparing multilin (CL:0011018) vs B-cell progenitor (CL_0002046) (fuzzy author=True): sim=0.38461538461538464
# Comparing myeloid intermediate (CL:0001059) vs Promyelocyte (CL_0000564) (fuzzy author=True): sim=0.5652173913043478
# Comparing b cell (CL:0000236) vs B cell (CL_0000788) (fuzzy author=False): sim=0.782608695652174
# Comparing plasma cell (CL:0000786) vs Plasma cell (CL_0000786) (fuzzy author=False): sim=1.0
# Comparing stromal (CL:0000134) vs Mesenchymal Stromal Cell (CL_0002540) (fuzzy author=True): sim=0.8125
# Comparing t proliferating (CL:4033069) vs T cell (CL_0000084) (fuzzy author=True): sim=0.9444444444444444
# Comparing t/nk (None) vs Natural Killer (NK) cell (CL_0000939) (fuzzy author=False): sim=0
# Comparing th2 (CL:0000546) vs T cell (CL_0000084) (fuzzy author=True): sim=0.7083333333333334
# Comparing transitional-b (CL:0000244) vs B cell precursor (CL_0000957) (fuzzy author=True): sim=0.32
# Comparing cdc (CL:0000990) vs Dendritic cell (CL_0000782) (fuzzy author=False): sim=0.88
# Comparing early-erythroid (CL:0001066) vs Erythroid progenitor (CL_0000038) (fuzzy author=True): sim=0.9473684210526315
# Comparing early-mono (CL:0000049) vs Neutrophil (CL_0000096) (fuzzy author=True): sim=0.4166666666666667
# Comparing early-neu (CL:0000049) vs Promyelocyte (CL_0000564) (fuzzy author=True): sim=0.5
# Comparing bmcp (CL:0002028) vs Mast cells (CL_0000097) (fuzzy author=False): sim=0.4230769230769231
# Comparing pdc (CL:0000784) vs Plasma cell (CL_0000786) (fuzzy author=False): sim=0.5769230769230769
# Comparing pre-b (CL:0000817) vs B cell precursor (CL_0000817) (fuzzy author=True): sim=1.0
# Comparing pre-dc (CL:0002010) vs Dendritic cell (CL_0002399) (fuzzy author=True): sim=0.3793103448275862
# Comparing cd4 t-cell (CL:0000000) vs T cell (CL_0000895) (fuzzy author=True): sim=0.30434782608695654
# Comparing cd8 t-cell (CL:0000000) vs T cell (CL_0000898) (fuzzy author=True): sim=0.3684210526315789
# Comparing clp (CL:0000051) vs Pre-B cell (CL_0000957) (fuzzy author=False): sim=0.35714285714285715
# Comparing eos-early (CL:0000049) vs Mast cell (CL_0000097) (fuzzy author=True): sim=0.45454545454545453
# Comparing erythroblast (CL:0000765) vs Erythroid progenitor (CL_0000552) (fuzzy author=False): sim=0.9375
# Comparing gmp (CL:0000557) vs Hematopoietic Stem/Progenitor Cell (CL_0000837) (fuzzy author=False): sim=0.5
# Comparing asdc (None) vs Antigen-presenting cell (APC) (CL_0011031) (fuzzy author=False): sim=0
# Comparing hsc (CL:0000037) vs Hematopoietic stem and progenitor cell (CL_0000037) (fuzzy author=False): sim=1.0
# Comparing mdp (CL:0002009) vs Plasmacytoid dendritic cell (pDC) progenitor (CL_0002009) (fuzzy author=False): sim=1.0
# Comparing mep (CL:0000050) vs Hematopoietic stem and progenitor cell (HSPC) (CL_0000050) (fuzzy author=False): sim=1.0
# Comparing mkp (CL:0000553) vs Megakaryocyte lineage cell (CL_0002023) (fuzzy author=False): sim=0.9444444444444444
# Comparing mpp (CL:0000837) vs Hematopoietic stem and progenitor cell (HSPC) (CL_0000037) (fuzzy author=False): sim=0.6470588235294118
# Comparing mac (CL:0000091) vs Macrophage (CL_0002476) (fuzzy author=True): sim=0.8
# Comparing mast-early (CL:0002354) vs Mast cell (CL_0000097) (fuzzy author=True): sim=0.37037037037037035
# Comparing monocyte (CL:0001054) vs Monocyte (CL_0001055) (fuzzy author=False): sim=0.8928571428571429
# Comparing multilin (CL:0011018) vs Hematopoietic Stem and Progenitor Cell (HSPC) (CL_0000837) (fuzzy author=True): sim=0.47619047619047616
# Comparing myeloid intermediate (CL:0001059) vs Neutrophil precursor / immature neutrophil (CL_0000776) (fuzzy author=True): sim=0.4
# Comparing b cell (CL:0000236) vs B cell (CL_0000816) (fuzzy author=False): sim=0.8571428571428571
# Comparing plasma cell (CL:0000786) vs Plasma cell (CL_0000786) (fuzzy author=False): sim=1.0
# Comparing stromal (CL:0000134) vs Bone marrow stromal cell (CL_0010001) (fuzzy author=True): sim=0.5
# Comparing t proliferating (CL:4033069) vs Proliferating T cell (CL_4033069) (fuzzy author=True): sim=1.0
# Comparing t/nk (None) vs Natural Killer (NK) cell (CL_0000623) (fuzzy author=False): sim=0
# Comparing th2 (CL:0000546) vs CD4-positive memory T cell (CL_0000897) (fuzzy author=True): sim=0.8076923076923077
# Comparing transitional-b (CL:0000244) vs Transitional B cell (CL_0000818) (fuzzy author=True): sim=0.34782608695652173
# Comparing cdc (CL:0000990) vs Monocyte / Antigen-presenting cell (CL_0000860) (fuzzy author=False): sim=0.6785714285714286
# Comparing early-erythroid (CL:0001066) vs Erythroid precursor (CL_0000547) (fuzzy author=True): sim=0.5714285714285714
# Comparing early-mono (CL:0000049) vs Granulocyte-Monocyte Progenitor (GMP) (CL_0000557) (fuzzy author=True): sim=0.5454545454545454
# Comparing early-neu (CL:0000049) vs Granulocyte precursor (CL_0000557) (fuzzy author=True): sim=0.5454545454545454
# Comparing bmcp (CL:0002028) vs Basophil (CL_0000767) (fuzzy author=False): sim=0.44
# Comparing pdc (CL:0000784) vs Plasma cell (CL_0000786) (fuzzy author=False): sim=0.5769230769230769
# Comparing pre-b (CL:0000817) vs Pro-B cell (CL_0000826) (fuzzy author=True): sim=0.37037037037037035
# Comparing pre-dc (CL:0002010) vs Conventional dendritic cell (cDC) (CL_0000990) (fuzzy author=True): sim=0.38461538461538464
# Comparing cd4 t-cell (CL:0000000) vs CD4-positive T cell (CL_0000492) (fuzzy author=True): sim=0.3181818181818182
# Comparing cd8 t-cell (CL:0000000) vs T cell (CL_0002419) (fuzzy author=True): sim=0.3888888888888889
# Comparing clp (CL:0000051) vs B cell progenitor (CL_0000826) (fuzzy author=False): sim=0.7222222222222222
# Comparing eos-early (CL:0000049) vs Mast cell (CL_0000097) (fuzzy author=True): sim=0.45454545454545453
# Comparing erythroblast (CL:0000765) vs Erythroid precursor (CL_0000765) (fuzzy author=False): sim=1.0
# Comparing gmp (CL:0000557) vs Granulocyte-Macrophage Progenitor (GMP) (CL_0000557) (fuzzy author=False): sim=1.0
# Comparing asdc (None) vs Dendritic cell (CL_0001056) (fuzzy author=False): sim=0
# Comparing hsc (CL:0000037) vs Hematopoietic Stem Cell (HSC) (CL_0000037) (fuzzy author=False): sim=1.0
# Comparing mdp (CL:0002009) vs B cell (CL_0000818) (fuzzy author=False): sim=0.37037037037037035
# Comparing mep (CL:0000050) vs Hematopoietic Stem Cell (CL_0000037) (fuzzy author=False): sim=0.6842105263157895
# Comparing mkp (CL:0000553) vs Megakaryocyte progenitor (CL_0000553) (fuzzy author=False): sim=1.0
# Comparing mpp (CL:0000837) vs Hematopoietic Stem/Progenitor Cell (HSPC) (CL_0001024) (fuzzy author=False): sim=0.6111111111111112
# Comparing mac (CL:0000091) vs Macrophage (CL_0000864) (fuzzy author=True): sim=0.96
# Comparing mast-early (CL:0002354) vs Mast Cell Progenitor (CL_0000831) (fuzzy author=True): sim=0.5909090909090909
# Comparing monocyte (CL:0001054) vs Classical Monocyte (CL_0002057) (fuzzy author=False): sim=0.9259259259259259
# Comparing multilin (CL:0011018) vs Hematopoietic stem/progenitor cell (CL_0000837) (fuzzy author=True): sim=0.47619047619047616
# Comparing myeloid intermediate (CL:0001059) vs Myeloid Progenitor (CL_0000557) (fuzzy author=True): sim=0.6086956521739131
# Comparing b cell (CL:0000236) vs B cell (CL_0000236) (fuzzy author=False): sim=1.0
# Comparing plasma cell (CL:0000786) vs Plasma cell (CL_0000786) (fuzzy author=False): sim=1.0
# Comparing stromal (CL:0000134) vs Mesenchymal stromal cell (CL_0000134) (fuzzy author=True): sim=1.0
# Comparing t proliferating (CL:4033069) vs T-cell (CL_0000084) (fuzzy author=True): sim=0.9444444444444444
# Comparing t/nk (None) vs T cell (CL_0000084) (fuzzy author=False): sim=0
# Comparing th2 (CL:0000546) vs T cell (CL_0000084) (fuzzy author=True): sim=0.7083333333333334
# Comparing transitional-b (CL:0000244) vs Transitional B cell (CL_0000818) (fuzzy author=True): sim=0.34782608695652173
# Comparing cdc (CL:0000990) vs Dendritic cell (CL_0001056) (fuzzy author=False): sim=0.9130434782608695
# Comparing early-erythroid (CL:0001066) vs Erythroid progenitor cell (CL_0000765) (fuzzy author=True): sim=0.7
# Comparing early-mono (CL:0000049) vs Monocyte (CL_0000860) (fuzzy author=True): sim=0.35714285714285715
# Comparing early-neu (CL:0000049) vs Neutrophil precursor (CL_0000776) (fuzzy author=True): sim=0.45454545454545453
# Comparing bmcp (CL:0002028) vs Hematopoietic progenitor cell (CL_0001059) (fuzzy author=False): sim=0.6190476190476191
# Comparing pdc (CL:0000784) vs Plasma cell (CL_0000786) (fuzzy author=False): sim=0.5769230769230769
# Comparing pre-b (CL:0000817) vs Pro-B cell (CL_0000826) (fuzzy author=True): sim=0.37037037037037035
# Comparing pre-dc (CL:0002010) vs Cell (CL_0000000) (fuzzy author=True): sim=0.5
# Comparing cd4 t-cell (CL:0000000) vs T cell (CL_0000084) (fuzzy author=True): sim=0.4117647058823529
# Comparing cd8 t-cell (CL:0000000) vs T cell (CL_0000084) (fuzzy author=True): sim=0.4117647058823529
# Comparing clp (CL:0000051) vs B cell (CL_0000791) (fuzzy author=False): sim=0.4
# Comparing eos-early (CL:0000049) vs Cell (CL_0000000) (fuzzy author=True): sim=0.5384615384615384
# Comparing erythroblast (CL:0000765) vs Cell (CL_0000000) (fuzzy author=False): sim=0.4666666666666667
# Comparing gmp (CL:0000557) vs Cell (CL_0000000) (fuzzy author=False): sim=0.3333333333333333
#   Saved: cluster_descriptions_with_author_similarity.csv
